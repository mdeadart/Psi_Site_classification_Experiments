# %%
##################################################################################
##### Define all parameters for model tuning
##################################################################################

n_fold = 10
expName = "PSI_Site_DLNN_RNAfold"
outPath = "Results"
foldName = "folds.pickle"

# modelNames = ["DLNN_3", "DLNN_5"]

epochs = 100
batch_size = 16
shuffle = False
seed = None


input_data_folder = "Data\\Aziz"

# %%
import os 
from Bio import SeqIO
import pickle
import numpy as np
import pandas as pd

import tensorflow as tf

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc, accuracy_score, precision_score, confusion_matrix
from sklearn.metrics import roc_auc_score

import math

# %%
# print(tf.test.is_gpu_available(cuda_only=True))
# physical_devices = tf.config.experimental.list_physical_devices('GPU')
physical_devices = tf.config.list_physical_devices('GPU')
print(physical_devices)
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
##################################################################################
##### define all CUSTOM functions
##################################################################################

def one_hot_encode_dna(sequence):
    seq_encoded = np.zeros((len(sequence),4))
    dict_nuc = {
        "A": 0,
        "C": 1,
        "G": 2,
        "T": 3
    }
    i = 0
    for single_character in sequence:
        if(single_character.upper() in dict_nuc.keys()):
            seq_encoded[i][dict_nuc[single_character.upper()]] = 1
            i = i+1
        else:
            raise ValueError('Incorrect character in DNA sequence: '+sequence)
    return seq_encoded

def one_hot_encode_rna(sequence):
    seq_encoded = np.zeros((len(sequence),4))
    dict_nuc = {
        "A": 0,
        "C": 1,
        "G": 2,
        "U": 3
    }
    i = 0
    for single_character in sequence:
        if(single_character.upper() in dict_nuc.keys()):
            seq_encoded[i][dict_nuc[single_character.upper()]] = 1
            i = i+1
        else:
            raise ValueError('Incorrect character in RNA sequence: '+sequence)
    return seq_encoded

def one_hot_encode_rnafold(sequence):
    seq_encoded = np.zeros((len(sequence),3))
    dict_fold = {
        "(": 0,
        ")": 1,
        ".": 2
    }
    i = 0
    for single_character in sequence:
        if(single_character in dict_fold.keys()):
            seq_encoded[i][dict_fold[single_character]] = 1
            i = i+1
        else:
            raise ValueError('Incorrect character in RNAfold: '+sequence)
    return seq_encoded

# %%
##################################################################################
##### define evaluator functions
##################################################################################

## Build the K-fold from dataset
def build_kfold(features, labels, k=10, shuffle=False, seed=None):
    
    skf = StratifiedKFold(n_splits=k, shuffle=shuffle, random_state=seed)
    kfoldList = []
    for train_index, test_index in skf.split(features, labels):
        X_train, X_test = features[train_index], features[test_index]
        y_train, y_test = labels[train_index], labels[test_index]
        kfoldList.append({
            "X_train": X_train,
            "X_test": X_test,
            "y_train":y_train,
            "y_test":y_test
        })
    return kfoldList

def build_kfold_multifeature(features_1, features_2, labels, k=10, shuffle=False, seed=None):
    
    skf = StratifiedKFold(n_splits=k, shuffle=shuffle, random_state=seed)
    kfoldList = []
    for train_index, test_index in skf.split(features_1, labels):
        X1_train, X1_test = features_1[train_index], features_1[test_index]
        X2_train, X2_test = features_2[train_index], features_2[test_index]
        y_train, y_test = labels[train_index], labels[test_index]
        kfoldList.append({
            "X1_train": X1_train,
            "X1_test": X1_test,
            "X2_train": X2_train,
            "X2_test": X2_test,
            "y_train":y_train,
            "y_test":y_test
        })
    return kfoldList

def pred2label(y_pred):
    y_pred = np.round(np.clip(y_pred, 0, 1))
    return y_pred

# %%
##################################################################################
##### Function to customize the DLNN architecture with parameters
##################################################################################

def DLNN_RNAFold_custom_1(input_shape_1 = (21,4), input_shape_2 = (21,3),
                          conv_filters_per_layer = 5, max_kernel_length = 9, conv_strides = 1, ## 1st Convolutional layer parameters
                          max_pool_width = 2, max_pool_stride = 2, ## 1st Maxpool layer parameters
                          rnn_decode_units = 25, ## LSTM layer parameters
                          dense_decode_units = 512, ## Dense layer parameters
                          prob = 0.5, learn_rate = 0.001, loss = 'binary_crossentropy', 
                          metrics = None):
    
    # beta = 0.001
    
    assert max_kernel_length >= 3
    
    # max_kernel_length = int(np.ceil(input_shape_1[0]/2))
    
    input1 = tf.keras.layers.Input(shape=input_shape_1)
    input2 = tf.keras.layers.Input(shape=input_shape_2)
    
    ##################################################
    ##### SEQUENCE
    ##################################################
    
    #########################
    ##### LSTM
    #########################
    
    sx1 = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(rnn_decode_units, 
                                                             return_sequences=True, 
                                                             return_state=False))(input1)
    # sx1 = tf.keras.layers.Dropout(prob)(sx1)
    sx1 = tf.keras.layers.Flatten()(sx1)
    
    #########################
    ##### Multipath Conv
    #########################
    
    sx2 = []
    for kernel_length in range(3, max_kernel_length):
        
        sxx = tf.keras.layers.Conv1D(conv_filters_per_layer, kernel_length, strides = conv_strides)(input1)
        sxx = tf.keras.layers.Activation('relu')(sxx)
        sxx = tf.keras.layers.MaxPool1D(pool_size = max_pool_width, strides = max_pool_stride)(sxx)
        # sxx = tf.keras.layers.Dropout(prob)(sxx)
        sxx = tf.keras.layers.Flatten()(sxx)
        
        sx2.append(sxx)
    
    ##################################################
    ##### FOLD
    ##################################################
    
    fx1 = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(rnn_decode_units, 
                                                             return_sequences=True, 
                                                             return_state=False))(input2)
    # fx1 = tf.keras.layers.Dropout(prob)(fx1)
    fx1 = tf.keras.layers.Flatten()(fx1)
    
    #########################
    ##### Multipath Conv
    #########################
    
    fx2 = []
    for kernel_length in range(2, max_kernel_length):
        
        fxx = tf.keras.layers.Conv1D(conv_filters_per_layer, kernel_length, strides = conv_strides)(input2)
        fxx = tf.keras.layers.Activation('relu')(fxx)
        fxx = tf.keras.layers.MaxPool1D(pool_size = max_pool_width, strides = max_pool_stride)(fxx)
        # fxx = tf.keras.layers.Dropout(prob)(fxx)
        fxx = tf.keras.layers.Flatten()(fxx)
        
        fx2.append(fxx)
    
    ##################################################
    ##### Fully connected Layers
    ##################################################

    y = tf.keras.layers.Concatenate(1)([fx1]+fx2+[sx1]+sx2)
    
    y = tf.keras.layers.Dense(dense_decode_units, activation = 'relu')(y)
    y = tf.keras.layers.Dropout(prob)(y)
    
    # y = tf.keras.layers.Dense(2, activation = 'softmax')(y)
    
    y = tf.keras.layers.Dense(1, activation = 'sigmoid')(y)
    
    #########################
    ##### Generate Model from input and output
    #########################
    
    model = tf.keras.models.Model(inputs=[input1, input2], outputs=y)
    
    ## Compile model
    if(metrics != None):
        model.compile(optimizer = tf.keras.optimizers.Adam(lr=learn_rate), loss = loss, metrics = metrics)
    else:
        model.compile(optimizer = tf.keras.optimizers.Adam(lr=learn_rate), loss = loss)

    return model

# %%
DLNN_RNAFold_custom_1().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 21, 3)]      0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 21, 4)]      0
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 20, 5)        35          input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 19, 5)        50          input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 18, 5)        65          input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 17, 5)        80          input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 16, 5)        95          input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 15, 5)        110         input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 14, 5)        125         input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 13, 5)        140         input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 12, 5)        155         input_2[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 20, 5)        45          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 19, 5)        65          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 18, 5)        85          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 17, 5)        105         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 16, 5)        125         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 15, 5)        145         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 14, 5)        165         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 13, 5)        185         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 12, 5)        205         input_1[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 20, 5)        0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 19, 5)        0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 18, 5)        0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 17, 5)        0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 5)        0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 15, 5)        0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 14, 5)        0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 13, 5)        0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 12, 5)        0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 20, 5)        0           conv1d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 19, 5)        0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 18, 5)        0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 17, 5)        0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 5)        0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 15, 5)        0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 14, 5)        0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 13, 5)        0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 12, 5)        0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 21, 50)       4500        input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 10, 5)        0           activation_9[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_10 (MaxPooling1D) (None, 9, 5)         0           activation_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_11 (MaxPooling1D) (None, 9, 5)         0           activation_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_12 (MaxPooling1D) (None, 8, 5)         0           activation_12[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_13 (MaxPooling1D) (None, 8, 5)         0           activation_13[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_14 (MaxPooling1D) (None, 7, 5)         0           activation_14[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_15 (MaxPooling1D) (None, 7, 5)         0           activation_15[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_16 (MaxPooling1D) (None, 6, 5)         0           activation_16[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_17 (MaxPooling1D) (None, 6, 5)         0           activation_17[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 21, 50)       4650        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 10, 5)        0           activation[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 9, 5)         0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 9, 5)         0           activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 8, 5)         0           activation_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 8, 5)         0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 7, 5)         0           activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 7, 5)         0           activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 6, 5)         0           activation_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 6, 5)         0           activation_8[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 1050)         0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 50)           0           max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 45)           0           max_pooling1d_10[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 45)           0           max_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# flatten_14 (Flatten)            (None, 40)           0           max_pooling1d_12[0][0]
# __________________________________________________________________________________________________
# flatten_15 (Flatten)            (None, 40)           0           max_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# flatten_16 (Flatten)            (None, 35)           0           max_pooling1d_14[0][0]
# __________________________________________________________________________________________________
# flatten_17 (Flatten)            (None, 35)           0           max_pooling1d_15[0][0]
# __________________________________________________________________________________________________
# flatten_18 (Flatten)            (None, 30)           0           max_pooling1d_16[0][0]
# __________________________________________________________________________________________________
# flatten_19 (Flatten)            (None, 30)           0           max_pooling1d_17[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1050)         0           bidirectional[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 50)           0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 45)           0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 45)           0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 40)           0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 40)           0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 35)           0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 35)           0           max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 30)           0           max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 30)           0           max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2800)         0           flatten_10[0][0]
#                                                                  flatten_11[0][0]
#                                                                  flatten_12[0][0]
#                                                                  flatten_13[0][0]
#                                                                  flatten_14[0][0]
#                                                                  flatten_15[0][0]
#                                                                  flatten_16[0][0]
#                                                                  flatten_17[0][0]
#                                                                  flatten_18[0][0]
#                                                                  flatten_19[0][0]
#                                                                  flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
#                                                                  flatten_6[0][0]
#                                                                  flatten_7[0][0]
#                                                                  flatten_8[0][0]
#                                                                  flatten_9[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1434112     concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            1026        dropout[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            3           dense_1[0][0]
# ==================================================================================================
# Total params: 1,446,271
# Trainable params: 1,446,271
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
##################################################################################
##### For each input file, train model and generate different outputs in a structured folder
##################################################################################

## create the evaluation data structure for all iterations
evaluations = {
    "Model" : [],
    "Kernel_Length" : [],
    "Dataset" : [],
    "Fold" : [],
    "Train_Test" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

for root, dirs, files in os.walk(input_data_folder):
    for file in files:
        
        input_data_file = os.path.join(root, file)
        
        current_dataset_variety = input_data_file.split("\\")[-1].split(".")[0]

        csv_data = pd.read_csv(input_data_file)

        ##################################################################################
        ##### extract data from the current CSV file
        ##################################################################################

        csv_data["OHE_Sequence"] = pd.Series([one_hot_encode_rna(val) for val in csv_data["Sequence"]])
        csv_data["OHE_RNAfold"] = pd.Series([one_hot_encode_rnafold(val) for val in csv_data["RNAfold"]])

        df_positive = csv_data[csv_data['Number'].str.contains("P")]
        df_negative = csv_data[csv_data['Number'].str.contains("N")]

        positive_onehotencoded_List = (np.array(list(df_positive['OHE_Sequence'])), np.array(list(df_positive['OHE_RNAfold'])))
        negative_onehotencoded_List = (np.array(list(df_negative['OHE_Sequence'])), np.array(list(df_negative['OHE_RNAfold'])))

        print("\n======================================================================")
        print("\nFile:", input_data_file)
        print("Positive:", len(positive_onehotencoded_List[0]))
        print("Negative:", len(negative_onehotencoded_List[0]))

        ##################################################################################
        ##### Generate Folds from dataset, and store to file
        ##################################################################################

        ## create the features and labels datasets for the training
        input_size_1 = (len(positive_onehotencoded_List[0][0]), 4)
        input_size_2 = (len(positive_onehotencoded_List[0][0]), 3)

        labels = np.concatenate((np.ones((positive_onehotencoded_List[0].shape[0], 1), 
                                         dtype=np.float32), 
                                 np.zeros((negative_onehotencoded_List[0].shape[0], 1), 
                                          dtype=np.float32)), 
                                axis=0)
        features_1 = np.concatenate((positive_onehotencoded_List[0], 
                                     negative_onehotencoded_List[0]), 
                                    axis=0)
        features_2 = np.concatenate((positive_onehotencoded_List[1], 
                                     negative_onehotencoded_List[1]), 
                                    axis=0)

        folds = build_kfold_multifeature(features_1, features_2, labels, 
                                         k=n_fold, shuffle=shuffle, seed=seed)

        ## Write the k-fold dataset to file
        foldPath = os.path.join(outPath, expName, current_dataset_variety, "{}fold".format(n_fold))
        if(not os.path.isdir(foldPath)):
            os.makedirs(foldPath)
        pickle.dump(folds, open(os.path.join(foldPath, foldName), "wb"))

        ## Create and set directory to save model
        modelPath = os.path.join(outPath, expName, current_dataset_variety, "{}fold".format(n_fold), "models")
        if(not os.path.isdir(modelPath)):
            os.makedirs(modelPath)

        ##################################################################################
        ##### TRAIN and PREDICT for every Fold, using models
        ##################################################################################

        # fold counter
        i = 0

        for fold in folds:

            print("\nTrain/Test model "+current_dataset_variety+" on Fold #"+str(i)+".")

            kernel_length = 3
            ## Generate model using function
        #             model = Conv_LSTM_DLNN(input_shape = input_size, conv_filters_per_layer = 50, kernel_length = kernel_length, 
        #                                    lstm_decode_units = 50, max_pool_width = 2, max_pool_stride = 2, dense_decode_units = 50,
        #                                    learn_rate = 0.0001, prob = 0.5, loss='binary_crossentropy', metrics=None)

            model = DLNN_RNAFold_custom_1(input_shape_1 = input_size_1, input_shape_2 = input_size_2)

            ## Define the model callbacks for early stopping and saving the model. Then train model
        #     modelCallbacks = [
        #         tf.keras.callbacks.ModelCheckpoint(os.path.join(modelPath, "{}_bestModel-fold{}.hdf5".format(current_dataset_variety, i)),
        #                                            monitor = 'val_loss', verbose = 1, save_best_only = True, 
        #                                            save_weights_only = False, mode = 'auto', save_freq = 'epoch'),
        #         tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', min_delta = 0, patience = 10, verbose = 1, 
        #                                          mode = 'auto', baseline = None, restore_best_weights = False)
        #     ]
        #     model.fit(x = fold["X_train"], y = fold["y_train"], batch_size = batch_size, epochs = epochs, verbose = 1, 
        #               callbacks = modelCallbacks, validation_split=0.2)

            model.fit(x = [fold["X1_train"], fold["X2_train"]], y = fold["y_train"], batch_size = batch_size, epochs = epochs, verbose = 1, 
                      validation_split=0.2)

            ##################################################################################
            ##### Prediction and metrics for TRAIN dataset
            ##################################################################################

            y_pred = model.predict([fold["X1_train"], fold["X2_train"]])
            label_pred = pred2label(y_pred)
            # Compute precision, recall, sensitivity, specifity, mcc
            acc = accuracy_score(fold["y_train"], label_pred)
            prec = precision_score(fold["y_train"],label_pred)

            conf = confusion_matrix(fold["y_train"], label_pred)
            if(conf[0][0]+conf[1][0]):
                sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
            else:
                sens = 0.0
            if(conf[1][1]+conf[0][1]):
                spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
            else:
                spec = 0.0
            if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
                mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
            else:
                mcc= 0.0
            fpr, tpr, thresholds = roc_curve(fold["y_train"], y_pred)
            auc = roc_auc_score(fold["y_train"], y_pred)

            evaluations["Model"].append(current_dataset_variety)
            evaluations["Kernel_Length"].append(kernel_length)
            evaluations["Dataset"].append(current_dataset_variety)
            evaluations["Fold"].append(i)
            evaluations["Train_Test"].append("Train")
            evaluations["Accuracy"].append(acc)
            evaluations["Precision"].append(prec)
            evaluations["TPR"].append(tpr)
            evaluations["FPR"].append(fpr)
            evaluations["TPR_FPR_Thresholds"].append(thresholds)
            evaluations["AUC"].append(auc)
            evaluations["Sensitivity"].append(sens)
            evaluations["Specificity"].append(spec)
            evaluations["MCC"].append(mcc)

            ##################################################################################
            ##### Prediction and metrics for TEST dataset
            ##################################################################################

            y_pred = model.predict([fold["X1_test"], fold["X2_test"]])
            label_pred = pred2label(y_pred)
            # Compute precision, recall, sensitivity, specifity, mcc
            acc = accuracy_score(fold["y_test"], label_pred)
            prec = precision_score(fold["y_test"],label_pred)

            conf = confusion_matrix(fold["y_test"], label_pred)
            if(conf[0][0]+conf[1][0]):
                sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
            else:
                sens = 0.0
            if(conf[1][1]+conf[0][1]):
                spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
            else:
                spec = 0.0
            if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
                mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
            else:
                mcc= 0.0
            fpr, tpr, thresholds = roc_curve(fold["y_test"], y_pred)
            auc = roc_auc_score(fold["y_test"], y_pred)

            evaluations["Model"].append(current_dataset_variety)
            evaluations["Kernel_Length"].append(kernel_length)
            evaluations["Dataset"].append(current_dataset_variety)
            evaluations["Fold"].append(i)
            evaluations["Train_Test"].append("Test")
            evaluations["Accuracy"].append(acc)
            evaluations["Precision"].append(prec)
            evaluations["TPR"].append(tpr)
            evaluations["FPR"].append(fpr)
            evaluations["TPR_FPR_Thresholds"].append(thresholds)
            evaluations["AUC"].append(auc)
            evaluations["Sensitivity"].append(sens)
            evaluations["Specificity"].append(spec)
            evaluations["MCC"].append(mcc)

            i = i+1
            del model
            tf.keras.backend.clear_session()

        ##################################################################################
        ##### Dump evaluations to a file
        ##################################################################################

        evalPath = os.path.join(outPath, expName, "_Evaluation_All_Datasets")
        if(not os.path.isdir(evalPath)):
            os.makedirs(evalPath)

        pickle.dump(evaluations,
                    open(os.path.join(evalPath, "{}fold_evaluations.pickle".format(n_fold)), "wb"))
# Out:
# ======================================================================
#
# File: Data\Aziz\HS_990.csv
# Positive: 495
# Negative: 495
#
# Train/Test model HS_990 on Fold #0.
# Epoch 1/100
# 45/45 [==============================] - 3s 57ms/step - loss: 0.6667 - val_loss: 0.7529
# Epoch 2/100
# 45/45 [==============================] - 1s 22ms/step - loss: 0.6642 - val_loss: 1.1365
# Epoch 3/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6542 - val_loss: 0.8523
# Epoch 4/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6421 - val_loss: 1.0498
# Epoch 5/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6340 - val_loss: 1.0417
# Epoch 6/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6121 - val_loss: 1.1689
# Epoch 7/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.5953 - val_loss: 0.8965
# Epoch 8/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.5874 - val_loss: 0.9481
# Epoch 9/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.5713 - val_loss: 1.1036
# Epoch 10/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.5661 - val_loss: 1.1007
# Epoch 11/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.5611 - val_loss: 1.1054
# Epoch 12/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.5484 - val_loss: 0.9985
# Epoch 13/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.5262 - val_loss: 1.1131
# Epoch 14/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.5239 - val_loss: 1.1044
# Epoch 15/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.5074 - val_loss: 1.1390
# Epoch 16/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.4885 - val_loss: 1.2578
# Epoch 17/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.4670 - val_loss: 1.1186
# Epoch 18/100
# 45/45 [==============================] - 1s 22ms/step - loss: 0.4419 - val_loss: 1.0268
# Epoch 19/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.4203 - val_loss: 1.1400
# Epoch 20/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.4021 - val_loss: 1.0815
# Epoch 21/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.3958 - val_loss: 1.1329
# Epoch 22/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.3803 - val_loss: 1.1231
# Epoch 23/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.3665 - val_loss: 1.2252
# Epoch 24/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.3625 - val_loss: 1.1478
# Epoch 25/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.3382 - val_loss: 1.2221
# Epoch 26/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.3341 - val_loss: 1.2851
# Epoch 27/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.3290 - val_loss: 1.1362
# Epoch 28/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.3130 - val_loss: 1.3281
# Epoch 29/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.3050 - val_loss: 1.2721
# Epoch 30/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.2967 - val_loss: 1.3318
# Epoch 31/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.2905 - val_loss: 1.2010
# Epoch 32/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.2801 - val_loss: 1.2888
# Epoch 33/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.2678 - val_loss: 1.2935
# Epoch 34/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.2666 - val_loss: 1.4472
# Epoch 35/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.2691 - val_loss: 1.0523
# Epoch 36/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.2471 - val_loss: 1.5191
# Epoch 37/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.2441 - val_loss: 1.1893
# Epoch 38/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.2440 - val_loss: 1.3324
# Epoch 39/100
# 45/45 [==============================] - 1s 22ms/step - loss: 0.2260 - val_loss: 1.1554
# Epoch 40/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.2217 - val_loss: 1.2405
# Epoch 41/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.2203 - val_loss: 1.2503
# Epoch 42/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.2191 - val_loss: 1.3393
# Epoch 43/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.2131 - val_loss: 1.3979
# Epoch 44/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.1961 - val_loss: 1.4121
# Epoch 45/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1975 - val_loss: 1.4270
# Epoch 46/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1895 - val_loss: 1.3968
# Epoch 47/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1874 - val_loss: 1.5520
# Epoch 48/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1799 - val_loss: 1.5478
# Epoch 49/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1835 - val_loss: 1.2878
# Epoch 50/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1768 - val_loss: 1.7659
# Epoch 51/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1824 - val_loss: 1.3552
# Epoch 52/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1761 - val_loss: 1.4928
# Epoch 53/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1657 - val_loss: 1.4368
# Epoch 54/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.1632 - val_loss: 1.6351
# Epoch 55/100
# 45/45 [==============================] - 1s 22ms/step - loss: 0.1600 - val_loss: 1.5929
# Epoch 56/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.1570 - val_loss: 1.5901
# Epoch 57/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1588 - val_loss: 1.4388
# Epoch 58/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1667 - val_loss: 1.6367
# Epoch 59/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1622 - val_loss: 1.7091
# Epoch 60/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1596 - val_loss: 1.4008
# Epoch 61/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.1571 - val_loss: 1.7338
# Epoch 62/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1679 - val_loss: 1.8159
# Epoch 63/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1657 - val_loss: 1.6329
# Epoch 64/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1549 - val_loss: 1.4804
# Epoch 65/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1461 - val_loss: 1.7129
# Epoch 66/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.1465 - val_loss: 1.7636
# Epoch 67/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1417 - val_loss: 1.7633
# Epoch 68/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1421 - val_loss: 1.8057
# Epoch 69/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1370 - val_loss: 1.6407
# Epoch 70/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1381 - val_loss: 1.8038
# Epoch 71/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1470 - val_loss: 1.7155
# Epoch 72/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1455 - val_loss: 1.7100
# Epoch 73/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1388 - val_loss: 1.8065
# Epoch 74/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1459 - val_loss: 1.6705
# Epoch 75/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1428 - val_loss: 1.6667
# Epoch 76/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1322 - val_loss: 2.0831
# Epoch 77/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1426 - val_loss: 2.0341
# Epoch 78/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1395 - val_loss: 1.7812
# Epoch 79/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1295 - val_loss: 1.8074
# Epoch 80/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1369 - val_loss: 2.0023
# Epoch 81/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.1256 - val_loss: 1.6428
# Epoch 82/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1233 - val_loss: 1.7820
# Epoch 83/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1301 - val_loss: 1.6861
# Epoch 84/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1256 - val_loss: 1.6639
# Epoch 85/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1251 - val_loss: 1.7344
# Epoch 86/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1275 - val_loss: 1.7576
# Epoch 87/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1198 - val_loss: 1.8302
# Epoch 88/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1183 - val_loss: 1.9563
# Epoch 89/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1164 - val_loss: 2.0582
# Epoch 90/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1152 - val_loss: 1.7400
# Epoch 91/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.1222 - val_loss: 1.8899
# Epoch 92/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.1303 - val_loss: 1.9425
# Epoch 93/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1318 - val_loss: 2.0223
# Epoch 94/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1382 - val_loss: 1.8468
# Epoch 95/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.1256 - val_loss: 2.1311
# Epoch 96/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1146 - val_loss: 2.0869
# Epoch 97/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1121 - val_loss: 1.7479
# Epoch 98/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1101 - val_loss: 1.9320
# Epoch 99/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.1112 - val_loss: 2.1027
# Epoch 100/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.1110 - val_loss: 1.9093
#
# Train/Test model HS_990 on Fold #1.
# Epoch 1/100
# 45/45 [==============================] - 2s 46ms/step - loss: 0.7383 - val_loss: 1.5572
# Epoch 2/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.7271 - val_loss: 1.5049
# Epoch 3/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.7170 - val_loss: 1.4553
# Epoch 4/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.7078 - val_loss: 1.4101
# Epoch 5/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.7000 - val_loss: 1.3662
# Epoch 6/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6931 - val_loss: 1.3274
# Epoch 7/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6873 - val_loss: 1.2858
# Epoch 8/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6824 - val_loss: 1.2550
# Epoch 9/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6785 - val_loss: 1.2204
# Epoch 10/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6748 - val_loss: 1.1965
# Epoch 11/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6723 - val_loss: 1.1676
# Epoch 12/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6698 - val_loss: 1.1485
# Epoch 13/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6680 - val_loss: 1.1265
# Epoch 14/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6666 - val_loss: 1.1041
# Epoch 15/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6653 - val_loss: 1.0899
# Epoch 16/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6644 - val_loss: 1.0757
# Epoch 17/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6638 - val_loss: 1.0618
# Epoch 18/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6632 - val_loss: 1.0515
# Epoch 19/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6629 - val_loss: 1.0413
# Epoch 20/100
# 45/45 [==============================] - 1s 22ms/step - loss: 0.6626 - val_loss: 1.0327
# Epoch 21/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6623 - val_loss: 1.0278
# Epoch 22/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6622 - val_loss: 1.0187
# Epoch 23/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6620 - val_loss: 1.0146
# Epoch 24/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6619 - val_loss: 1.0129
# Epoch 25/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6619 - val_loss: 1.0075
# Epoch 26/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6618 - val_loss: 1.0048
# Epoch 27/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9985
# Epoch 28/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9929
# Epoch 29/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9923
# Epoch 30/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9920
# Epoch 31/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9897
# Epoch 32/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9918
# Epoch 33/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9891
# Epoch 34/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9846
# Epoch 35/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9871
# Epoch 36/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9864
# Epoch 37/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9836
# Epoch 38/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9843
# Epoch 39/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9824
# Epoch 40/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9837
# Epoch 41/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9860
# Epoch 42/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9875
# Epoch 43/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9839
# Epoch 44/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9826
# Epoch 45/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9830
# Epoch 46/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9805
# Epoch 47/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9848
# Epoch 48/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9818
# Epoch 49/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9835
# Epoch 50/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9865
# Epoch 51/100
# 45/45 [==============================] - 1s 22ms/step - loss: 0.6616 - val_loss: 0.9826
# Epoch 52/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9798
# Epoch 53/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9812
# Epoch 54/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9810
# Epoch 55/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9825
# Epoch 56/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9821
# Epoch 57/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9811
# Epoch 58/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9832
# Epoch 59/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9848
# Epoch 60/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9830
# Epoch 61/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9820
# Epoch 62/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9811
# Epoch 63/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9830
# Epoch 64/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9814
# Epoch 65/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9797
# Epoch 66/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9809
# Epoch 67/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9798
# Epoch 68/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9790
# Epoch 69/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9790
# Epoch 70/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9802
# Epoch 71/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9785
# Epoch 72/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9792
# Epoch 73/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9825
# Epoch 74/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9798
# Epoch 75/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9815
# Epoch 76/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9776
# Epoch 77/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9790
# Epoch 78/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9781
# Epoch 79/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9800
# Epoch 80/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9833
# Epoch 81/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9782
# Epoch 82/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9799
# Epoch 83/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9794
# Epoch 84/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9781
# Epoch 85/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9744
# Epoch 86/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9771
# Epoch 87/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9785
# Epoch 88/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9771
# Epoch 89/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9795
# Epoch 90/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9778
# Epoch 91/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9821
# Epoch 92/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6618 - val_loss: 0.9779
# Epoch 93/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9803
# Epoch 94/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9804
# Epoch 95/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9808
# Epoch 96/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9832
# Epoch 97/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9858
# Epoch 98/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9800
# Epoch 99/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9830
# Epoch 100/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9824
#
# Train/Test model HS_990 on Fold #2.
# Epoch 1/100
# 45/45 [==============================] - 2s 45ms/step - loss: 0.6847 - val_loss: 1.2556
# Epoch 2/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6782 - val_loss: 1.2191
# Epoch 3/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6744 - val_loss: 1.1805
# Epoch 4/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6710 - val_loss: 1.1553
# Epoch 5/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6687 - val_loss: 1.1307
# Epoch 6/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6669 - val_loss: 1.1111
# Epoch 7/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6656 - val_loss: 1.0902
# Epoch 8/100
# 45/45 [==============================] - 1s 22ms/step - loss: 0.6645 - val_loss: 1.0754
# Epoch 9/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6637 - val_loss: 1.0605
# Epoch 10/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6630 - val_loss: 1.0453
# Epoch 11/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6633 - val_loss: 1.0365
# Epoch 12/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6623 - val_loss: 1.0260
# Epoch 13/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6621 - val_loss: 1.0155
# Epoch 14/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6620 - val_loss: 1.0128
# Epoch 15/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6619 - val_loss: 1.0054
# Epoch 16/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6618 - val_loss: 1.0015
# Epoch 17/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6618 - val_loss: 0.9971
# Epoch 18/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9998
# Epoch 19/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9958
# Epoch 20/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9936
# Epoch 21/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9910
# Epoch 22/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6619 - val_loss: 0.9805
# Epoch 23/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9872
# Epoch 24/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9839
# Epoch 25/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9827
# Epoch 26/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9854
# Epoch 27/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9834
# Epoch 28/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9799
# Epoch 29/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9799
# Epoch 30/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9832
# Epoch 31/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9817
# Epoch 32/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9867
# Epoch 33/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9819
# Epoch 34/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9815
# Epoch 35/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9790
# Epoch 36/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9840
# Epoch 37/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9838
# Epoch 38/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9798
# Epoch 39/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9833
# Epoch 40/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9819
# Epoch 41/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9812
# Epoch 42/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9810
# Epoch 43/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9795
# Epoch 44/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9798
# Epoch 45/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9747
# Epoch 46/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9759
# Epoch 47/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9785
# Epoch 48/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9752
# Epoch 49/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9798
# Epoch 50/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9768
# Epoch 51/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9781
# Epoch 52/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9784
# Epoch 53/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9807
# Epoch 54/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9785
# Epoch 55/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9815
# Epoch 56/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9812
# Epoch 57/100
# 45/45 [==============================] - 1s 22ms/step - loss: 0.6618 - val_loss: 0.9859
# Epoch 58/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9837
# Epoch 59/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9811
# Epoch 60/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9804
# Epoch 61/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9856
# Epoch 62/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6619 - val_loss: 0.9802
# Epoch 63/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9816
# Epoch 64/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9772
# Epoch 65/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9834
# Epoch 66/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9846
# Epoch 67/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9817
# Epoch 68/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9811
# Epoch 69/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9829
# Epoch 70/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9821
# Epoch 71/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9816
# Epoch 72/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9789
# Epoch 73/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9799
# Epoch 74/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9813
# Epoch 75/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9796
# Epoch 76/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6618 - val_loss: 0.9826
# Epoch 77/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6618 - val_loss: 0.9873
# Epoch 78/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9796
# Epoch 79/100
# 45/45 [==============================] - 1s 22ms/step - loss: 0.6616 - val_loss: 0.9794
# Epoch 80/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9820
# Epoch 81/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9817
# Epoch 82/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9816
# Epoch 83/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9830
# Epoch 84/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9840
# Epoch 85/100
# 45/45 [==============================] - 1s 22ms/step - loss: 0.6616 - val_loss: 0.9821
# Epoch 86/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9833
# Epoch 87/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6619 - val_loss: 0.9789
# Epoch 88/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9804
# Epoch 89/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9811
# Epoch 90/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9833
# Epoch 91/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9823
# Epoch 92/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9796
# Epoch 93/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9800
# Epoch 94/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9828
# Epoch 95/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9844
# Epoch 96/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9849
# Epoch 97/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9830
# Epoch 98/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9818
# Epoch 99/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9782
# Epoch 100/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9780
#
# Train/Test model HS_990 on Fold #3.
# Epoch 1/100
# 45/45 [==============================] - 2s 44ms/step - loss: 0.6770 - val_loss: 0.8126
# Epoch 2/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6698 - val_loss: 0.8380
# Epoch 3/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6674 - val_loss: 0.8592
# Epoch 4/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6658 - val_loss: 0.8790
# Epoch 5/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6646 - val_loss: 0.8932
# Epoch 6/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6637 - val_loss: 0.9070
# Epoch 7/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6631 - val_loss: 0.9193
# Epoch 8/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6627 - val_loss: 0.9273
# Epoch 9/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6624 - val_loss: 0.9335
# Epoch 10/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6622 - val_loss: 0.9420
# Epoch 11/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6620 - val_loss: 0.9480
# Epoch 12/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6620 - val_loss: 0.9577
# Epoch 13/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6618 - val_loss: 0.9597
# Epoch 14/100
# 45/45 [==============================] - 1s 23ms/step - loss: 0.6618 - val_loss: 0.9597
# Epoch 15/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9673
# Epoch 16/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9679
# Epoch 17/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9692
# Epoch 18/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6618 - val_loss: 0.9724
# Epoch 19/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9731
# Epoch 20/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9742
# Epoch 21/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9749
# Epoch 22/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9771
# Epoch 23/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9766
# Epoch 24/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9812
# Epoch 25/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9777
# Epoch 26/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9798
# Epoch 27/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9818
# Epoch 28/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9835
# Epoch 29/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9836
# Epoch 30/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9824
# Epoch 31/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9786
# Epoch 32/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9806
# Epoch 33/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9805
# Epoch 34/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9788
# Epoch 35/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9805
# Epoch 36/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9826
# Epoch 37/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9841
# Epoch 38/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9770
# Epoch 39/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9813
# Epoch 40/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6619 - val_loss: 0.9787
# Epoch 41/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9797
# Epoch 42/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9805
# Epoch 43/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9787
# Epoch 44/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9807
# Epoch 45/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9803
# Epoch 46/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9790
# Epoch 47/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6618 - val_loss: 0.9866
# Epoch 48/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9814
# Epoch 49/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9779
# Epoch 50/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9830
# Epoch 51/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9793
# Epoch 52/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6621 - val_loss: 0.9846
# Epoch 53/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9754
# Epoch 54/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9792
# Epoch 55/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9774
# Epoch 56/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9798
# Epoch 57/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9727
# Epoch 58/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9789
# Epoch 59/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9805
# Epoch 60/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9779
# Epoch 61/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9803
# Epoch 62/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9795
# Epoch 63/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9790
# Epoch 64/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9811
# Epoch 65/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9802
# Epoch 66/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9781
# Epoch 67/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9795
# Epoch 68/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9816
# Epoch 69/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9848
# Epoch 70/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9804
# Epoch 71/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6618 - val_loss: 0.9873
# Epoch 72/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9778
# Epoch 73/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9812
# Epoch 74/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6618 - val_loss: 0.9808
# Epoch 75/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9769
# Epoch 76/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9757
# Epoch 77/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9775
# Epoch 78/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9758
# Epoch 79/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9796
# Epoch 80/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9750
# Epoch 81/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9789
# Epoch 82/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9790
# Epoch 83/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9830
# Epoch 84/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9771
# Epoch 85/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9767
# Epoch 86/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9779
# Epoch 87/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9743
# Epoch 88/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9807
# Epoch 89/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9804
# Epoch 90/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9763
# Epoch 91/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9771
# Epoch 92/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9796
# Epoch 93/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9825
# Epoch 94/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9814
# Epoch 95/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9825
# Epoch 96/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9823
# Epoch 97/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9819
# Epoch 98/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9790
# Epoch 99/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9807
# Epoch 100/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9778
#
# Train/Test model HS_990 on Fold #4.
# Epoch 1/100
# 45/45 [==============================] - 2s 45ms/step - loss: 0.6635 - val_loss: 1.0308
# Epoch 2/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6623 - val_loss: 1.0271
# Epoch 3/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6621 - val_loss: 1.0144
# Epoch 4/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6619 - val_loss: 1.0090
# Epoch 5/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6618 - val_loss: 1.0026
# Epoch 6/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6618 - val_loss: 1.0023
# Epoch 7/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9994
# Epoch 8/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9936
# Epoch 9/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9919
# Epoch 10/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9920
# Epoch 11/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9913
# Epoch 12/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9838
# Epoch 13/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9883
# Epoch 14/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9855
# Epoch 15/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9843
# Epoch 16/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9847
# Epoch 17/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9871
# Epoch 18/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9826
# Epoch 19/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9824
# Epoch 20/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9834
# Epoch 21/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9856
# Epoch 22/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9805
# Epoch 23/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9828
# Epoch 24/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9783
# Epoch 25/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9822
# Epoch 26/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6618 - val_loss: 0.9816
# Epoch 27/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9777
# Epoch 28/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9807
# Epoch 29/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9772
# Epoch 30/100
# 45/45 [==============================] - 1s 22ms/step - loss: 0.6617 - val_loss: 0.9760
# Epoch 31/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9800
# Epoch 32/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9854
# Epoch 33/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9815
# Epoch 34/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9797
# Epoch 35/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9823
# Epoch 36/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6616 - val_loss: 0.9810
# Epoch 37/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9820
# Epoch 38/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9817
# Epoch 39/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9801
# Epoch 40/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9834
# Epoch 41/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9828
# Epoch 42/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9806
# Epoch 43/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9812
# Epoch 44/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9826
# Epoch 45/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9807
# Epoch 46/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9828
# Epoch 47/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9822
# Epoch 48/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9821
# Epoch 49/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9799
# Epoch 50/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9855
# Epoch 51/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9813
# Epoch 52/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9839
# Epoch 53/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9855
# Epoch 54/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9862
# Epoch 55/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9828
# Epoch 56/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9849
# Epoch 57/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9821
# Epoch 58/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9831
# Epoch 59/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9866
# Epoch 60/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9809
# Epoch 61/100
# 45/45 [==============================] - ETA: 0s - loss: 0.661 - 1s 19ms/step - loss: 0.6617 - val_loss: 0.9823
# Epoch 62/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6616 - val_loss: 0.9820
# Epoch 63/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6617 - val_loss: 0.9816
# Epoch 64/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9809
# Epoch 65/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9778
# Epoch 66/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6616 - val_loss: 0.9784
# Epoch 67/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6617 - val_loss: 0.9799
# Epoch 68/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9778
# Epoch 69/100
# 45/45 [==============================] - 1s 20ms/step - loss: 0.6617 - val_loss: 0.9750
# Epoch 70/100
# 45/45 [==============================] - 1s 22ms/step - loss: 0.6617 - val_loss: 0.9770
# Epoch 71/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6616 - val_loss: 0.9787
# Epoch 72/100
# 45/45 [==============================] - 1s 21ms/step - loss: 0.6618 - val_loss: 0.9861
# Epoch 73/100
# ...
# Epoch 43/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6617 - val_loss: 0.9383
# Epoch 44/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6616 - val_loss: 0.9419
# Epoch 45/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6616 - val_loss: 0.9429
# Epoch 46/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.6615 - val_loss: 0.9455
# Epoch 47/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6615 - val_loss: 0.9488
# Epoch 48/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6613 - val_loss: 0.9518
# Epoch 49/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6613 - val_loss: 0.9575
# Epoch 50/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6612 - val_loss: 0.9592
# Epoch 51/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6613 - val_loss: 0.9619
# Epoch 52/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6612 - val_loss: 0.9616
# Epoch 53/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.6612 - val_loss: 0.9608
# Epoch 54/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6612 - val_loss: 0.9607
# Epoch 55/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.6611 - val_loss: 0.9632
# Epoch 56/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.6612 - val_loss: 0.9678
# Epoch 57/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9685
# Epoch 58/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9699
# Epoch 59/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9724
# Epoch 60/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9719
# Epoch 61/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6611 - val_loss: 0.9723
# Epoch 62/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9729
# Epoch 63/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9733
# Epoch 64/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9725
# Epoch 65/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6611 - val_loss: 0.9761
# Epoch 66/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9732
# Epoch 67/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9767
# Epoch 68/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9766
# Epoch 69/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9752
# Epoch 70/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9744
# Epoch 71/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9767
# Epoch 72/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9816
# Epoch 73/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6610 - val_loss: 0.9810
# Epoch 74/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.6610 - val_loss: 0.9799
# Epoch 75/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6610 - val_loss: 0.9799
# Epoch 76/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9827
# Epoch 77/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9823
# Epoch 78/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6611 - val_loss: 0.9815
# Epoch 79/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9876
# Epoch 80/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6611 - val_loss: 0.9891
# Epoch 81/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6610 - val_loss: 0.9840
# Epoch 82/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6611 - val_loss: 0.9820
# Epoch 83/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6611 - val_loss: 0.9838
# Epoch 84/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9812
# Epoch 85/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9789
# Epoch 86/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6612 - val_loss: 0.9851
# Epoch 87/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9792
# Epoch 88/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9832
# Epoch 89/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6613 - val_loss: 0.9780
# Epoch 90/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9801
# Epoch 91/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9820
# Epoch 92/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6612 - val_loss: 0.9853
# Epoch 93/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6610 - val_loss: 0.9835
# Epoch 94/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9810
# Epoch 95/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9808
# Epoch 96/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6610 - val_loss: 0.9819
# Epoch 97/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9791
# Epoch 98/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6610 - val_loss: 0.9844
# Epoch 99/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6610 - val_loss: 0.9840
# Epoch 100/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9827
#
# Train/Test model SN_628 on Fold #9.
# Epoch 1/100
# 29/29 [==============================] - 2s 70ms/step - loss: 0.6796 - val_loss: 1.2119
# Epoch 2/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6734 - val_loss: 1.1927
# Epoch 3/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6714 - val_loss: 1.1711
# Epoch 4/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6695 - val_loss: 1.1562
# Epoch 5/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6682 - val_loss: 1.1400
# Epoch 6/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6670 - val_loss: 1.1256
# Epoch 7/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6660 - val_loss: 1.1079
# Epoch 8/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6649 - val_loss: 1.0968
# Epoch 9/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6643 - val_loss: 1.0856
# Epoch 10/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6636 - val_loss: 1.0756
# Epoch 11/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6632 - val_loss: 1.0663
# Epoch 12/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6628 - val_loss: 1.0565
# Epoch 13/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6625 - val_loss: 1.0502
# Epoch 14/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6622 - val_loss: 1.0472
# Epoch 15/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6620 - val_loss: 1.0379
# Epoch 16/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6618 - val_loss: 1.0314
# Epoch 17/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6617 - val_loss: 1.0213
# Epoch 18/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6615 - val_loss: 1.0233
# Epoch 19/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6615 - val_loss: 1.0198
# Epoch 20/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6614 - val_loss: 1.0162
# Epoch 21/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6613 - val_loss: 1.0128
# Epoch 22/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6612 - val_loss: 1.0074
# Epoch 23/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6612 - val_loss: 1.0053
# Epoch 24/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6612 - val_loss: 1.0056
# Epoch 25/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6612 - val_loss: 1.0054
# Epoch 26/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6612 - val_loss: 1.0057
# Epoch 27/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6612 - val_loss: 1.0009
# Epoch 28/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6612 - val_loss: 0.9996
# Epoch 29/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9981
# Epoch 30/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6611 - val_loss: 0.9965
# Epoch 31/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6611 - val_loss: 0.9942
# Epoch 32/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6611 - val_loss: 0.9945
# Epoch 33/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6611 - val_loss: 0.9946
# Epoch 34/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9927
# Epoch 35/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9940
# Epoch 36/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6612 - val_loss: 0.9910
# Epoch 37/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9868
# Epoch 38/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6611 - val_loss: 0.9857
# Epoch 39/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6612 - val_loss: 0.9897
# Epoch 40/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9889
# Epoch 41/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9911
# Epoch 42/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6610 - val_loss: 0.9895
# Epoch 43/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9898
# Epoch 44/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6610 - val_loss: 0.9899
# Epoch 45/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6610 - val_loss: 0.9883
# Epoch 46/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6610 - val_loss: 0.9884
# Epoch 47/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9899
# Epoch 48/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6610 - val_loss: 0.9878
# Epoch 49/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9878
# Epoch 50/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9829
# Epoch 51/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9821
# Epoch 52/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9824
# Epoch 53/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9808
# Epoch 54/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9804
# Epoch 55/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6612 - val_loss: 0.9822
# Epoch 56/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9776
# Epoch 57/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9781
# Epoch 58/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6611 - val_loss: 0.9744
# Epoch 59/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9788
# Epoch 60/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9779
# Epoch 61/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9820
# Epoch 62/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9811
# Epoch 63/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9810
# Epoch 64/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9852
# Epoch 65/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6610 - val_loss: 0.9869
# Epoch 66/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6610 - val_loss: 0.9869
# Epoch 67/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6610 - val_loss: 0.9871
# Epoch 68/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6612 - val_loss: 0.9851
# Epoch 69/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6611 - val_loss: 0.9869
# Epoch 70/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.6611 - val_loss: 0.9903
# Epoch 71/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9908
# Epoch 72/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9916
# Epoch 73/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9887
# Epoch 74/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6610 - val_loss: 0.9849
# Epoch 75/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.6611 - val_loss: 0.9807
# Epoch 76/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9793
# Epoch 77/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6610 - val_loss: 0.9823
# Epoch 78/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6611 - val_loss: 0.9838
# Epoch 79/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9761
# Epoch 80/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6611 - val_loss: 0.9742
# Epoch 81/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9766
# Epoch 82/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.6610 - val_loss: 0.9764
# Epoch 83/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9771
# Epoch 84/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6611 - val_loss: 0.9812
# Epoch 85/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9831
# Epoch 86/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6611 - val_loss: 0.9846
# Epoch 87/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9840
# Epoch 88/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6610 - val_loss: 0.9852
# Epoch 89/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6612 - val_loss: 0.9796
# Epoch 90/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6611 - val_loss: 0.9873
# Epoch 91/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6611 - val_loss: 0.9868
# Epoch 92/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9889
# Epoch 93/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9888
# Epoch 94/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6610 - val_loss: 0.9909
# Epoch 95/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6610 - val_loss: 0.9906
# Epoch 96/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6611 - val_loss: 0.9913
# Epoch 97/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9877
# Epoch 98/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6610 - val_loss: 0.9866
# Epoch 99/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9868
# Epoch 100/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6611 - val_loss: 0.9853

# %% [markdown]
# ## Visualization of Evaluation

# %%
##################################################################################
##### Add import statement here, to make this next part of code standalone executable
##################################################################################

import os
import pickle
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter
import numpy as np
import pandas as pd

# %%
##################################################################################
##### Load file and convert to dataframe for easy manipulation
##################################################################################

evalPath = os.path.join(outPath, expName, "_Evaluation_All_Datasets")
if(not os.path.isdir(evalPath)):
    os.makedirs(evalPath)

evaluations = pickle.load(open(os.path.join(evalPath, "{}fold_evaluations.pickle".format(n_fold)), "rb"))

# %%
# evaluations["Model"] = evaluations["Model"][0:20]
# evaluations_df = pd.DataFrame.from_dict(evaluations)

# %%
evaluations_df = pd.DataFrame.from_dict(evaluations)

##################################################################################
##### Group dataset (mean of metrics) by [Dataset, Model, Train_Test] combinations
##################################################################################

evaluations_df_grouped = evaluations_df.groupby(["Dataset", 
                                                 "Model", 
                                                 "Train_Test"]).mean().filter(['Accuracy', 
                                                                               'Precision', 
                                                                               'AUC', 
                                                                               'Sensitivity', 
                                                                               'Specificity', 
                                                                               'MCC'])

# DLNN_3 = evaluations_df_grouped[np.in1d(evaluations_df_grouped.index.get_level_values(1), ['DLNN_3'])]
# DLNN_5 = evaluations_df_grouped[np.in1d(evaluations_df_grouped.index.get_level_values(1), ['DLNN_5'])]

# DLNN_3_Train = DLNN_3[np.in1d(DLNN_3.index.get_level_values(2), ['Train'])]
# DLNN_3_Test = DLNN_3[np.in1d(DLNN_3.index.get_level_values(2), ['Test'])]

# DLNN_5_Train = DLNN_5[np.in1d(DLNN_5.index.get_level_values(2), ['Train'])]
# DLNN_5_Test = DLNN_5[np.in1d(DLNN_5.index.get_level_values(2), ['Test'])]

# %%
evaluations_df_grouped
# Out:
#                            Accuracy  Precision       AUC  Sensitivity  \
# Dataset Model  Train_Test
# HS_990  HS_990 Test        0.508081   0.506418  0.509327     0.061765
#                Train       0.536700   0.529910  0.541533     0.097391
# MM_944  MM_944 Test        0.519071   0.513574  0.529894     0.130976
#                Train       0.570985   0.556097  0.581154     0.197080
# SN_628  SN_628 Test        0.500000   0.500000  0.500000     0.000000
#                Train       0.500000   0.500000  0.500000     0.000000
#
#                            Specificity       MCC
# Dataset Model  Train_Test
# HS_990  HS_990 Test           0.506418  0.017749
#                Train          0.529910  0.075254
# MM_944  MM_944 Test           0.513574  0.040571
#                Train          0.556097  0.147535
# SN_628  SN_628 Test           0.500000  0.000000
#                Train          0.500000  0.000000

# %%
# ##################################################################################
# ##### Decide on metric to visualize
# ##################################################################################

# print("Metrics Available : ")
# print(list(evaluations_df_grouped.columns))

# %% [markdown]
# #### Select a metric to plot below:

# %%
# metric_to_plot = "Accuracy"

# %%
# ##################################################################################
# ##### Visualize with a multiple Bar chart
# ##################################################################################

# x = np.arange(len(DLNN_3_Train[metric_to_plot]))
# width = 0.15

# fig, ax = plt.subplots(figsize=(17,6))
# rects1 = ax.bar(x - (4*(width/2)), round(DLNN_3_Train[metric_to_plot]*100, 3), width, label='DLNN_3, Train')
# rects2 = ax.bar(x - (1.5*(width/2)), round(DLNN_5_Train[metric_to_plot]*100, 3), width, label='DLNN_5, Train')
# rects3 = ax.bar(x + (1.5*(width/2)), round(DLNN_3_Test[metric_to_plot]*100, 3), width, label='DLNN_3, Test')
# rects4 = ax.bar(x + (4*(width/2)), round(DLNN_5_Test[metric_to_plot]*100, 3), width, label='DLNN_5, Test')

# ## Custom y-axis tick labels
# ax.set_ylabel(metric_to_plot)
# ax.set_ylim([(math.floor(min(evaluations_df_grouped[metric_to_plot])*10)-1)*10, 
#             (math.ceil(max(evaluations_df_grouped[metric_to_plot])*10)+1)*10])
# # ax.set_ylim([80, 105])

# ## Custom x-axis tick labels
# ax.set_xticks(x)
# # ax.set_xticklabels(DLNN_3_Train.index.get_level_values(0))
# # ax.set_xticklabels([m+" - "+str(n) for m,n in 
# #                         zip(DLNN_3_Train.index.get_level_values(0),DLNN_3_Train.index.get_level_values(1))],
# #                   rotation=30)
# ax.set_xticklabels(DLNN_3_Train.index.get_level_values(0))

# ax.set_title(metric_to_plot+' by Dataset, Model, Train/Test')
# ax.legend(loc='upper left')

# def autolabel(rects):
#     for rect in rects:
#         height = rect.get_height()
#         ax.annotate('{}'.format(height),
#                     xy=(rect.get_x() + rect.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points", 
#                     ha='center', va='bottom', rotation=90)

# autolabel(rects1)
# autolabel(rects2)
# autolabel(rects3)
# autolabel(rects4)

# plt.show()

# %% [markdown]
# ### Store all metrics' plots to file

# %%
# ##################################################################################
# ##### Iteratively generate comparison plot using every metric
# ##################################################################################

# for metric_to_plot in list(evaluations_df_grouped.columns):
    
#     x = np.arange(len(DLNN_3_Train[metric_to_plot]))
#     width = 0.15

#     fig, ax = plt.subplots(figsize=(17,6))
#     rects1 = ax.bar(x - (4*(width/2)), round(DLNN_3_Train[metric_to_plot]*100, 3), width, label='DLNN_3, Train')
#     rects2 = ax.bar(x - (1.5*(width/2)), round(DLNN_5_Train[metric_to_plot]*100, 3), width, label='DLNN_5, Train')
#     rects3 = ax.bar(x + (1.5*(width/2)), round(DLNN_3_Test[metric_to_plot]*100, 3), width, label='DLNN_3, Test')
#     rects4 = ax.bar(x + (4*(width/2)), round(DLNN_5_Test[metric_to_plot]*100, 3), width, label='DLNN_5, Test')

#     ## Custom y-axis tick labels
#     ax.set_ylabel(metric_to_plot)
#     ax.set_ylim([(math.floor(min(evaluations_df_grouped[metric_to_plot])*10)-1)*10, 
#                 (math.ceil(max(evaluations_df_grouped[metric_to_plot])*10)+1)*10])
#     # ax.set_ylim([80, 105])

#     ## Custom x-axis tick labels
#     ax.set_xticks(x)
#     # ax.set_xticklabels(DLNN_3_Train.index.get_level_values(0))
#     # ax.set_xticklabels([m+" - "+str(n) for m,n in 
#     #                         zip(DLNN_3_Train.index.get_level_values(0),DLNN_3_Train.index.get_level_values(1))],
#     #                   rotation=30)
#     ax.set_xticklabels(DLNN_3_Train.index.get_level_values(0))

#     ax.set_title(metric_to_plot+' by Dataset, Model, Train/Test')
#     ax.legend(loc='upper left')

#     def autolabel(rects):
#         for rect in rects:
#             height = rect.get_height()
#             ax.annotate('{}'.format(height),
#                         xy=(rect.get_x() + rect.get_width() / 2, height),
#                         xytext=(0, 3),  # 3 points vertical offset
#                         textcoords="offset points", 
#                         ha='center', va='bottom', rotation=90)

#     autolabel(rects1)
#     autolabel(rects2)
#     autolabel(rects3)
#     autolabel(rects4)
    
#     plt.savefig(os.path.join(evalPath, "{}_DLNN_Comparison".format(metric_to_plot)))
#     plt.close()

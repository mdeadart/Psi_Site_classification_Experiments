# %%
##################################################################################
##### Define all parameters for model tuning
##################################################################################

n_fold = 10
expName = "PSI_Site_DLNN_CORENup_MergedSeq"
outPath = "Results"
foldName = "folds.pickle"

# modelNames = ["DLNN_3", "DLNN_5"]

epochs = 100
batch_size = 32
shuffle = True
seed = None

input_data_folder = "Data\\Aziz"

# %%
import os 
from Bio import SeqIO
import pickle
import numpy as np
import pandas as pd

import tensorflow as tf

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc, accuracy_score, precision_score, confusion_matrix
from sklearn.metrics import roc_auc_score

import math

# %%
# print(tf.test.is_gpu_available(cuda_only=True))
# physical_devices = tf.config.experimental.list_physical_devices('GPU')
physical_devices = tf.config.list_physical_devices('GPU')
print(physical_devices)
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
##################################################################################
##### define all CUSTOM functions
##################################################################################

def one_hot_encode_dna(sequence):
    seq_encoded = np.zeros((len(sequence),4))
    dict_nuc = {
        "A": 0,
        "C": 1,
        "G": 2,
        "T": 3
    }
    i = 0
    for single_character in sequence:
        if(single_character.upper() in dict_nuc.keys()):
            seq_encoded[i][dict_nuc[single_character.upper()]] = 1
            i = i+1
        else:
            raise ValueError('Incorrect character in DNA sequence: '+sequence)
    return seq_encoded

def one_hot_encode_rna(sequence):
    seq_encoded = np.zeros((len(sequence),4))
    dict_nuc = {
        "A": 0,
        "C": 1,
        "G": 2,
        "U": 3
    }
    i = 0
    for single_character in sequence:
        if(single_character.upper() in dict_nuc.keys()):
            seq_encoded[i][dict_nuc[single_character.upper()]] = 1
            i = i+1
        else:
            raise ValueError('Incorrect character in RNA sequence: '+sequence)
    return seq_encoded

def one_hot_encode_rnafold(sequence):
    seq_encoded = np.zeros((len(sequence),3))
    dict_fold = {
        "(": 0,
        ")": 1,
        ".": 2
    }
    i = 0
    for single_character in sequence:
        if(single_character in dict_fold.keys()):
            seq_encoded[i][dict_fold[single_character]] = 1
            i = i+1
        else:
            raise ValueError('Incorrect character in RNAfold: '+sequence)
    return seq_encoded

def one_hot_encode_rna_mergedseq(sequence):
    dict_nuc = {
        "A": 0,
        "C": 1,
        "G": 2,
        "U": 3
    }
    dict_fold = {
        "(": 0,
        ")": 1,
        ".": 2
    }
    list_seq = sequence.strip().split(' ')
    seq_encoded = np.zeros((len(list_seq),12))
    i = 0
    for single_character in list_seq:
        if(single_character[0].upper() in dict_nuc.keys()):
            idx1 = dict_nuc[single_character[0].upper()]+1
        else:
            raise ValueError('Incorrect RNA character in MergedSeq sequence: '+sequence)
        if(single_character[1] in dict_fold.keys()):
            idx2 = dict_fold[single_character[1]]+1
        else:
            raise ValueError('Incorrect RNAfold character in MergedSeq sequence: '+sequence)
        idx = (idx1 * idx2) - 1
        seq_encoded[i][idx] = 1
        i = i+1        
    return seq_encoded

# %%
##################################################################################
##### define evaluator functions
##################################################################################

## Build the K-fold from dataset
def build_kfold(features, labels, k=10, shuffle=False, seed=None):
    
    skf = StratifiedKFold(n_splits=k, shuffle=shuffle, random_state=seed)
    kfoldList = []
    for train_index, test_index in skf.split(features, labels):
        X_train, X_test = features[train_index], features[test_index]
        y_train, y_test = labels[train_index], labels[test_index]
        kfoldList.append({
            "X_train": X_train,
            "X_test": X_test,
            "y_train":y_train,
            "y_test":y_test
        })
    return kfoldList

def pred2label(y_pred):
    y_pred = np.round(y_pred).astype(int)
    return y_pred

# %%
##################################################################################
##### Function to customize the DLNN architecture with parameters
##################################################################################

def DLNN_CORENup(input_shape = (21,12),
               conv_filters_per_layer_1 = 50, kernel_length_1 = 5, conv_strides_1 = 1, ## 1st Convolutional layer parameters
               max_pool_width_1 = 2, max_pool_stride_1 = 2, ## 1st Maxpool layer parameters
               lstm_decode_units = 50, ## LSTM layer parameters
               conv_filters_per_layer_2 = 50,  kernel_length_2 = 10, conv_strides_2 = 1, ## 2nd Convolutional layer parameters
               max_pool_width_2 = 2, max_pool_stride_2 = 2, ## 2nd Maxpool layer parameters
               dense_decode_units = 370, ## Dense layer parameters
               prob = 0.5, learn_rate = 0.0003, loss = 'binary_crossentropy', metrics = 'accuracy'):
    
    beta = 0.001
    
    input1 = tf.keras.layers.Input(shape=input_shape)

    x1 = tf.keras.layers.Conv1D(conv_filters_per_layer_1, kernel_length_1, input_shape = input_shape, 
                                strides = conv_strides_1, kernel_regularizer = tf.keras.regularizers.l2(beta), 
                                padding = "same")(input1)
    x1 = tf.keras.layers.Activation('relu')(x1)
    x1 = tf.keras.layers.MaxPool1D(pool_size = max_pool_width_1, strides = max_pool_stride_1)(x1)
    x1 = tf.keras.layers.Dropout(prob)(x1)

    ## LSTM Path

    x2 = tf.keras.layers.LSTM(lstm_decode_units, return_sequences = True, 
                              kernel_regularizer = tf.keras.regularizers.l2(beta))(x1)
    x2 = tf.keras.layers.Dropout(prob)(x2)
    
    x2 = tf.keras.layers.Flatten()(x2)

    ## Conv Path

    x3 = tf.keras.layers.Conv1D(conv_filters_per_layer_2, kernel_length_2, strides = conv_strides_2, 
                                kernel_regularizer = tf.keras.regularizers.l2(beta), padding = 'same')(x1)
    x3 = tf.keras.layers.Activation('relu')(x3)
    x3 = tf.keras.layers.MaxPooling1D(pool_size = max_pool_width_2, strides = max_pool_stride_2)(x3)
    x3 = tf.keras.layers.Dropout(prob)(x3)
    
    x3 = tf.keras.layers.Flatten()(x3)

    ## Fully connected Layers

    y = tf.keras.layers.Concatenate(1)([x2,x3])
    
    y1 = tf.keras.layers.Dense(dense_decode_units, kernel_regularizer = tf.keras.regularizers.l2(beta), activation = 'relu')(y)
    
    y1 = tf.keras.layers.Dropout(prob)(y1)
    
    y1 = tf.keras.layers.Dense(1, kernel_regularizer = tf.keras.regularizers.l2(beta), activation = 'sigmoid')(y1)

    ## Generate Model from input and output
    model = tf.keras.models.Model(inputs=[input1], outputs=y1)
    
    ## Compile model
    if(metrics != None):
        model.compile(optimizer = tf.keras.optimizers.Adam(lr=learn_rate), loss = loss, metrics = metrics)
    else:
        model.compile(optimizer = tf.keras.optimizers.Adam(lr=learn_rate), loss = loss)

    return model

# %%
DLNN_CORENup().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 21, 4)]      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 21, 50)       1050        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 21, 50)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 10, 50)       0           activation[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 10, 50)       0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 10, 50)       25050       dropout[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10, 50)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 10, 50)       20200       dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 5, 50)        0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 10, 50)       0           lstm[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 5, 50)        0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 500)          0           dropout_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 250)          0           dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 750)          0           flatten[0][0]
#                                                                  flatten_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 370)          277870      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 370)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            371         dropout_3[0][0]
# ==================================================================================================
# Total params: 324,541
# Trainable params: 324,541
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
##################################################################################
##### For each input file, train model and generate different outputs in a structured folder
##################################################################################

## create the evaluation data structure for all iterations
evaluations = {
    "Model" : [],
#     "Kernel_Length" : [],
    "Dataset" : [],
    "Fold" : [],
    "Train_Test" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

# %%
for root, dirs, files in os.walk(input_data_folder):
    for file in files:
        
        input_data_file = os.path.join(root, file)
        
        current_dataset_variety = input_data_file.split("\\")[-1].split(".")[0]
        
        csv_data = pd.read_csv(input_data_file)

        ##################################################################################
        ##### extract data from the current CSV file
        ##################################################################################

        csv_data["OHE_MergedSeq"] = pd.Series([one_hot_encode_rna_mergedseq(val) for val in csv_data["MergedSeq"]])

        df_positive = csv_data[csv_data['Number'].str.contains("P")]
        df_negative = csv_data[csv_data['Number'].str.contains("N")]

        positive_onehotencoded_array = np.array(list(df_positive['OHE_MergedSeq']))
        negative_onehotencoded_array = np.array(list(df_negative['OHE_MergedSeq']))

        print("\n======================================================================")
        print("\nFile:", input_data_file)
        print("Positive:", positive_onehotencoded_array.shape[0])
        print("Negative:", negative_onehotencoded_array.shape[0])

        ##################################################################################
        ##### Generate Folds from dataset, and store to file
        ##################################################################################

        ## create the features and labels datasets for the training
        input_size = positive_onehotencoded_array[0].shape

        labels = np.concatenate((np.ones((positive_onehotencoded_array.shape[0], 1), 
                                         dtype=np.float32), 
                                 np.zeros((negative_onehotencoded_array.shape[0], 1), 
                                          dtype=np.float32)), 
                                axis=0)

        features = np.concatenate((positive_onehotencoded_array, 
                                   negative_onehotencoded_array), 
                                  axis=0)

        folds = build_kfold(features, labels, 
                            k=n_fold, shuffle=shuffle, seed=seed)

        ## Write the k-fold dataset to file
        foldPath = os.path.join(outPath, expName, current_dataset_variety, "{}fold".format(n_fold))
        if(not os.path.isdir(foldPath)):
            os.makedirs(foldPath)
        pickle.dump(folds, open(os.path.join(foldPath, foldName), "wb"))

        ## Create and set directory to save model
        modelPath = os.path.join(outPath, expName, current_dataset_variety, "{}fold".format(n_fold), "models")
        if(not os.path.isdir(modelPath)):
            os.makedirs(modelPath)
            
        ##################################################################################
        ##### TRAIN and PREDICT for every Fold, using models
        ##################################################################################

        # fold counter
        i = 0

        for fold in folds:
            
            # adding random shuffling of the dataset for training purpose
            randomized_index_arr = np.arange(ens_fold["X_train"].shape[0])
            randomized_index_arr = np.random.permutation(randomized_index_arr)

            print("\nTrain/Test model "+current_dataset_variety+" on Fold #"+str(i)+".")

#             kernel_length = 3
            ## Generate model using function
            model = DLNN_CORENup(input_shape = input_size)
    
            model_file_path = os.path.join(modelPath, "{}_bestModel-fold{}.hdf5".format(current_dataset_variety, i))
            ## Define the model callbacks for early stopping and saving the model. Then train model
            modelCallbacks = [
                tf.keras.callbacks.ModelCheckpoint(model_file_path,
                                                   monitor = 'val_loss', verbose = 1, save_best_only = True, 
                                                   save_weights_only = False, mode = 'auto', save_freq = 'epoch'),
#                 tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', min_delta = 0, patience = 10, verbose = 0, 
#                                                  mode = 'auto', baseline = None, restore_best_weights = True)
            ]
            model.fit(x = fold["X_train"][randomized_index_arr], y = fold["y_train"][randomized_index_arr], batch_size = batch_size, epochs = epochs, verbose = 1, 
                      callbacks = modelCallbacks, validation_data = (fold["X_test"], fold["y_test"]))
            
            ##################################################################################
            ##### Prediction and metrics for TRAIN dataset
            ##################################################################################

            y_pred = model.predict(fold["X_train"])
            label_pred = pred2label(y_pred)
            # Compute precision, recall, sensitivity, specifity, mcc
            acc = accuracy_score(fold["y_train"], label_pred)
            prec = precision_score(fold["y_train"],label_pred)

            conf = confusion_matrix(fold["y_train"], label_pred)
            if(conf[0][0]+conf[1][0]):
                sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
            else:
                sens = 0.0
            if(conf[1][1]+conf[0][1]):
                spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
            else:
                spec = 0.0
            if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
                mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
            else:
                mcc= 0.0
            fpr, tpr, thresholds = roc_curve(fold["y_train"], y_pred)
            auc = roc_auc_score(fold["y_train"], y_pred)

            evaluations["Model"].append(current_dataset_variety)
#             evaluations["Kernel_Length"].append(kernel_length)
            evaluations["Dataset"].append(current_dataset_variety)
            evaluations["Fold"].append(i)
            evaluations["Train_Test"].append("Train")
            evaluations["Accuracy"].append(acc)
            evaluations["Precision"].append(prec)
            evaluations["TPR"].append(tpr)
            evaluations["FPR"].append(fpr)
            evaluations["TPR_FPR_Thresholds"].append(thresholds)
            evaluations["AUC"].append(auc)
            evaluations["Sensitivity"].append(sens)
            evaluations["Specificity"].append(spec)
            evaluations["MCC"].append(mcc)

            ##################################################################################
            ##### Prediction and metrics for TEST dataset
            ##################################################################################

            y_pred = model.predict(fold["X_test"])
            label_pred = pred2label(y_pred)
            # Compute precision, recall, sensitivity, specifity, mcc
            acc = accuracy_score(fold["y_test"], label_pred)
            prec = precision_score(fold["y_test"],label_pred)

            conf = confusion_matrix(fold["y_test"], label_pred)
            if(conf[0][0]+conf[1][0]):
                sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
            else:
                sens = 0.0
            if(conf[1][1]+conf[0][1]):
                spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
            else:
                spec = 0.0
            if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
                mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
            else:
                mcc= 0.0
            fpr, tpr, thresholds = roc_curve(fold["y_test"], y_pred)
            auc = roc_auc_score(fold["y_test"], y_pred)

            evaluations["Model"].append(current_dataset_variety)
#             evaluations["Kernel_Length"].append(kernel_length)
            evaluations["Dataset"].append(current_dataset_variety)
            evaluations["Fold"].append(i)
            evaluations["Train_Test"].append("Test")
            evaluations["Accuracy"].append(acc)
            evaluations["Precision"].append(prec)
            evaluations["TPR"].append(tpr)
            evaluations["FPR"].append(fpr)
            evaluations["TPR_FPR_Thresholds"].append(thresholds)
            evaluations["AUC"].append(auc)
            evaluations["Sensitivity"].append(sens)
            evaluations["Specificity"].append(spec)
            evaluations["MCC"].append(mcc)

            i = i+1
            del model
            tf.keras.backend.clear_session()

        ##################################################################################
        ##### Dump evaluations to a file
        ##################################################################################

        evalPath = os.path.join(outPath, expName, "_Evaluation_All_Datasets")
        if(not os.path.isdir(evalPath)):
            os.makedirs(evalPath)

        pickle.dump(evaluations,
                    open(os.path.join(evalPath, "{}fold_evaluations.pickle".format(n_fold)), "wb"))
# Out:
# ======================================================================
#
# File: Data\Aziz\HS_990.csv
# Positive: 495
# Negative: 495
#
# Train/Test model HS_990 on Fold #0.
# Epoch 1/100
# 28/28 [==============================] - ETA: 0s - loss: 1.3145 - accuracy: 0.5174
# Epoch 00001: val_loss improved from inf to 1.28553, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 1s 28ms/step - loss: 1.3145 - accuracy: 0.5174 - val_loss: 1.2855 - val_accuracy: 0.4848
# Epoch 2/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.2610 - accuracy: 0.5213
# Epoch 00002: val_loss improved from 1.28553 to 1.23770, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 1.2584 - accuracy: 0.5118 - val_loss: 1.2377 - val_accuracy: 0.4949
# Epoch 3/100
# 26/28 [==========================>...] - ETA: 0s - loss: 1.2116 - accuracy: 0.5252
# Epoch 00003: val_loss improved from 1.23770 to 1.19210, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 1.2103 - accuracy: 0.5253 - val_loss: 1.1921 - val_accuracy: 0.4545
# Epoch 4/100
# 22/28 [======================>.......] - ETA: 0s - loss: 1.1721 - accuracy: 0.5369
# Epoch 00004: val_loss improved from 1.19210 to 1.15698, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 11ms/step - loss: 1.1688 - accuracy: 0.5376 - val_loss: 1.1570 - val_accuracy: 0.4949
# Epoch 5/100
# 26/28 [==========================>...] - ETA: 0s - loss: 1.1360 - accuracy: 0.5397
# Epoch 00005: val_loss improved from 1.15698 to 1.12644, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 1.1354 - accuracy: 0.5342 - val_loss: 1.1264 - val_accuracy: 0.4646
# Epoch 6/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.1048 - accuracy: 0.5263
# Epoch 00006: val_loss improved from 1.12644 to 1.09715, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 1.1030 - accuracy: 0.5297 - val_loss: 1.0971 - val_accuracy: 0.4848
# Epoch 7/100
# 21/28 [=====================>........] - ETA: 0s - loss: 1.0750 - accuracy: 0.5432
# Epoch 00007: val_loss improved from 1.09715 to 1.07290, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 1.0720 - accuracy: 0.5421 - val_loss: 1.0729 - val_accuracy: 0.4747
# Epoch 8/100
# 23/28 [=======================>......] - ETA: 0s - loss: 1.0449 - accuracy: 0.5530
# Epoch 00008: val_loss improved from 1.07290 to 1.04972, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 1.0410 - accuracy: 0.5623 - val_loss: 1.0497 - val_accuracy: 0.4747
# Epoch 9/100
# 27/28 [===========================>..] - ETA: 0s - loss: 1.0266 - accuracy: 0.5359
# Epoch 00009: val_loss improved from 1.04972 to 1.02786, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 1.0259 - accuracy: 0.5410 - val_loss: 1.0279 - val_accuracy: 0.4848
# Epoch 10/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.9994 - accuracy: 0.5718
# Epoch 00010: val_loss improved from 1.02786 to 1.00951, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.9991 - accuracy: 0.5735 - val_loss: 1.0095 - val_accuracy: 0.5051
# Epoch 11/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.9840 - accuracy: 0.5584
# Epoch 00011: val_loss improved from 1.00951 to 0.99220, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 0.9828 - accuracy: 0.5589 - val_loss: 0.9922 - val_accuracy: 0.4646
# Epoch 12/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.9670 - accuracy: 0.5794
# Epoch 00012: val_loss improved from 0.99220 to 0.97745, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 11ms/step - loss: 0.9631 - accuracy: 0.5859 - val_loss: 0.9774 - val_accuracy: 0.4747
# Epoch 13/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.9495 - accuracy: 0.5769
# Epoch 00013: val_loss improved from 0.97745 to 0.96628, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.9474 - accuracy: 0.5746 - val_loss: 0.9663 - val_accuracy: 0.5152
# Epoch 14/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.9346 - accuracy: 0.5813
# Epoch 00014: val_loss improved from 0.96628 to 0.95528, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.9323 - accuracy: 0.5836 - val_loss: 0.9553 - val_accuracy: 0.5051
# Epoch 15/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.9186 - accuracy: 0.5938
# Epoch 00015: val_loss improved from 0.95528 to 0.94221, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.9210 - accuracy: 0.5859 - val_loss: 0.9422 - val_accuracy: 0.4949
# Epoch 16/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.9010 - accuracy: 0.6094
# Epoch 00016: val_loss improved from 0.94221 to 0.93388, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.9025 - accuracy: 0.6105 - val_loss: 0.9339 - val_accuracy: 0.4949
# Epoch 17/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.9027 - accuracy: 0.5673
# Epoch 00017: val_loss improved from 0.93388 to 0.92081, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.9031 - accuracy: 0.5668 - val_loss: 0.9208 - val_accuracy: 0.5253
# Epoch 18/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.8802 - accuracy: 0.6087
# Epoch 00018: val_loss improved from 0.92081 to 0.91292, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8823 - accuracy: 0.6049 - val_loss: 0.9129 - val_accuracy: 0.4747
# Epoch 19/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.8759 - accuracy: 0.5900
# Epoch 00019: val_loss improved from 0.91292 to 0.91034, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8775 - accuracy: 0.5870 - val_loss: 0.9103 - val_accuracy: 0.5152
# Epoch 20/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.8503 - accuracy: 0.6435
# Epoch 00020: val_loss improved from 0.91034 to 0.90405, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8501 - accuracy: 0.6431 - val_loss: 0.9041 - val_accuracy: 0.5556
# Epoch 21/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.8476 - accuracy: 0.6325
# Epoch 00021: val_loss improved from 0.90405 to 0.90009, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8496 - accuracy: 0.6319 - val_loss: 0.9001 - val_accuracy: 0.5354
# Epoch 22/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.8423 - accuracy: 0.6125
# Epoch 00022: val_loss improved from 0.90009 to 0.89670, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8419 - accuracy: 0.6128 - val_loss: 0.8967 - val_accuracy: 0.5354
# Epoch 23/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.8401 - accuracy: 0.6185
# Epoch 00023: val_loss improved from 0.89670 to 0.88404, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 0.8349 - accuracy: 0.6240 - val_loss: 0.8840 - val_accuracy: 0.5758
# Epoch 24/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.8220 - accuracy: 0.6237
# Epoch 00024: val_loss did not improve from 0.88404
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8227 - accuracy: 0.6173 - val_loss: 0.8888 - val_accuracy: 0.5253
# Epoch 25/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.8158 - accuracy: 0.6363
# Epoch 00025: val_loss improved from 0.88404 to 0.88211, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 0.8166 - accuracy: 0.6364 - val_loss: 0.8821 - val_accuracy: 0.5051
# Epoch 26/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.8119 - accuracy: 0.6341
# Epoch 00026: val_loss improved from 0.88211 to 0.87501, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8059 - accuracy: 0.6465 - val_loss: 0.8750 - val_accuracy: 0.5253
# Epoch 27/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.7999 - accuracy: 0.6328
# Epoch 00027: val_loss improved from 0.87501 to 0.86648, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 0.8001 - accuracy: 0.6319 - val_loss: 0.8665 - val_accuracy: 0.5657
# Epoch 28/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.7853 - accuracy: 0.6495
# Epoch 00028: val_loss did not improve from 0.86648
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7831 - accuracy: 0.6543 - val_loss: 0.8681 - val_accuracy: 0.5354
# Epoch 29/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.7735 - accuracy: 0.6617
# Epoch 00029: val_loss improved from 0.86648 to 0.86517, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 0.7769 - accuracy: 0.6521 - val_loss: 0.8652 - val_accuracy: 0.5354
# Epoch 30/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7682 - accuracy: 0.6675
# Epoch 00030: val_loss improved from 0.86517 to 0.85967, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7695 - accuracy: 0.6678 - val_loss: 0.8597 - val_accuracy: 0.5455
# Epoch 31/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.7782 - accuracy: 0.6502
# Epoch 00031: val_loss improved from 0.85967 to 0.85607, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7724 - accuracy: 0.6543 - val_loss: 0.8561 - val_accuracy: 0.5455
# Epoch 32/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.7608 - accuracy: 0.6620
# Epoch 00032: val_loss improved from 0.85607 to 0.85002, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7630 - accuracy: 0.6588 - val_loss: 0.8500 - val_accuracy: 0.5051
# Epoch 33/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.7552 - accuracy: 0.6589
# Epoch 00033: val_loss improved from 0.85002 to 0.84939, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7525 - accuracy: 0.6633 - val_loss: 0.8494 - val_accuracy: 0.5556
# Epoch 34/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.7493 - accuracy: 0.6731
# Epoch 00034: val_loss improved from 0.84939 to 0.84624, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7459 - accuracy: 0.6768 - val_loss: 0.8462 - val_accuracy: 0.5455
# Epoch 35/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.7296 - accuracy: 0.7005
# Epoch 00035: val_loss did not improve from 0.84624
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7332 - accuracy: 0.6902 - val_loss: 0.8501 - val_accuracy: 0.5758
# Epoch 36/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.7244 - accuracy: 0.7038
# Epoch 00036: val_loss did not improve from 0.84624
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7235 - accuracy: 0.7037 - val_loss: 0.8489 - val_accuracy: 0.5758
# Epoch 37/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.7361 - accuracy: 0.6667
# Epoch 00037: val_loss improved from 0.84624 to 0.84041, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 0.7412 - accuracy: 0.6655 - val_loss: 0.8404 - val_accuracy: 0.5657
# Epoch 38/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.7298 - accuracy: 0.6821
# Epoch 00038: val_loss improved from 0.84041 to 0.83121, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 0.7199 - accuracy: 0.6958 - val_loss: 0.8312 - val_accuracy: 0.5556
# Epoch 39/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.7176 - accuracy: 0.6836
# Epoch 00039: val_loss did not improve from 0.83121
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7166 - accuracy: 0.6824 - val_loss: 0.8373 - val_accuracy: 0.5354
# Epoch 40/100
# 28/28 [==============================] - ETA: 0s - loss: 0.6962 - accuracy: 0.7059
# Epoch 00040: val_loss improved from 0.83121 to 0.82625, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.6962 - accuracy: 0.7059 - val_loss: 0.8263 - val_accuracy: 0.5657
# Epoch 41/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.6871 - accuracy: 0.7083
# Epoch 00041: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 7ms/step - loss: 0.6832 - accuracy: 0.7104 - val_loss: 0.8370 - val_accuracy: 0.5455
# Epoch 42/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.7149 - accuracy: 0.6771
# Epoch 00042: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7036 - accuracy: 0.6891 - val_loss: 0.8724 - val_accuracy: 0.5657
# Epoch 43/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6981 - accuracy: 0.6875
# Epoch 00043: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6972 - accuracy: 0.6869 - val_loss: 0.8382 - val_accuracy: 0.5657
# Epoch 44/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.7007 - accuracy: 0.6875
# Epoch 00044: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6919 - accuracy: 0.6947 - val_loss: 0.8315 - val_accuracy: 0.5657
# Epoch 45/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6816 - accuracy: 0.6914
# Epoch 00045: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6703 - accuracy: 0.7026 - val_loss: 0.8406 - val_accuracy: 0.5657
# Epoch 46/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6548 - accuracy: 0.7425
# Epoch 00046: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6556 - accuracy: 0.7396 - val_loss: 0.8375 - val_accuracy: 0.5455
# Epoch 47/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6746 - accuracy: 0.7011
# Epoch 00047: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6772 - accuracy: 0.6947 - val_loss: 0.8420 - val_accuracy: 0.5657
# Epoch 48/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.6594 - accuracy: 0.7332
# Epoch 00048: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6523 - accuracy: 0.7419 - val_loss: 0.8361 - val_accuracy: 0.5556
# Epoch 49/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.6394 - accuracy: 0.7386
# Epoch 00049: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 9ms/step - loss: 0.6562 - accuracy: 0.7217 - val_loss: 0.8316 - val_accuracy: 0.5455
# Epoch 50/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6341 - accuracy: 0.7435
# Epoch 00050: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6355 - accuracy: 0.7508 - val_loss: 0.8395 - val_accuracy: 0.5859
# Epoch 51/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.6412 - accuracy: 0.7457
# Epoch 00051: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 9ms/step - loss: 0.6395 - accuracy: 0.7441 - val_loss: 0.8366 - val_accuracy: 0.5758
# Epoch 52/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.6179 - accuracy: 0.7644
# Epoch 00052: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 7ms/step - loss: 0.6214 - accuracy: 0.7587 - val_loss: 0.8287 - val_accuracy: 0.5556
# Epoch 53/100
# 28/28 [==============================] - ETA: 0s - loss: 0.6402 - accuracy: 0.7273
# Epoch 00053: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 7ms/step - loss: 0.6402 - accuracy: 0.7273 - val_loss: 0.8500 - val_accuracy: 0.5657
# Epoch 54/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.6470 - accuracy: 0.7373
# Epoch 00054: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 7ms/step - loss: 0.6481 - accuracy: 0.7340 - val_loss: 0.8461 - val_accuracy: 0.5556
# Epoch 55/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.6353 - accuracy: 0.7338
# Epoch 00055: val_loss did not improve from 0.82625
# 28/28 [==============================] - 0s 9ms/step - loss: 0.6393 - accuracy: 0.7306 - val_loss: 0.8347 - val_accuracy: 0.5657
# Epoch 56/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.6414 - accuracy: 0.7287
# Epoch 00056: val_loss improved from 0.82625 to 0.81717, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold0.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 0.6284 - accuracy: 0.7430 - val_loss: 0.8172 - val_accuracy: 0.5354
# Epoch 57/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6124 - accuracy: 0.7786
# Epoch 00057: val_loss did not improve from 0.81717
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6175 - accuracy: 0.7722 - val_loss: 0.8240 - val_accuracy: 0.5253
# Epoch 58/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.5905 - accuracy: 0.7885
# Epoch 00058: val_loss did not improve from 0.81717
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5962 - accuracy: 0.7811 - val_loss: 0.8459 - val_accuracy: 0.5455
# Epoch 59/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6191 - accuracy: 0.7459
# Epoch 00059: val_loss did not improve from 0.81717
# 28/28 [==============================] - 0s 9ms/step - loss: 0.6158 - accuracy: 0.7486 - val_loss: 0.8303 - val_accuracy: 0.5657
# Epoch 60/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.6077 - accuracy: 0.7656
# Epoch 00060: val_loss did not improve from 0.81717
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6068 - accuracy: 0.7699 - val_loss: 0.8213 - val_accuracy: 0.5556
# Epoch 61/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.5914 - accuracy: 0.7855
# Epoch 00061: val_loss did not improve from 0.81717
# 28/28 [==============================] - 0s
val_loss did not improve from 0.81717
# 28/28 [==============================] - 0s 7ms/step - loss: 0.4895 - accuracy: 0.8328 - val_loss: 0.8496 - val_accuracy: 0.5455
# Epoch 95/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.4724 - accuracy: 0.8372
# Epoch 00095: val_loss did not improve from 0.81717
# 28/28 [==============================] - 0s 8ms/step - loss: 0.4783 - accuracy: 0.8406 - val_loss: 0.8593 - val_accuracy: 0.5657
# Epoch 96/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.4832 - accuracy: 0.8225
# Epoch 00096: val_loss did not improve from 0.81717
# 28/28 [==============================] - 0s 8ms/step - loss: 0.4805 - accuracy: 0.8238 - val_loss: 0.8605 - val_accuracy: 0.5556
# Epoch 97/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5016 - accuracy: 0.8177
# Epoch 00097: val_loss did not improve from 0.81717
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5059 - accuracy: 0.8137 - val_loss: 0.8556 - val_accuracy: 0.5354
# Epoch 98/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.4627 - accuracy: 0.8568
# Epoch 00098: val_loss did not improve from 0.81717
# 28/28 [==============================] - 0s 8ms/step - loss: 0.4612 - accuracy: 0.8586 - val_loss: 0.8454 - val_accuracy: 0.5455
# Epoch 99/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.4740 - accuracy: 0.8325
# Epoch 00099: val_loss did not improve from 0.81717
# 28/28 [==============================] - 0s 7ms/step - loss: 0.4841 - accuracy: 0.8249 - val_loss: 0.8575 - val_accuracy: 0.5556
# Epoch 100/100
# 27/28 [===========================>..] - ETA: 0s - loss: 0.4507 - accuracy: 0.8530
# Epoch 00100: val_loss did not improve from 0.81717
# 28/28 [==============================] - 0s 7ms/step - loss: 0.4508 - accuracy: 0.8541 - val_loss: 0.8546 - val_accuracy: 0.5657
#
# Train/Test model HS_990 on Fold #1.
# Epoch 1/100
# 23/28 [=======================>......] - ETA: 0s - loss: 1.3218 - accuracy: 0.5027
# Epoch 00001: val_loss improved from inf to 1.28217, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 1s 23ms/step - loss: 1.3173 - accuracy: 0.5039 - val_loss: 1.2822 - val_accuracy: 0.4949
# Epoch 2/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.2624 - accuracy: 0.5362
# Epoch 00002: val_loss improved from 1.28217 to 1.23250, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 1.2605 - accuracy: 0.5365 - val_loss: 1.2325 - val_accuracy: 0.4747
# Epoch 3/100
# 24/28 [========================>.....] - ETA: 0s - loss: 1.2168 - accuracy: 0.5286
# Epoch 00003: val_loss improved from 1.23250 to 1.18868, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 1.2137 - accuracy: 0.5297 - val_loss: 1.1887 - val_accuracy: 0.6061
# Epoch 4/100
# 23/28 [=======================>......] - ETA: 0s - loss: 1.1860 - accuracy: 0.4837
# Epoch 00004: val_loss improved from 1.18868 to 1.15059, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 1.1805 - accuracy: 0.4938 - val_loss: 1.1506 - val_accuracy: 0.6162
# Epoch 5/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.1458 - accuracy: 0.5075
# Epoch 00005: val_loss improved from 1.15059 to 1.11822, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 1.1419 - accuracy: 0.5107 - val_loss: 1.1182 - val_accuracy: 0.5960
# Epoch 6/100
# 23/28 [=======================>......] - ETA: 0s - loss: 1.1085 - accuracy: 0.5408
# Epoch 00006: val_loss improved from 1.11822 to 1.08909, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 1.1058 - accuracy: 0.5432 - val_loss: 1.0891 - val_accuracy: 0.5556
# Epoch 7/100
# 24/28 [========================>.....] - ETA: 0s - loss: 1.0810 - accuracy: 0.5312
# Epoch 00007: val_loss improved from 1.08909 to 1.06164, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 1.0789 - accuracy: 0.5376 - val_loss: 1.0616 - val_accuracy: 0.5556
# Epoch 8/100
# 24/28 [========================>.....] - ETA: 0s - loss: 1.0498 - accuracy: 0.5677
# Epoch 00008: val_loss improved from 1.06164 to 1.03733, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 1.0478 - accuracy: 0.5645 - val_loss: 1.0373 - val_accuracy: 0.5960
# Epoch 9/100
# 26/28 [==========================>...] - ETA: 0s - loss: 1.0289 - accuracy: 0.5541
# Epoch 00009: val_loss improved from 1.03733 to 1.01744, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 1.0291 - accuracy: 0.5466 - val_loss: 1.0174 - val_accuracy: 0.5859
# Epoch 10/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.0118 - accuracy: 0.5387
# Epoch 00010: val_loss improved from 1.01744 to 0.99950, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 1.0115 - accuracy: 0.5354 - val_loss: 0.9995 - val_accuracy: 0.5556
# Epoch 11/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.9838 - accuracy: 0.5650
# Epoch 00011: val_loss improved from 0.99950 to 0.98132, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 11ms/step - loss: 0.9832 - accuracy: 0.5701 - val_loss: 0.9813 - val_accuracy: 0.5859
# Epoch 12/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.9703 - accuracy: 0.5652
# Epoch 00012: val_loss improved from 0.98132 to 0.96734, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 0.9694 - accuracy: 0.5634 - val_loss: 0.9673 - val_accuracy: 0.5556
# Epoch 13/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.9452 - accuracy: 0.5877
# Epoch 00013: val_loss improved from 0.96734 to 0.95367, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.9476 - accuracy: 0.5814 - val_loss: 0.9537 - val_accuracy: 0.5556
# Epoch 14/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.9431 - accuracy: 0.5565
# Epoch 00014: val_loss improved from 0.95367 to 0.93895, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.9439 - accuracy: 0.5578 - val_loss: 0.9390 - val_accuracy: 0.5556
# Epoch 15/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.9255 - accuracy: 0.5859
# Epoch 00015: val_loss improved from 0.93895 to 0.92552, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.9230 - accuracy: 0.5926 - val_loss: 0.9255 - val_accuracy: 0.5758
# Epoch 16/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.9121 - accuracy: 0.6046
# Epoch 00016: val_loss improved from 0.92552 to 0.91393, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 0.9096 - accuracy: 0.6061 - val_loss: 0.9139 - val_accuracy: 0.6061
# Epoch 17/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.9058 - accuracy: 0.5693
# Epoch 00017: val_loss improved from 0.91393 to 0.90675, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 0.9013 - accuracy: 0.5769 - val_loss: 0.9068 - val_accuracy: 0.5556
# Epoch 18/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.8765 - accuracy: 0.6172
# Epoch 00018: val_loss improved from 0.90675 to 0.89739, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8787 - accuracy: 0.6061 - val_loss: 0.8974 - val_accuracy: 0.5455
# Epoch 19/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.8817 - accuracy: 0.5815
# Epoch 00019: val_loss improved from 0.89739 to 0.88862, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 10ms/step - loss: 0.8769 - accuracy: 0.5870 - val_loss: 0.8886 - val_accuracy: 0.5253
# Epoch 20/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.8688 - accuracy: 0.6200
# Epoch 00020: val_loss improved from 0.88862 to 0.87669, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\HS_990\10fold\models\HS_990_bestModel-fold1.hdf5
# 28/28 [==============================] - 0s 9ms/step - loss:
saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\SN_628\10fold\models\SN_628_bestModel-fold9.hdf5
# 18/18 [==============================] - 0s 12ms/step - loss: 0.6439 - accuracy: 0.7774 - val_loss: 0.8834 - val_accuracy: 0.5968
# Epoch 59/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.6368 - accuracy: 0.7729
# Epoch 00059: val_loss did not improve from 0.88344
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6409 - accuracy: 0.7633 - val_loss: 0.9128 - val_accuracy: 0.5806
# Epoch 60/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.6407 - accuracy: 0.8000
# Epoch 00060: val_loss did not improve from 0.88344
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6318 - accuracy: 0.8021 - val_loss: 0.8956 - val_accuracy: 0.5484
# Epoch 61/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.6034 - accuracy: 0.7875
# Epoch 00061: val_loss did not improve from 0.88344
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6034 - accuracy: 0.7845 - val_loss: 0.8900 - val_accuracy: 0.5806
# Epoch 62/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.6001 - accuracy: 0.8021
# Epoch 00062: val_loss improved from 0.88344 to 0.87913, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\SN_628\10fold\models\SN_628_bestModel-fold9.hdf5
# 18/18 [==============================] - 0s 11ms/step - loss: 0.6102 - accuracy: 0.7933 - val_loss: 0.8791 - val_accuracy: 0.5806
# Epoch 63/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.6014 - accuracy: 0.8027
# Epoch 00063: val_loss did not improve from 0.87913
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5965 - accuracy: 0.8110 - val_loss: 0.8802 - val_accuracy: 0.5645
# Epoch 64/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.6113 - accuracy: 0.7832
# Epoch 00064: val_loss improved from 0.87913 to 0.87181, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\SN_628\10fold\models\SN_628_bestModel-fold9.hdf5
# 18/18 [==============================] - 0s 11ms/step - loss: 0.6000 - accuracy: 0.7968 - val_loss: 0.8718 - val_accuracy: 0.5645
# Epoch 65/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.5834 - accuracy: 0.8145
# Epoch 00065: val_loss did not improve from 0.87181
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5787 - accuracy: 0.8180 - val_loss: 0.8875 - val_accuracy: 0.5484
# Epoch 66/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.5686 - accuracy: 0.8184
# Epoch 00066: val_loss did not improve from 0.87181
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5718 - accuracy: 0.8127 - val_loss: 0.9052 - val_accuracy: 0.5645
# Epoch 67/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.5799 - accuracy: 0.8086
# Epoch 00067: val_loss did not improve from 0.87181
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5741 - accuracy: 0.8110 - val_loss: 0.8903 - val_accuracy: 0.5806
# Epoch 68/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.5828 - accuracy: 0.7917
# Epoch 00068: val_loss did not improve from 0.87181
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5847 - accuracy: 0.7933 - val_loss: 0.9131 - val_accuracy: 0.5645
# Epoch 69/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.5866 - accuracy: 0.8145
# Epoch 00069: val_loss did not improve from 0.87181
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5720 - accuracy: 0.8251 - val_loss: 0.9210 - val_accuracy: 0.5645
# Epoch 70/100
# 14/18 [======================>.......] - ETA: 0s - loss: 0.5625 - accuracy: 0.8326
# Epoch 00070: val_loss improved from 0.87181 to 0.87163, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\SN_628\10fold\models\SN_628_bestModel-fold9.hdf5
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5718 - accuracy: 0.8233 - val_loss: 0.8716 - val_accuracy: 0.5484
# Epoch 71/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.5796 - accuracy: 0.7979
# Epoch 00071: val_loss did not improve from 0.87163
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5800 - accuracy: 0.8039 - val_loss: 0.8737 - val_accuracy: 0.5645
# Epoch 72/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.5552 - accuracy: 0.8229
# Epoch 00072: val_loss did not improve from 0.87163
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5558 - accuracy: 0.8180 - val_loss: 0.9094 - val_accuracy: 0.5806
# Epoch 73/100
# 14/18 [======================>.......] - ETA: 0s - loss: 0.5523 - accuracy: 0.8192
# Epoch 00073: val_loss did not improve from 0.87163
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5507 - accuracy: 0.8251 - val_loss: 0.8752 - val_accuracy: 0.5806
# Epoch 74/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.5679 - accuracy: 0.8146
# Epoch 00074: val_loss improved from 0.87163 to 0.85481, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\SN_628\10fold\models\SN_628_bestModel-fold9.hdf5
# 18/18 [==============================] - 0s 12ms/step - loss: 0.5570 - accuracy: 0.8233 - val_loss: 0.8548 - val_accuracy: 0.5968
# Epoch 75/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.5416 - accuracy: 0.8379
# Epoch 00075: val_loss improved from 0.85481 to 0.85246, saving model to Results\PSI_Site_DLNN_CORENup_MergedSeq\SN_628\10fold\models\SN_628_bestModel-fold9.hdf5
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5407 - accuracy: 0.8375 - val_loss: 0.8525 - val_accuracy: 0.5645
# Epoch 76/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.5536 - accuracy: 0.8354
# Epoch 00076: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5581 - accuracy: 0.8304 - val_loss: 0.8719 - val_accuracy: 0.5484
# Epoch 77/100
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5252 - accuracy: 0.8309
# Epoch 00077: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5267 - accuracy: 0.8322 - val_loss: 0.8545 - val_accuracy: 0.5484
# Epoch 78/100
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5364 - accuracy: 0.8290
# Epoch 00078: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5314 - accuracy: 0.8339 - val_loss: 0.8983 - val_accuracy: 0.5484
# Epoch 79/100
# 17/18 [===========================>..] - ETA: 0s - loss: 0.5175 - accuracy: 0.8346
# Epoch 00079: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4666 - accuracy: 0.8763 - val_loss: 0.8991 - val_accuracy: 0.5806
# Epoch 91/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.4592 - accuracy: 0.8542
# Epoch 00091: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4676 - accuracy: 0.8587 - val_loss: 0.9043 - val_accuracy: 0.5645
# Epoch 92/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.4551 - accuracy: 0.8574
# Epoch 00092: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4639 - accuracy: 0.8569 - val_loss: 0.9231 - val_accuracy: 0.5323
# Epoch 93/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.4951 - accuracy: 0.8438
# Epoch 00093: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5012 - accuracy: 0.8516 - val_loss: 0.9076 - val_accuracy: 0.5323
# Epoch 94/100
# 14/18 [======================>.......] - ETA: 0s - loss: 0.4821 - accuracy: 0.8460
# Epoch 00094: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4857 - accuracy: 0.8463 - val_loss: 0.8952 - val_accuracy: 0.5484
# Epoch 95/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.4519 - accuracy: 0.8729
# Epoch 00095: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4527 - accuracy: 0.8728 - val_loss: 0.9116 - val_accuracy: 0.5161
# Epoch 96/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.4497 - accuracy: 0.8833
# Epoch 00096: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4581 - accuracy: 0.8799 - val_loss: 0.8868 - val_accuracy: 0.5645
# Epoch 97/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.4409 - accuracy: 0.8711
# Epoch 00097: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4304 - accuracy: 0.8799 - val_loss: 0.8732 - val_accuracy: 0.5484
# Epoch 98/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.4350 - accuracy: 0.8729
# Epoch 00098: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4332 - accuracy: 0.8710 - val_loss: 0.9577 - val_accuracy: 0.5806
# Epoch 99/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.4446 - accuracy: 0.8828
# Epoch 00099: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4499 - accuracy: 0.8763 - val_loss: 0.8748 - val_accuracy: 0.5323
# Epoch 100/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.4235 - accuracy: 0.8867
# Epoch 00100: val_loss did not improve from 0.85246
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4268 - accuracy: 0.8887 - val_loss: 0.8843 - val_accuracy: 0.5484

# %% [markdown]
# ## Visualization of Evaluation

# %%
##################################################################################
##### Add import statement here, to make this next part of code standalone executable
##################################################################################

import os
import pickle
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter
import numpy as np
import pandas as pd

# %%
##################################################################################
##### Load file and convert to dataframe for easy manipulation
##################################################################################

evalPath = os.path.join(outPath, expName, "_Evaluation_All_Datasets")
if(not os.path.isdir(evalPath)):
    os.makedirs(evalPath)

evaluations = pickle.load(open(os.path.join(evalPath, "{}fold_evaluations.pickle".format(n_fold)), "rb"))

evaluations_df = pd.DataFrame.from_dict(evaluations)

# %%
##################################################################################
##### Group dataset (mean of metrics) by [Dataset, Model, Train_Test] combinations
##################################################################################

evaluations_df_grouped = evaluations_df.groupby(["Dataset", 
                                                 "Model", 
                                                 "Train_Test"]).mean().filter(['Accuracy', 
                                                                               'Precision', 
                                                                               'AUC', 
                                                                               'Sensitivity', 
                                                                               'Specificity', 
                                                                               'MCC'])

# DLNN_3 = evaluations_df_grouped[np.in1d(evaluations_df_grouped.index.get_level_values(1), ['DLNN_3'])]
# DLNN_5 = evaluations_df_grouped[np.in1d(evaluations_df_grouped.index.get_level_values(1), ['DLNN_5'])]

# DLNN_3_Train = DLNN_3[np.in1d(DLNN_3.index.get_level_values(2), ['Train'])]
# DLNN_3_Test = DLNN_3[np.in1d(DLNN_3.index.get_level_values(2), ['Test'])]

# DLNN_5_Train = DLNN_5[np.in1d(DLNN_5.index.get_level_values(2), ['Train'])]
# DLNN_5_Test = DLNN_5[np.in1d(DLNN_5.index.get_level_values(2), ['Test'])]

# %%
evaluations_df
# Out:
#      Model  Kernel_Length Dataset  Fold Train_Test  Accuracy  Precision  \
# 0   HS_990              3  HS_990     0      Train  0.983165   0.988636
# 1   HS_990              3  HS_990     0       Test  0.565657   0.589744
# 2   HS_990              3  HS_990     1      Train  0.978676   0.981900
# 3   HS_990              3  HS_990     1       Test  0.616162   0.625000
# 4   HS_990              3  HS_990     2      Train  0.970819   0.956427
# 5   HS_990              3  HS_990     2       Test  0.535354   0.538462
# 6   HS_990              3  HS_990     3      Train  0.966330   0.983683
# 7   HS_990              3  HS_990     3       Test  0.595960   0.592593
# 8   HS_990              3  HS_990     4      Train  0.973064   0.986143
# 9   HS_990              3  HS_990     4       Test  0.676768   0.714286
# 10  HS_990              3  HS_990     5      Train  0.971942   0.960613
# 11  HS_990              3  HS_990     5       Test  0.595960   0.581818
# 12  HS_990              3  HS_990     6      Train  0.974186   0.981777
# 13  HS_990              3  HS_990     6       Test  0.464646   0.458333
# 14  HS_990              3  HS_990     7      Train  0.979798   0.977679
# 15  HS_990              3  HS_990     7       Test  0.525253   0.520000
# 16  HS_990              3  HS_990     8      Train  0.985410   0.984340
# 17  HS_990              3  HS_990     8       Test  0.555556   0.547170
# 18  HS_990              3  HS_990     9      Train  0.980920   0.988610
# 19  HS_990              3  HS_990     9       Test  0.565657   0.571429
# 20  MM_944              3  MM_944     0      Train  0.957597   0.944954
# 21  MM_944              3  MM_944     0       Test  0.652632   0.653061
# 22  MM_944              3  MM_944     1      Train  0.967020   0.958333
# 23  MM_944              3  MM_944     1       Test  0.600000   0.583333
# 24  MM_944              3  MM_944     2      Train  0.976443   0.976471
# 25  MM_944              3  MM_944     2       Test  0.757895   0.740000
# 26  MM_944              3  MM_944     3      Train  0.970554   0.971698
# 27  MM_944              3  MM_944     3       Test  0.621053   0.603774
# 28  MM_944              3  MM_944     4      Train  0.972941   0.963134
# 29  MM_944              3  MM_944     4       Test  0.648936   0.645833
# 30  MM_944              3  MM_944     5      Train  0.972941   0.965278
# 31  MM_944              3  MM_944     5       Test  0.553191   0.567568
# 32  MM_944              3  MM_944     6      Train  0.963529   0.958140
# 33  MM_944              3  MM_944     6       Test  0.670213   0.633333
# 34  MM_944              3  MM_944     7      Train  0.971765   0.967366
# 35  MM_944              3  MM_944     7       Test  0.659574   0.647059
# 36  MM_944              3  MM_944     8      Train  0.975294   0.959091
# 37  MM_944              3  MM_944     8       Test  0.734043   0.677419
# 38  MM_944              3  MM_944     9      Train  0.969412   0.971631
# 39  MM_944              3  MM_944     9       Test  0.648936   0.675000
# 40  SN_628              3  SN_628     0      Train  0.996460   1.000000
# 41  SN_628              3  SN_628     0       Test  0.698413   0.709677
# 42  SN_628              3  SN_628     1      Train  0.996460   0.996454
# 43  SN_628              3  SN_628     1       Test  0.603175   0.606061
# 44  SN_628              3  SN_628     2      Train  0.998230   0.996466
# 45  SN_628              3  SN_628     2       Test  0.634921   0.600000
# 46  SN_628              3  SN_628     3      Train  0.994690   0.992933
# 47  SN_628              3  SN_628     3       Test  0.523810   0.526316
# 48  SN_628              3  SN_628     4      Train  0.996460   0.992982
# 49  SN_628              3  SN_628     4       Test  0.650794   0.636364
# 50  SN_628              3  SN_628     5      Train  0.994690   1.000000
# 51  SN_628              3  SN_628     5       Test  0.698413   0.687500
# 52  SN_628              3  SN_628     6      Train  0.991150   0.982639
# 53  SN_628              3  SN_628     6       Test  0.523810   0.512195
# 54  SN_628              3  SN_628     7      Train  1.000000   1.000000
# 55  SN_628              3  SN_628     7       Test  0.603175   0.593750
# 56  SN_628              3  SN_628     8      Train  0.991166   0.989437
# 57  SN_628              3  SN_628     8       Test  0.596774   0.588235
# 58  SN_628              3  SN_628     9      Train  0.994700   0.996454
# 59  SN_628              3  SN_628     9       Test  0.548387   0.540541
#
#                                                   TPR  \
# 0   [0.0, 0.0022471910112359553, 0.849438202247191...
# 1   [0.0, 0.02, 0.02, 0.08, 0.08, 0.1, 0.1, 0.3, 0...
# 2   [0.0, 0.0022471910112359553, 0.696629213483146...
# 3   [0.0, 0.02, 0.02, 0.04, 0.04, 0.08, 0.08, 0.14...
# 4   [0.0, 0.0022471910112359553, 0.768539325842696...
# 5   [0.0, 0.02, 0.02, 0.04, 0.04, 0.12, 0.12, 0.14...
# 6   [0.0, 0.0022471910112359553, 0.730337078651685...
# 7   [0.0, 0.02, 0.06, 0.06, 0.08, 0.08, 0.1, 0.1, ...
# 8   [0.0, 0.0022471910112359553, 0.923595505617977...
# 9   [0.0, 0.02, 0.06, 0.06, 0.08, 0.08, 0.12, 0.12...
# 10  [0.0, 0.002242152466367713, 0.6165919282511211...
# 11  [0.0, 0.02040816326530612, 0.16326530612244897...
# 54     [1.9869524, 0.9869524, 0.6143668, 0.019014226]  1.000000     1.000000
# 55  [1.9882123, 0.9882124, 0.86691564, 0.86382, 0....  0.646169     0.612903
# 56  [1.9890132, 0.9890132, 0.66109186, 0.6521284, ...  0.999788     0.992908
# 57  [1.9877534, 0.98775345, 0.93165123, 0.9168251,...  0.580645     0.607143
# 58  [1.9909482, 0.99094814, 0.62585515, 0.57502615...  0.999888     0.992958
# 59  [1.9782047, 0.9782048, 0.9620213, 0.95299405, ...  0.635796     0.560000
#
#     Specificity       MCC
# 0      0.988636  0.966390
# 1      0.589744  0.136570
# 2      0.981900  0.957373
# 3      0.625000  0.232748
# 4      0.956427  0.942106
# 5      0.538462  0.070290
# 6      0.983683  0.933259
# 7      0.592593  0.191805
# 8      0.986143  0.946470
# 9      0.714286  0.359231
# 10     0.960613  0.944170
# 11     0.581818  0.194254
# 12     0.981777  0.948491
# 13     0.458333 -0.071049
# 14     0.977679  0.959605
# 15     0.520000  0.050612
# 16     0.984340  0.970822
# 17     0.547170  0.112112
# 18     0.988610  0.961960
# 19     0.571429  0.131305
# 20     0.944954  0.915563
# 21     0.653061  0.305100
# 22     0.958333  0.934207
# 23     0.583333  0.204447
# 24     0.976471  0.952886
# 25     0.740000  0.517089
# 26     0.971698  0.941110
# 27     0.603774  0.244985
# 28     0.963134  0.946095
# 29     0.645833  0.297940
# 30     0.965278  0.946011
# 31     0.567568  0.108876
# 32     0.958140  0.927123
# 33     0.633333  0.354246
# 34     0.967366  0.943571
# 35     0.647059  0.320311
# 36     0.959091  0.951181
# 37     0.677419  0.493915
# 38     0.971631  0.938834
# 39     0.675000  0.301232
# 40     1.000000  0.992945
# 41     0.709677  0.397177
# 42     0.996454  0.992920
# 43     0.606061  0.205853
# 44     0.996466  0.996466
# 45     0.600000  0.291167
# 46     0.992933  0.989387
# 47     0.526316  0.045325
# 48     0.992982  0.992945
# 49     0.636364  0.302725
# 50     1.000000  0.989436
# 51     0.687500  0.397177
# 52     0.982639  0.982454
# 53     0.512195  0.054972
# 54     1.000000  1.000000
# 55     0.593750  0.206653
# 56     0.989437  0.982338
# 57     0.588235  0.194461
# 58     0.996454  0.989405
# 59     0.540541  0.098639

# %%
evaluations_df_grouped
# Out:
#                            Accuracy  Precision       AUC  Sensitivity  \
# Dataset Model  Train_Test
# HS_990  HS_990 Test        0.569697   0.573883  0.599510     0.568034
#                Train       0.976431   0.978981  0.997319     0.974292
# MM_944  MM_944 Test        0.654647   0.642638  0.696256     0.678051
#                Train       0.969750   0.963610  0.995736     0.976202
# SN_628  SN_628 Test        0.608167   0.600064  0.653801     0.623157
#                Train       0.995401   0.994737  0.999941     0.996124
#
#                            Specificity       MCC
# Dataset Model  Train_Test
# HS_990  HS_990 Test           0.573883  0.140788
#                Train          0.978981  0.953064
# MM_944  MM_944 Test           0.642638  0.314814
#                Train          0.963610  0.939658
# SN_628  SN_628 Test           0.600064  0.219415
#                Train          0.994737  0.990830

# %%
evaluations_df_max = evaluations_df[["Dataset",
                                     "Model",
                                     "Train_Test",
                                     "Accuracy",
                                     "Precision",
                                     "Sensitivity",
                                     "Specificity",
                                     "AUC",
                                     "MCC"]].groupby(["Dataset", 
                                                      "Model", 
                                                      "Train_Test"]).max().filter(['Accuracy', 
                                                                               'Precision', 
                                                                               'AUC', 
                                                                               'Sensitivity', 
                                                                               'Specificity', 
                                                                               'MCC']).reset_index()

evaluations_df_test_max = evaluations_df_max[evaluations_df_max["Train_Test"] == 'Test']
evaluations_df_test_max
# Out:
#   Dataset   Model Train_Test  Accuracy  Precision       AUC  Sensitivity  \
# 0  HS_990  HS_990       Test  0.676768   0.714286  0.704898     0.649123
# 2  MM_944  MM_944       Test  0.757895   0.740000  0.764599     0.843750
# 4  SN_628  SN_628       Test  0.698413   0.709677  0.780242     0.722222
#
#    Specificity       MCC
# 0     0.714286  0.359231
# 2     0.740000  0.517089
# 4     0.709677  0.397177

# %%
evaluations_df5 = evaluations_df.sort_values(['Accuracy'], ascending=False).groupby(["Dataset", 
                                                                                    "Model", 
                                                                                    "Train_Test"]).head(5).reset_index()

evaluations_df5_grouped = evaluations_df5.groupby(["Dataset", 
                                                 "Model", 
                                                 "Train_Test"]).mean().filter(['Accuracy', 
                                                                               'Precision', 
                                                                               'AUC', 
                                                                               'Sensitivity', 
                                                                               'Specificity', 
                                                                               'MCC']).reset_index()

# %%
evaluations_df5_grouped[evaluations_df5_grouped["Train_Test"] == 'Test']
# Out:
#   Dataset   Model Train_Test  Accuracy  Precision       AUC  Sensitivity  \
# 0  HS_990  HS_990       Test  0.610101   0.617025  0.633388     0.606401
# 2  MM_944  MM_944       Test  0.694871   0.670175  0.738851     0.736683
# 4  SN_628  SN_628       Test  0.657143   0.647920  0.699395     0.677213
#
#    Specificity       MCC
# 0     0.617025  0.221869
# 2     0.670175  0.398132
# 4     0.647920  0.318820

# %% [markdown]
# # Independent Testing

# %%
independent_data_folder = "Data\\Aziz_Ind"

# %%
##################################################################################
##### For each input file, train model and generate different outputs in a structured folder
##################################################################################

## create the evaluation data structure for all iterations
evaluations = {
    "Model" : [],
    "Dataset" : [],
    "Fold" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

sum_evaluations = {
    "Model" : [],
    "Dataset" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

vote_evaluations = {
    "Model" : [],
    "Dataset" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

for root, dirs, files in os.walk(independent_data_folder):
    for file in files:
        
        input_data_file = os.path.join(root, file)
        
        if 'HS' in file:
            bench_data = 'HS_990'
        elif 'SN' in file:
            bench_data = 'SN_628'
        else:
            raise ValueError('No benchmarking model trained.')
            
        current_dataset_variety = input_data_file.split("\\")[-1].split(".")[0]
        
        input_data_file = os.path.join(root, file)
        
        current_dataset_variety = input_data_file.split("\\")[-1].split(".")[0]
        
        csv_data = pd.read_csv(input_data_file)

        ##################################################################################
        ##### extract data from the current CSV file
        ##################################################################################

        csv_data["OHE_MergedSeq"] = pd.Series([one_hot_encode_rna_mergedseq(val) for val in csv_data["MergedSeq"]])

        df_positive = csv_data[csv_data['Number'].str.contains("P")]
        df_negative = csv_data[csv_data['Number'].str.contains("N")]

        positive_onehotencoded_array = np.array(list(df_positive['OHE_MergedSeq']))
        negative_onehotencoded_array = np.array(list(df_negative['OHE_MergedSeq']))

        print("\n======================================================================")
        print("\nFile:", input_data_file)
        print("Positive:", positive_onehotencoded_array.shape[0])
        print("Negative:", negative_onehotencoded_array.shape[0])

        ##################################################################################
        ##### Generate Folds from dataset, and store to file
        ##################################################################################

        ## create the features and labels datasets for the training
        input_size = positive_onehotencoded_array[0].shape

        labels = np.concatenate((np.ones((positive_onehotencoded_array.shape[0], 1), 
                                         dtype=np.float32), 
                                 np.zeros((negative_onehotencoded_array.shape[0], 1), 
                                          dtype=np.float32)), 
                                axis=0)

        features = np.concatenate((positive_onehotencoded_array, 
                                   negative_onehotencoded_array), 
                                  axis=0)
        
        benchModelPath = os.path.join(outPath, expName, bench_data, "{}fold".format(n_fold), "models")
            
        ##################################################################################
        ##### TRAIN and PREDICT for every Fold, using models
        ##################################################################################
        
        y_pred_list = []

        for fold in range(n_fold):

            print("\nIndependent test on "+current_dataset_variety+" using Fold #"+str(fold)+" model from "+bench_data+".")
            
            current_model_path = os.path.join(
                benchModelPath, 
                "{}_bestModel-fold{}.hdf5".format(bench_data, fold)
            )
            
            model = tf.keras.models.load_model(current_model_path)

            ##################################################################################
            ##### Prediction and metrics for TEST dataset
            ##################################################################################
            
            y_pred = model.predict(features)
            y_pred_list.append(y_pred)
            label_pred = pred2label(y_pred)
            # Compute precision, recall, sensitivity, specifity, mcc
            acc = accuracy_score(labels, label_pred)
            prec = precision_score(labels,label_pred)

            conf = confusion_matrix(labels, label_pred)
            if(conf[0][0]+conf[1][0]):
                sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
            else:
                sens = 0.0
            if(conf[1][1]+conf[0][1]):
                spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
            else:
                spec = 0.0
            if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
                mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
            else:
                mcc= 0.0
            fpr, tpr, thresholds = roc_curve(labels, y_pred)
            auc = roc_auc_score(labels, y_pred)

            evaluations["Model"].append(current_dataset_variety)
            evaluations["Dataset"].append(current_dataset_variety)
            evaluations["Fold"].append(i)
            evaluations["Accuracy"].append(acc)
            evaluations["Precision"].append(prec)
            evaluations["TPR"].append(tpr)
            evaluations["FPR"].append(fpr)
            evaluations["TPR_FPR_Thresholds"].append(thresholds)
            evaluations["AUC"].append(auc)
            evaluations["Sensitivity"].append(sens)
            evaluations["Specificity"].append(spec)
            evaluations["MCC"].append(mcc)

            del model
            tf.keras.backend.clear_session()
            
        ##################################################################################
        ##### Prediction and metrics using sum of all folds
        ##################################################################################
        
        y_pred_list_arr = np.swapaxes(np.array(y_pred_list), 0,1)
        y_pred_vote = np.mean(y_pred_list_arr, axis = 1)
        label_vote = pred2label(y_pred_vote)
        
        # Compute precision, recall, sensitivity, specifity, mcc
        acc = accuracy_score(labels, label_vote)
        prec = precision_score(labels, label_vote)

        conf = confusion_matrix(labels, label_vote)
        if(conf[0][0]+conf[1][0]):
            sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
        else:
            sens = 0.0
        if(conf[1][1]+conf[0][1]):
            spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
        else:
            spec = 0.0
        if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
            mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
        else:
            mcc= 0.0
        fpr, tpr, thresholds = roc_curve(labels, y_pred_vote)
        auc = roc_auc_score(labels, y_pred_vote)
        
        sum_evaluations["Model"].append(current_dataset_variety)
        sum_evaluations["Dataset"].append(current_dataset_variety)
        sum_evaluations["Accuracy"].append(acc)
        sum_evaluations["Precision"].append(prec)
        sum_evaluations["TPR"].append(tpr)
        sum_evaluations["FPR"].append(fpr)
        sum_evaluations["TPR_FPR_Thresholds"].append(thresholds)
        sum_evaluations["AUC"].append(auc)
        sum_evaluations["Sensitivity"].append(sens)
        sum_evaluations["Specificity"].append(spec)
        sum_evaluations["MCC"].append(mcc)
        
        ##################################################################################
        ##### Prediction and metrics using vote of all folds
        ##################################################################################
        
        y_pred_list_arr = np.swapaxes(np.array(y_pred_list), 0,1)
        y_pred_vote = np.sum(np.round(y_pred_list_arr), axis = 1)
        label_vote = (y_pred_vote > 5).astype(int)
        
        # Compute precision, recall, sensitivity, specifity, mcc
        acc = accuracy_score(labels, label_vote)
        prec = precision_score(labels, label_vote)

        conf = confusion_matrix(labels, label_vote)
        if(conf[0][0]+conf[1][0]):
            sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
        else:
            sens = 0.0
        if(conf[1][1]+conf[0][1]):
            spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
        else:
            spec = 0.0
        if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
            mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
        else:
            mcc= 0.0
        fpr, tpr, thresholds = roc_curve(labels, y_pred_vote)
        auc = roc_auc_score(labels, y_pred_vote)

        vote_evaluations["Model"].append(current_dataset_variety)
        vote_evaluations["Dataset"].append(current_dataset_variety)
        vote_evaluations["Accuracy"].append(acc)
        vote_evaluations["Precision"].append(prec)
        vote_evaluations["TPR"].append(tpr)
        vote_evaluations["FPR"].append(fpr)
        vote_evaluations["TPR_FPR_Thresholds"].append(thresholds)
        vote_evaluations["AUC"].append(auc)
        vote_evaluations["Sensitivity"].append(sens)
        vote_evaluations["Specificity"].append(spec)
        vote_evaluations["MCC"].append(mcc)
        
        ##################################################################################
        ##### Dump evaluations to a file
        ##################################################################################

        evalPath = os.path.join(outPath, expName, "_Evaluation_Independent_Datasets")
        if(not os.path.isdir(evalPath)):
            os.makedirs(evalPath)

        pickle.dump(evaluations,
                    open(os.path.join(evalPath, "{}fold_evaluations.pickle".format(n_fold)), "wb"))
        
        pickle.dump(sum_evaluations,
                    open(os.path.join(evalPath, "{}fold_sum_evaluations.pickle".format(n_fold)), "wb"))
        
        pickle.dump(vote_evaluations,
                    open(os.path.join(evalPath, "{}fold_vote_evaluations.pickle".format(n_fold)), "wb"))
# Out:
# ======================================================================
#
# File: Data\Aziz_Ind\HS_200.csv
# Positive: 100
# Negative: 100
#
# Independent test on HS_200 using Fold #0 model from HS_990.
#
# Independent test on HS_200 using Fold #1 model from HS_990.
#
# Independent test on HS_200 using Fold #2 model from HS_990.
#
# Independent test on HS_200 using Fold #3 model from HS_990.
#
# Independent test on HS_200 using Fold #4 model from HS_990.
#
# Independent test on HS_200 using Fold #5 model from HS_990.
#
# Independent test on HS_200 using Fold #6 model from HS_990.
#
# Independent test on HS_200 using Fold #7 model from HS_990.
#
# Independent test on HS_200 using Fold #8 model from HS_990.
#
# Independent test on HS_200 using Fold #9 model from HS_990.
#
# ======================================================================
#
# File: Data\Aziz_Ind\SN_200.csv
# Positive: 100
# Negative: 100
#
# Independent test on SN_200 using Fold #0 model from SN_628.
#
# Independent test on SN_200 using Fold #1 model from SN_628.
#
# Independent test on SN_200 using Fold #2 model from SN_628.
#
# Independent test on SN_200 using Fold #3 model from SN_628.
#
# Independent test on SN_200 using Fold #4 model from SN_628.
#
# Independent test on SN_200 using Fold #5 model from SN_628.
#
# Independent test on SN_200 using Fold #6 model from SN_628.
#
# Independent test on SN_200 using Fold #7 model from SN_628.
#
# Independent test on SN_200 using Fold #8 model from SN_628.
#
# Independent test on SN_200 using Fold #9 model from SN_628.

# %% [markdown]
# ## Predict using each fold, average result of all 10 folds

# %%
evaluations_df = pd.DataFrame.from_dict(evaluations)

evaluations_df_grouped = evaluations_df.groupby(["Dataset", 
                                                 "Model"]).mean().filter(['Accuracy', 
                                                                           'Precision', 
                                                                           'AUC', 
                                                                           'Sensitivity', 
                                                                           'Specificity', 
                                                                           'MCC'])

# %%
evaluations_df_grouped
# Out:
#                 Accuracy  Precision      AUC  Sensitivity  Specificity  \
# Dataset Model
# HS_200  HS_200     0.618   0.613222  0.66479     0.625643     0.613222
# SN_200  SN_200     0.670   0.649927  0.73771     0.700807     0.649927
#
#                      MCC
# Dataset Model
# HS_200  HS_200  0.237413
# SN_200  SN_200  0.345273

# %%
#                 Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# Dataset	Model						
# HS_200	HS_200	0.6750	0.664200	0.72708	0.693586	0.664200	0.353822
# SS_200	SS_200	0.6975	0.674367	0.76201	0.731014	0.674367	0.400129

# %% [markdown]
# ## Predict using 1 fold, average result of top 5 folds

# %%
evaluations_df5 = evaluations_df.sort_values(['Accuracy'],ascending=False).groupby(["Dataset", 
                                                                                    "Model"]).head(5).reset_index()

evaluations_df5_grouped = evaluations_df5.groupby(["Dataset", 
                                                   "Model"]).mean().filter(['Accuracy', 
                                                                            'Precision', 
                                                                            'AUC', 
                                                                            'Sensitivity', 
                                                                            'Specificity', 
                                                                            'MCC']).reset_index()

# %%
evaluations_df5_grouped
# Out:
#   Dataset   Model  Accuracy  Precision      AUC  Sensitivity  Specificity  \
# 0  HS_200  HS_200     0.634   0.632214  0.66870     0.636857     0.632214
# 1  SN_200  SN_200     0.690   0.668568  0.74996     0.725537     0.668568
#
#         MCC
# 0  0.268535
# 1  0.386893

# %%
# 	Dataset	Model	Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# 0	HS_200	HS_200	0.690	0.690418	0.72364	0.690651	0.690418	0.380534
# 1	SS_200	SS_200	0.714	0.695143	0.76684	0.738915	0.695143	0.431015

# %% [markdown]
# ## Predict using all 10 folds, vote using sum of scores of all 10 folds

# %%
sum_evaluations_df = pd.DataFrame.from_dict(sum_evaluations)

sum_evaluations_df.filter(["Dataset", "Model", 'Accuracy', 'Precision', 'AUC', 'Sensitivity', 'Specificity', 'MCC'])
# Out:
#   Dataset   Model  Accuracy  Precision     AUC  Sensitivity  Specificity  \
# 0  HS_200  HS_200     0.645   0.638095  0.6872     0.652632     0.638095
# 1  SN_200  SN_200     0.710   0.684211  0.7616     0.744186     0.684211
#
#         MCC
# 0  0.290363
# 1  0.424178

# %%
# 	Dataset	Model	Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# 0	HS_200	HS_200	0.695	0.685714	0.7445	0.705263	0.685714	0.390488
# 1	SS_200	SS_200	0.705	0.672269	0.7873	0.753086	0.672269	0.417607

# %% [markdown]
# ## Predict using all 10 folds, vote using absolute vote of all 10 folds

# %%
vote_evaluations_df = pd.DataFrame.from_dict(vote_evaluations)

vote_evaluations_df.filter(["Dataset", "Model", 'Accuracy', 'Precision', 'AUC', 'Sensitivity', 'Specificity', 'MCC'])
# Out:
#   Dataset   Model  Accuracy  Precision     AUC  Sensitivity  Specificity  \
# 0  HS_200  HS_200     0.635   0.631068  0.6720     0.639175     0.631068
# 1  SN_200  SN_200     0.705   0.681416  0.7491     0.735632     0.681416
#
#         MCC
# 0  0.270122
# 1  0.413509

# %%
##################################################################################
##### Define all parameters for model tuning
##################################################################################

n_fold = 10
expName = "PSI_Site_DLNN_Custom_word2vec"
outPath = "Results"
foldName = "folds.pickle"

# modelNames = ["DLNN_3", "DLNN_5"]

epochs = 50
batch_size = 16
shuffle = False
seed = None

input_kmer_data_folder = "Data\\Psi_Site_Chen_Word2vec"

# %%
import os 
from Bio import SeqIO
import pickle
import numpy as np
import pandas as pd

import tensorflow as tf

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc, accuracy_score, precision_score, confusion_matrix
from sklearn.metrics import roc_auc_score

import math

# %%
# print(tf.test.is_gpu_available(cuda_only=True))
# physical_devices = tf.config.experimental.list_physical_devices('GPU')
physical_devices = tf.config.list_physical_devices('GPU')
print(physical_devices)
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ##################################################################################
# ##### define all CUSTOM functions
# ##################################################################################

# def one_hot_encode_dna(sequence):
    
#     seq_encoded = np.zeros((len(sequence),4))
#     dict_nuc = {
#         "A": 0,
#         "C": 1,
#         "G": 2,
#         "T":3
#     }
#     i = 0
    
#     for single_character in sequence:
#         if(single_character.upper() in dict_nuc.keys()):
#             seq_encoded[i][dict_nuc[single_character.upper()]] = 1
#             i = i+1
#         else:
#             return []
    
#     return seq_encoded

# def one_hot_encode_rna(sequence):
    
#     seq_encoded = np.zeros((len(sequence),4))
#     dict_nuc = {
#         "A": 0,
#         "C": 1,
#         "G": 2,
#         "U":3
#     }
#     i = 0
    
#     for single_character in sequence:
#         if(single_character.upper() in dict_nuc.keys()):
#             seq_encoded[i][dict_nuc[single_character.upper()]] = 1
#             i = i+1
#         else:
#             return []
    
#     return seq_encoded

# %%
##################################################################################
##### define evaluator functions
##################################################################################

## Build the K-fold from dataset
def build_kfold(features, labels, k=10, shuffle=False, seed=None):
    
    skf = StratifiedKFold(n_splits=k, shuffle=shuffle, random_state=seed)
    kfoldList = []
    for train_index, test_index in skf.split(features, labels):
        X_train, X_test = features[train_index], features[test_index]
        y_train, y_test = labels[train_index], labels[test_index]
        kfoldList.append({
            "X_train": X_train,
            "X_test": X_test,
            "y_train":y_train,
            "y_test":y_test
        })
    return kfoldList

def pred2label(y_pred):
    y_pred = np.round(np.clip(y_pred, 0, 1))
    return y_pred

# %%
##################################################################################
##### Function to customize the DLNN architecture with parameters
##################################################################################

def DLNN_custom_word2vec(input_shape = (64,),
                         dense_decode_units = 100, ## Dense layer parameters
                         prob = 0.25, learn_rate = 0.01, loss = 'binary_crossentropy', 
                         metrics = None):
    
    input1 = tf.keras.layers.Input(shape=input_shape)

    ##### LSTM Path
    #########################

#     x1 = tf.keras.layers.LSTM(lstm_decode_units, return_sequences = True)(input1)
#     x1 = tf.keras.layers.LSTM(1, return_sequences = True)(x1)
#     x1 = tf.keras.layers.Dropout(prob)(x1)
    
#     x1 = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(lstm_decode_units, return_sequences=True,
#                                                            kernel_regularizer = tf.keras.regularizers.l2(beta)))(input1)
    
#     model.add(Bidirectional(tf.keras.layers.LSTM(21)))
    
#     x1 = tf.keras.layers.Flatten()(x1)
#     x1 = tf.keras.layers.Dropout(prob)(x1)

    ##### Multipath Conv
    #########################
    
#     x2 = []
#     for kernel_length in range(2,max_kernel_length):
        

#         xx = tf.keras.layers.Conv1D(conv_filters_per_layer, kernel_length, strides = conv_strides,
#                                     kernel_regularizer = tf.keras.regularizers.l2(beta))(input1)
#         xx = tf.keras.layers.Activation('relu')(xx)
#         xx = tf.keras.layers.Flatten()(xx)
#         xx = tf.keras.layers.Dropout(prob)(xx)
        
#         x2.append(xx)
#     x2 = tf.keras.layers.MaxPooling1D(pool_size = max_pool_width, strides = max_pool_stride)(x2)
#     x2 = tf.keras.layers.Dropout(prob)(x2)

    ##### Fully connected Layers
    #########################
    
    y1 = tf.keras.layers.BatchNormalization()(input1)
    y1 = tf.keras.layers.Dense(dense_decode_units)(y1)
#     y1 = tf.keras.layers.Dropout(prob)(y1)
#     y1 = tf.keras.layers.BatchNormalization()(y1)
    y1 = tf.keras.layers.Dense(dense_decode_units*2)(y1)
#     y1 = tf.keras.layers.Dropout(prob)(y1)
    y1 = tf.keras.layers.Dense(dense_decode_units)(y1)
#     y1 = tf.keras.layers.Dropout(prob)(y1)
    y1 = tf.keras.layers.Dense(dense_decode_units/2)(y1)
#     x1 = tf.keras.layers.Dropout(prob)(y1)
    y1 = tf.keras.layers.Dense(1, activation = 'sigmoid')(y1)
#     y1 = tf.keras.layers.Dropout(prob)(y1)

#     y1 = tf.keras.layers.Dense(dense_decode_units)(y1)
    
#     y1 = tf.keras.layers.Dense(dense_decode_units/2)(y1)
#     y1 = tf.keras.layers.Dropout(prob)(y1)
    
#     y1 = tf.keras.layers.Dense(1, activation = 'sigmoid')(y1)
#     y1 = tf.keras.layers.Dense(1, activation = 'sigmoid')(y1)

    ##### Generate Model from input and output
    #########################
    
    model = tf.keras.models.Model(inputs=[input1], outputs=y1)
    
    ## Compile model
    if(metrics != None):
        model.compile(optimizer = tf.keras.optimizers.Adam(lr=learn_rate), loss = loss, metrics = metrics)
    else:
        model.compile(optimizer = tf.keras.optimizers.Adam(lr=learn_rate), loss = loss)

    return model

# %%
DLNN_custom_word2vec().summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64)]              0
# _________________________________________________________________
# dense (Dense)                (None, 50)                3250
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               5100
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               20200
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 54,151
# Trainable params: 53,951
# Non-trainable params: 200
# _________________________________________________________________

# %%
##################################################################################
##### For each input file, train model and generate different outputs in a structured folder
##################################################################################

## create the evaluation data structure for all iterations
evaluations = {
    "Model" : [],
    "Kmer" : [],
    "Dataset" : [],
    "Fold" : [],
    "Train_Test" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

# %%
kmer_input_folders = list(set([x[0] for x in os.walk(input_kmer_data_folder)])-set([input_kmer_data_folder]))

for input_data_folder in kmer_input_folders:
    
    current_kmer = int(input_data_folder.split("\\")[-1][0])
    
    for root, dirs, files in os.walk(input_data_folder):
        for file in files:

            input_data_file = os.path.join(root, file)

            current_dataset_variety = file.split("\\")[-1].split(".")[0]

            ##################################################################################
            ##### extract data from the related embedding file
            ##################################################################################

            embedding = pd.read_csv(input_data_file)
            embedding = embedding.rename(columns={"Unnamed: 0" : "name"})
            embedding["class"] = pd.Series([1 if "P" in val else 0 for val in list(embedding["name"])])

            print("\n======================================================================")
            print("\nFile:", input_data_file)
            print("Positive:", embedding[embedding["class"] == 1].shape[0])
            print("Negative:", embedding[embedding["class"] == 0].shape[0])

            ##################################################################################
            ##### Generate Folds from dataset, and store to file
            ##################################################################################

            ## create the features and labels datasets for the training
            labels = np.array(embedding["class"])
            features = np.array(embedding.drop("name", axis=1).drop("class", axis=1))
            input_size = features[0].shape

            ## Generate the k-fold dataset
            folds = build_kfold(features, labels, k=n_fold, shuffle=shuffle, seed=seed)

            ## Write the k-fold dataset to file
            foldPath = os.path.join(outPath, expName, current_dataset_variety, "{}fold".format(n_fold))
            if(not os.path.isdir(foldPath)):
                os.makedirs(foldPath)
            pickle.dump(folds, open(os.path.join(foldPath, foldName), "wb"))

            ## Create and set directory to save model
            modelPath = os.path.join(outPath, expName, current_dataset_variety, "{}fold".format(n_fold), "models")
            if(not os.path.isdir(modelPath)):
                os.makedirs(modelPath)

            ##################################################################################
            ##### TRAIN and PREDICT for every Fold, using models
            ##################################################################################

            # fold counter
            i = 0

            for fold in folds:

                print("\nTrain/Test model "+current_dataset_variety+" on Fold #"+str(i)+".")

                kernel_length = 3
                ## Generate model using function
    #             model = Conv_LSTM_DLNN(input_shape = input_size, conv_filters_per_layer = 50, kernel_length = kernel_length, 
    #                                    lstm_decode_units = 50, max_pool_width = 2, max_pool_stride = 2, dense_decode_units = 50,
    #                                    learn_rate = 0.0001, prob = 0.5, loss='binary_crossentropy', metrics=None)

                model = DLNN_custom_word2vec(input_shape = input_size)

    #             ## Define the model callbacks for early stopping and saving the model. Then train model
    #             modelCallbacks = [
    #                 tf.keras.callbacks.ModelCheckpoint(os.path.join(modelPath, "{}_bestModel-fold{}.hdf5".format(current_dataset_variety, i)),
    #                                                    monitor = 'val_loss', verbose = 0, save_best_only = True, 
    #                                                    save_weights_only = False, mode = 'auto', save_freq = 'epoch'),
    #                 tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', min_delta = 0, patience = 10, verbose = 0, 
    #                                                  mode = 'auto', baseline = None, restore_best_weights = False)
    #             ]
    #             model.fit(x = fold["X_train"], y = fold["y_train"], batch_size = batch_size, epochs = epochs, verbose = 0, 
    #                       callbacks = modelCallbacks, validation_split=0.2)

                model.fit(x = fold["X_train"], y = fold["y_train"], 
                          batch_size = batch_size, epochs = epochs, 
                          verbose = 1, 
                          validation_split=0.2)

                ##################################################################################
                ##### Prediction and metrics for TRAIN dataset
                ##################################################################################

                y_pred = model.predict(fold["X_train"])
                label_pred = pred2label(y_pred)
                # Compute precision, recall, sensitivity, specifity, mcc
                acc = accuracy_score(fold["y_train"], label_pred)
                prec = precision_score(fold["y_train"],label_pred)

                conf = confusion_matrix(fold["y_train"], label_pred)
                if(conf[0][0]+conf[1][0]):
                    sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
                else:
                    sens = 0.0
                if(conf[1][1]+conf[0][1]):
                    spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
                else:
                    spec = 0.0
                if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
                    mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
                else:
                    mcc= 0.0
                fpr, tpr, thresholds = roc_curve(fold["y_train"], y_pred)
                auc = roc_auc_score(fold["y_train"], y_pred)

                evaluations["Model"].append(current_dataset_variety)
                evaluations["Kmer"].append(current_kmer)
                evaluations["Dataset"].append(current_dataset_variety)
                evaluations["Fold"].append(i)
                evaluations["Train_Test"].append("Train")
                evaluations["Accuracy"].append(acc)
                evaluations["Precision"].append(prec)
                evaluations["TPR"].append(tpr)
                evaluations["FPR"].append(fpr)
                evaluations["TPR_FPR_Thresholds"].append(thresholds)
                evaluations["AUC"].append(auc)
                evaluations["Sensitivity"].append(sens)
                evaluations["Specificity"].append(spec)
                evaluations["MCC"].append(mcc)

                ##################################################################################
                ##### Prediction and metrics for TEST dataset
                ##################################################################################

                y_pred = model.predict(fold["X_test"])
                label_pred = pred2label(y_pred)
                # Compute precision, recall, sensitivity, specifity, mcc
                acc = accuracy_score(fold["y_test"], label_pred)
                prec = precision_score(fold["y_test"],label_pred)

                conf = confusion_matrix(fold["y_test"], label_pred)
                if(conf[0][0]+conf[1][0]):
                    sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
                else:
                    sens = 0.0
                if(conf[1][1]+conf[0][1]):
                    spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
                else:
                    spec = 0.0
                if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
                    mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
                else:
                    mcc= 0.0
                fpr, tpr, thresholds = roc_curve(fold["y_test"], y_pred)
                auc = roc_auc_score(fold["y_test"], y_pred)

                evaluations["Model"].append(current_dataset_variety)
                evaluations["Kmer"].append(current_kmer)
                evaluations["Dataset"].append(current_dataset_variety)
                evaluations["Fold"].append(i)
                evaluations["Train_Test"].append("Test")
                evaluations["Accuracy"].append(acc)
                evaluations["Precision"].append(prec)
                evaluations["TPR"].append(tpr)
                evaluations["FPR"].append(fpr)
                evaluations["TPR_FPR_Thresholds"].append(thresholds)
                evaluations["AUC"].append(auc)
                evaluations["Sensitivity"].append(sens)
                evaluations["Specificity"].append(spec)
                evaluations["MCC"].append(mcc)

                i = i+1
                del model
                tf.keras.backend.clear_session()

            ##################################################################################
            ##### Dump evaluations to a file
            ##################################################################################

            evalPath = os.path.join(outPath, expName, "_Evaluation_All_Datasets")
            if(not os.path.isdir(evalPath)):
                os.makedirs(evalPath)

            pickle.dump(evaluations,
                        open(os.path.join(evalPath, "{}fold_evaluations.pickle".format(n_fold)), "wb"))
# Out:
# ======================================================================
#
# File: Data\Psi_Site_Chen_Word2vec\3mer\HS_990.csv
# Positive: 495
# Negative: 495
#
# Train/Test model HS_990 on Fold #0.
# Epoch 1/50
# 45/45 [==============================] - 0s 7ms/step - loss: 0.6945 - val_loss: 0.9432
# Epoch 2/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6646 - val_loss: 1.1643
# Epoch 3/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6652 - val_loss: 8.9991
# Epoch 4/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6582 - val_loss: 64.2424
# Epoch 5/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6690 - val_loss: 13.9401
# Epoch 6/50
# 45/45 [==============================] - 0s 3ms/step - loss: 0.6586 - val_loss: 3.3776
# Epoch 7/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6644 - val_loss: 0.0575
# Epoch 8/50
# 45/45 [==============================] - 0s 3ms/step - loss: 0.6697 - val_loss: 14.0014
# Epoch 9/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6675 - val_loss: 2.4440e-07
# Epoch 10/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6641 - val_loss: 5.6539
# Epoch 11/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6555 - val_loss: 1.3389e-20
# Epoch 12/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6558 - val_loss: 704.2137
# Epoch 13/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6536 - val_loss: 2425.3413
# Epoch 14/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6475 - val_loss: 149.1335
# Epoch 15/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6550 - val_loss: 63.4695
# Epoch 16/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6635 - val_loss: 319.1818
# Epoch 17/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6640 - val_loss: 0.0000e+00
# Epoch 18/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6542 - val_loss: 4.6541e-07
# Epoch 19/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6473 - val_loss: 0.0000e+00
# Epoch 20/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6691 - val_loss: 0.0000e+00
# Epoch 21/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6692 - val_loss: 109.9784
# Epoch 22/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6606 - val_loss: 0.0000e+00
# Epoch 23/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6578 - val_loss: 0.0000e+00
# Epoch 24/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6460 - val_loss: 0.0000e+00
# Epoch 25/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6612 - val_loss: 18.2456
# Epoch 26/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6505 - val_loss: 1304.4977
# Epoch 27/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6502 - val_loss: 772.1069
# Epoch 28/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6433 - val_loss: 742.7798
# Epoch 29/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6470 - val_loss: 0.0000e+00
# Epoch 30/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6569 - val_loss: 19.7103
# Epoch 31/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6525 - val_loss: 1124.1394
# Epoch 32/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6589 - val_loss: 6.2588
# Epoch 33/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6439 - val_loss: 0.0000e+00
# Epoch 34/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6509 - val_loss: 5.9341e-17
# Epoch 35/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6560 - val_loss: 0.0000e+00
# Epoch 36/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6662 - val_loss: 1548.3810
# Epoch 37/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6516 - val_loss: 5441.6250
# Epoch 38/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6497 - val_loss: 0.0000e+00
# Epoch 39/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6619 - val_loss: 0.0000e+00
# Epoch 40/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6766 - val_loss: 0.0000e+00
# Epoch 41/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6571 - val_loss: 0.0000e+00
# Epoch 42/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6476 - val_loss: 1.6547e-27
# Epoch 43/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6465 - val_loss: 0.0000e+00
# Epoch 44/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6565 - val_loss: 0.0000e+00
# Epoch 45/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6531 - val_loss: 0.0000e+00
# Epoch 46/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6503 - val_loss: 0.0000e+00
# Epoch 47/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6485 - val_loss: 0.0000e+00
# Epoch 48/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6454 - val_loss: 6484.3589
# Epoch 49/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6417 - val_loss: 1816.5439
# Epoch 50/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6437 - val_loss: 968.2612
#
# Train/Test model HS_990 on Fold #1.
# Epoch 1/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6726 - val_loss: 1.0999
# Epoch 2/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6681 - val_loss: 1.6270
# Epoch 3/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6659 - val_loss: 0.6954
# Epoch 4/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6634 - val_loss: 5.5840
# Epoch 5/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6556 - val_loss: 25.7107
# Epoch 6/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6614 - val_loss: 1.2110e-21
# Epoch 7/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6774 - val_loss: 8.1654e-14
# Epoch 8/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6796 - val_loss: 0.0028
# Epoch 9/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6625 - val_loss: 77.4089
# Epoch 10/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6498 - val_loss: 46.2216
# Epoch 11/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6612 - val_loss: 114.5281
# Epoch 12/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6451 - val_loss: 41.0946
# Epoch 13/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6534 - val_loss: 1265.2389
# Epoch 14/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6377 - val_loss: 3121.2395
# Epoch 15/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6521 - val_loss: 578.2910
# Epoch 16/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6438 - val_loss: 13128.0420
# Epoch 17/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6680 - val_loss: 964.8265
# Epoch 18/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6621 - val_loss: 0.0000e+00
# Epoch 19/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6708 - val_loss: 267.8962
# Epoch 20/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6692 - val_loss: 0.0000e+00
# Epoch 21/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6524 - val_loss: 0.0000e+00
# Epoch 22/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6583 - val_loss: 0.0000e+00
# Epoch 23/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6491 - val_loss: 58.4418
# Epoch 24/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6495 - val_loss: 194.6362
# Epoch 25/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6564 - val_loss: 1.8221e-09
# Epoch 26/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6461 - val_loss: 1090.6481
# Epoch 27/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6527 - val_loss: 5115.5522
# Epoch 28/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6386 - val_loss: 6669.3008
# Epoch 29/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6476 - val_loss: 457.5445
# Epoch 30/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6611 - val_loss: 0.0000e+00
# Epoch 31/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6567 - val_loss: 0.0000e+00
# Epoch 32/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6687 - val_loss: 0.0000e+00
# Epoch 33/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6574 - val_loss: 0.0000e+00
# Epoch 34/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6487 - val_loss: 0.0000e+00
# Epoch 35/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6420 - val_loss: 290.5947
# Epoch 36/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6420 - val_loss: 210.9114
# Epoch 37/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6442 - val_loss: 0.0000e+00
# Epoch 38/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6370 - val_loss: 3.8035e-20
# Epoch 39/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6347 - val_loss: 0.0000e+00
# Epoch 40/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6426 - val_loss: 0.0000e+00
# Epoch 41/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6437 - val_loss: 0.0000e+00
# Epoch 42/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6353 - val_loss: 0.0000e+00
# Epoch 43/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6401 - val_loss: 0.0000e+00
# Epoch 44/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6378 - val_loss: 0.0000e+00
# Epoch 45/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6391 - val_loss: 0.0000e+00
# Epoch 46/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6337 - val_loss: 0.0000e+00
# Epoch 47/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6344 - val_loss: 732.9223
# Epoch 48/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6300 - val_loss: 0.0000e+00
# Epoch 49/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6371 - val_loss: 2171.3975
# Epoch 50/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6435 - val_loss: 2212.2205
#
# Train/Test model HS_990 on Fold #2.
# Epoch 1/50
# 45/45 [==============================] - 0s 7ms/step - loss: 0.6798 - val_loss: 0.8055
# Epoch 2/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6667 - val_loss: 0.8687
# Epoch 3/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6752 - val_loss: 1.2021
# Epoch 4/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6659 - val_loss: 0.9630
# Epoch 5/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6720 - val_loss: 0.6986
# Epoch 6/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6670 - val_loss: 1.2692
# Epoch 7/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6630 - val_loss: 0.8313
# Epoch 8/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6633 - val_loss: 1.6802
# Epoch 9/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6628 - val_loss: 0.0697
# Epoch 10/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6625 - val_loss: 7.4452e-09
# Epoch 11/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6628 - val_loss: 58.1213
# Epoch 12/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6625 - val_loss: 5.2685
# Epoch 13/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6688 - val_loss: 0.0000e+00
# Epoch 14/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6783 - val_loss: 83.5031
# Epoch 15/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6739 - val_loss: 0.0000e+00
# Epoch 16/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6706 - val_loss: 1.2190e-04
# Epoch 17/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6743 - val_loss: 6.0166
# Epoch 18/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6559 - val_loss: 188.1193
# Epoch 19/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6511 - val_loss: 665.4520
# Epoch 20/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6469 - val_loss: 1.3167e-18
# Epoch 21/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6498 - val_loss: 0.0000e+00
# Epoch 22/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6466 - val_loss: 1243.9944
# Epoch 23/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6474 - val_loss: 632.4496
# Epoch 24/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6477 - val_loss: 300.8473
# Epoch 25/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6516 - val_loss: 64.0370
# Epoch 26/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6517 - val_loss: 0.0000e+00
# Epoch 27/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6568 - val_loss: 0.0000e+00
# Epoch 28/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6469 - val_loss: 165.1934
# Epoch 29/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6507 - val_loss: 10.0257
# Epoch 30/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6581 - val_loss: 0.0000e+00
# Epoch 31/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6727 - val_loss: 0.0000e+00
# Epoch 32/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.7441 - val_loss: 0.0000e+00
# Epoch 33/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6593 - val_loss: 0.0000e+00
# Epoch 34/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6475 - val_loss: 0.0000e+00
# Epoch 35/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6557 - val_loss: 7.5662e-30
# Epoch 36/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6606 - val_loss: 0.0000e+00
# Epoch 37/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6520 - val_loss: 1.7659e-34
# Epoch 38/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6458 - val_loss: 126.0172
# Epoch 39/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6587 - val_loss: 2.3371e-23
# Epoch 40/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6610 - val_loss: 7.4883e-18
# Epoch 41/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6546 - val_loss: 0.2343
# Epoch 42/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6615 - val_loss: 12.8398
# Epoch 43/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6608 - val_loss: 418.2155
# Epoch 44/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6545 - val_loss: 38.2650
# Epoch 45/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6546 - val_loss: 65.6415
# Epoch 46/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6586 - val_loss: 45.8978
# Epoch 47/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6571 - val_loss: 134.3420
# Epoch 48/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6519 - val_loss: 1414.0262
# Epoch 49/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6515 - val_loss: 1654.8905
# Epoch 50/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6601 - val_loss: 2.4967
#
# Train/Test model HS_990 on Fold #3.
# Epoch 1/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6813 - val_loss: 0.9565
# Epoch 2/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6760 - val_loss: 0.8678
# Epoch 3/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6692 - val_loss: 1.0636
# Epoch 4/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6646 - val_loss: 0.9719
# Epoch 5/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6670 - val_loss: 1.6861
# Epoch 6/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6684 - val_loss: 1.0222
# Epoch 7/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6637 - val_loss: 0.9244
# Epoch 8/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6626 - val_loss: 1.0946
# Epoch 9/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6632 - val_loss: 0.9459
# Epoch 10/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6622 - val_loss: 1.1007
# Epoch 11/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6636 - val_loss: 1.0282
# Epoch 12/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6622 - val_loss: 1.1571
# Epoch 13/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6624 - val_loss: 1.5057
# Epoch 14/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6625 - val_loss: 4.5283
# Epoch 15/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6604 - val_loss: 0.0000e+00
# Epoch 16/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.7707 - val_loss: 2702.9907
# Epoch 17/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.7499 - val_loss: 1918.0378
# Epoch 18/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6621 - val_loss: 5895.9512
# Epoch 19/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6413 - val_loss: 10356.0400
# Epoch 20/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6461 - val_loss: 0.0000e+00
# Epoch 21/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6381 - val_loss: 0.0000e+00
# Epoch 22/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6389 - val_loss: 0.0000e+00
# Epoch 23/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6322 - val_loss: 0.0000e+00
# Epoch 24/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6439 - val_loss: 0.0000e+00
# Epoch 25/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6373 - val_loss: 0.0000e+00
# Epoch 26/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6408 - val_loss: 0.0000e+00
# Epoch 27/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6367 - val_loss: 0.0000e+00
# Epoch 28/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6348 - val_loss: 364.5688
# Epoch 29/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6316 - val_loss: 0.0000e+00
# Epoch 30/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6350 - val_loss: 0.0000e+00
# Epoch 31/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6356 - val_loss: 2760.3257
# Epoch 32/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6321 - val_loss: 1188.8763
# Epoch 33/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6374 - val_loss: 1223.5638
# Epoch 34/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6374 - val_loss: 431.8658
# Epoch 35/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6244 - val_loss: 0.0000e+00
# Epoch 36/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6287 - val_loss: 0.0000e+00
# Epoch 37/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6229 - val_loss: 0.0000e+00
# Epoch 38/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6396 - val_loss: 886.3616
# Epoch 39/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6328 - val_loss: 1021.0595
# Epoch 40/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6288 - val_loss: 0.0000e+00
# Epoch 41/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6360 - val_loss: 0.0000e+00
# Epoch 42/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6348 - val_loss: 430.4218
# Epoch 43/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6358 - val_loss: 1391.3442
# Epoch 44/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6294 - val_loss: 3034.0732
# Epoch 45/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6281 - val_loss: 0.0000e+00
# Epoch 46/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6354 - val_loss: 0.0000e+00
# Epoch 47/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6350 - val_loss: 0.0000e+00
# Epoch 48/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6415 - val_loss: 0.0000e+00
# Epoch 49/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6313 - val_loss: 0.0000e+00
# Epoch 50/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6344 - val_loss: 0.0000e+00
#
# Train/Test model HS_990 on Fold #4.
# Epoch 1/50
# C:\Users\arya3\.conda\envs\base_tf_24\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\arya3\.conda\envs\base_tf_24\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 45/45 [==============================] - 0s 7ms/step - loss: 0.7122 - val_loss: 0.7651
# Epoch 2/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6800 - val_loss: 0.8193
# Epoch 3/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6653 - val_loss: 0.9875
# Epoch 4/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6664 - val_loss: 0.8542
# Epoch 5/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6661 - val_loss: 0.8994
# Epoch 6/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6643 - val_loss: 0.8948
# Epoch 7/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6648 - val_loss: 0.8802
# Epoch 8/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6636 - val_loss: 1.0099
# Epoch 9/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6625 - val_loss: 0.9859
# Epoch 10/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6631 - val_loss: 1.0172
# Epoch 11/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6621 - val_loss: 0.9824
# Epoch 12/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6622 - val_loss: 0.9475
# Epoch 13/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6623 - val_loss: 0.9569
# Epoch 14/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6623 - val_loss: 0.7449
# Epoch 15/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6645 - val_loss: 2.4294
# Epoch 16/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6630 - val_loss: 0.7505
# Epoch 17/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6623 - val_loss: 0.8251
# Epoch 18/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6624 - val_loss: 0.8622
# Epoch 19/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6624 - val_loss: 0.7103
# Epoch 20/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6638 - val_loss: 16.6180
# Epoch 21/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6641 - val_loss: 0.2459
# Epoch 22/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6628 - val_loss: 0.0000e+00
# Epoch 23/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6598 - val_loss: 0.0000e+00
# Epoch 24/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6578 - val_loss: 0.0000e+00
# Epoch 25/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6572 - val_loss: 0.0000e+00
# Epoch 26/50
# 45/45 [==============================] - 0s 4ms/step - loss: 1.0558 - val_loss: 0.0000e+00
# Epoch 27/50
# 45/45 [==============================] - 0s 4ms/step - loss: 1.0547 - val_loss: 0.0000e+00
# Epoch 28/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6756 - val_loss: 0.0000e+00
# Epoch 29/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6436 - val_loss: 0.0000e+00
# Epoch 30/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6465 - val_loss: 0.0000e+00
# Epoch 31/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6552 - val_loss: 0.0000e+00
# Epoch 32/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6460 - val_loss: 0.0000e+00
# Epoch 33/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6500 - val_loss: 0.0000e+00
# Epoch 34/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6510 - val_loss: 0.0000e+00
# Epoch 35/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6466 - val_loss: 0.0000e+00
# Epoch 36/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6409 - val_loss: 0.0000e+00
# Epoch 37/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6450 - val_loss: 0.0000e+00
# Epoch 38/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6467 - val_loss: 0.0000e+00
# Epoch 39/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6423 - val_loss: 0.0000e+00
# Epoch 40/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6473 - val_loss: 0.0000e+00
# Epoch 41/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6458 - val_loss: 0.0000e+00
# Epoch 42/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6473 - val_loss: 0.0000e+00
# Epoch 43/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6461 - val_loss: 0.0000e+00
# Epoch 44/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6467 - val_loss: 0.0000e+00
# Epoch 45/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6431 - val_loss: 0.0000e+00
# Epoch 46/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6403 - val_loss: 0.0000e+00
# Epoch 47/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6480 - val_loss: 0.0000e+00
# Epoch 48/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6432 - val_loss: 3204.2954
# Epoch 49/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6395 - val_loss: 6781.3979
# Epoch 50/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6389 - val_loss: 2.0150e-08
#
# Train/Test model HS_990 on Fold #5.
# C:\Users\arya3\.conda\envs\base_tf_24\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\arya3\.conda\envs\base_tf_24\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6854 - val_loss: 0.8782
# Epoch 2/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6740 - val_loss: 0.8369
# Epoch 3/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6662 - val_loss: 1.0520
# Epoch 4/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6633 - val_loss: 0.7912
# Epoch 5/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6596 - val_loss: 8.6497
# Epoch 6/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6579 - val_loss: 29.7928
# Epoch 7/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6607 - val_loss: 128.3413
# Epoch 8/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6629 - val_loss: 0.0000e+00
# Epoch 9/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6473 - val_loss: 5.0569e-27
# Epoch 10/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6546 - val_loss: 8.6981e-15
# Epoch 11/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6574 - val_loss: 114.5469
# Epoch 12/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6579 - val_loss: 42.9658
# Epoch 13/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6521 - val_loss: 558.0514
# Epoch 14/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6566 - val_loss: 0.0000e+00
# Epoch 15/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6560 - val_loss: 4.3500e-13
# Epoch 16/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6559 - val_loss: 0.0000e+00
# Epoch 17/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6756 - val_loss: 0.0000e+00
# Epoch 18/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6526 - val_loss: 0.0000e+00
# Epoch 19/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6429 - val_loss: 0.0000e+00
# Epoch 20/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6728 - val_loss: 0.0319
# Epoch 21/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6587 - val_loss: 6.7606e-07
# Epoch 22/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6438 - val_loss: 0.0000e+00
# Epoch 23/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6452 - val_loss: 0.0000e+00
# Epoch 24/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6462 - val_loss: 0.0000e+00
# Epoch 25/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6452 - val_loss: 972.5296
# Epoch 26/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6468 - val_loss: 1354.5493
# Epoch 27/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6540 - val_loss: 81.6576
# Epoch 28/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6502 - val_loss: 0.0000e+00
# Epoch 29/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6463 - val_loss: 0.0000e+00
# Epoch 30/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6353 - val_loss: 0.0000e+00
# Epoch 31/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6482 - val_loss: 0.0000e+00
# Epoch 32/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6552 - val_loss: 0.0000e+00
# Epoch 33/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6606 - val_loss: 0.0000e+00
# Epoch 34/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6514 - val_loss: 0.0000e+00
# Epoch 35/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6503 - val_loss: 96.9487
# Epoch 36/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6438 - val_loss: 0.0000e+00
# Epoch 37/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6357 - val_loss: 613.4703
# Epoch 38/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6360 - val_loss: 2181.1392
# Epoch 39/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6388 - val_loss: 1186.5748
# Epoch 40/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6396 - val_loss: 60.7960
# Epoch 41/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6306 - val_loss: 2355.6729
# Epoch 42/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6437 - val_loss: 0.0000e+00
# Epoch 43/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6602 - val_loss: 0.0000e+00
# Epoch 44/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6539 - val_loss: 0.0000e+00
# Epoch 45/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6366 - val_loss: 4.8162e-06
# Epoch 46/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6476 - val_loss: 205.1135
# Epoch 47/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6411 - val_loss: 0.0000e+00
# Epoch 48/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6427 - val_loss: 579.4711
# Epoch 49/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6430 - val_loss: 347.0297
# Epoch 50/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6377 - val_loss: 0.0000e+00
#
# Train/Test model HS_990 on Fold #6.
# Epoch 1/50
# C:\Users\arya3\.conda\envs\base_tf_24\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\arya3\.conda\envs\base_tf_24\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6732 - val_loss: 0.7838
# Epoch 2/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6742 - val_loss: 0.8529
# Epoch 3/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6643 - val_loss: 2.4865
# Epoch 4/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6649 - val_loss: 0.9653
# Epoch 5/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6628 - val_loss: 0.8964
# Epoch 6/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6643 - val_loss: 0.9205
# Epoch 7/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6684 - val_loss: 0.8981
# Epoch 8/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6678 - val_loss: 0.9875
# Epoch 9/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6667 - val_loss: 1.0681
# Epoch 10/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6682 - val_loss: 0.5621
# Epoch 11/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6680 - val_loss: 1.9763
# Epoch 12/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6626 - val_loss: 0.5532
# Epoch 13/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6625 - val_loss: 0.5183
# Epoch 14/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6622 - val_loss: 42.2975
# Epoch 15/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6677 - val_loss: 2.3434e-10
# Epoch 16/50
# 45/45 [==============================] - 0s 4ms/step - loss: 1.3328 - val_loss: 0.0000e+00
# Epoch 17/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6971 - val_loss: 1623.1243
# Epoch 18/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6683 - val_loss: 241.8097
# Epoch 19/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6461 - val_loss: 0.0000e+00
# Epoch 20/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6433 - val_loss: 0.0000e+00
# Epoch 21/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6495 - val_loss: 0.0000e+00
# Epoch 22/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6545 - val_loss: 0.0000e+00
# Epoch 23/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6457 - val_loss: 0.0000e+00
# Epoch 24/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6461 - val_loss: 466.7891
# Epoch 25/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6409 - val_loss: 785.9537
# Epoch 26/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6508 - val_loss: 0.0000e+00
# Epoch 27/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6420 - val_loss: 0.0000e+00
# Epoch 28/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6419 - val_loss: 5373.8926
# Epoch 29/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6462 - val_loss: 2548.6338
# Epoch 30/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6435 - val_loss: 876.0944
# Epoch 31/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6509 - val_loss: 1082.1123
# Epoch 32/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6411 - val_loss: 1242.5410
# Epoch 33/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6377 - val_loss: 1545.9199
# Epoch 34/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6453 - val_loss: 0.0000e+00
# Epoch 35/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6376 - val_loss: 0.0000e+00
# Epoch 36/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6457 - val_loss: 0.0000e+00
# Epoch 37/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6421 - val_loss: 0.0000e+00
# Epoch 38/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6430 - val_loss: 0.0000e+00
# Epoch 39/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6408 - val_loss: 745.6792
# Epoch 40/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6424 - val_loss: 935.2169
# Epoch 41/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6465 - val_loss: 595.0056
# Epoch 42/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6476 - val_loss: 858.0051
# Epoch 43/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6461 - val_loss: 0.0000e+00
# Epoch 44/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6478 - val_loss: 0.0000e+00
# Epoch 45/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6535 - val_loss: 0.0000e+00
# Epoch 46/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6482 - val_loss: 0.0000e+00
# Epoch 47/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6552 - val_loss: 2153.0845
# Epoch 48/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6461 - val_loss: 1319.6438
# Epoch 49/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6447 - val_loss: 1361.2670
# Epoch 50/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6417 - val_loss: 810.6012
#
# Train/Test model HS_990 on Fold #7.
# Epoch 1/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6762 - val_loss: 1.0918
# Epoch 2/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6668 - val_loss: 0.9767
# Epoch 3/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6628 - val_loss: 0.9951
# Epoch 4/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6723 - val_loss: 1.0678
# Epoch 5/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6686 - val_loss: 0.8542
# Epoch 6/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6654 - val_loss: 1.1103
# Epoch 7/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6657 - val_loss: 0.6060
# Epoch 8/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6623 - val_loss: 0.9617
# Epoch 9/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6644 - val_loss: 1.0820
# Epoch 10/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6659 - val_loss: 0.2102
# Epoch 11/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6656 - val_loss: 0.9868
# Epoch 12/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6617 - val_loss: 1.1983
# Epoch 13/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6623 - val_loss: 3.3037
# Epoch 14/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6618 - val_loss: 0.9247
# Epoch 15/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6617 - val_loss: 1.0737
# Epoch 16/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6611 - val_loss: 2.5892
# Epoch 17/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6623 - val_loss: 7.6618
# Epoch 18/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6607 - val_loss: 261.2967
# Epoch 19/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6822 - val_loss: 1.9755e-25
# Epoch 20/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.7315 - val_loss: 0.0000e+00
# Epoch 21/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6788 - val_loss: 119.3859
# Epoch 22/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6607 - val_loss: 0.0000e+00
# Epoch 23/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6505 - val_loss: 99.8036
# Epoch 24/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6482 - val_loss: 1028.9110
# Epoch 25/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6500 - val_loss: 8.6972e-30
# Epoch 26/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6487 - val_loss: 0.0000e+00
# Epoch 27/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6502 - val_loss: 0.0000e+00
# Epoch 28/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6577 - val_loss: 12.1313
# Epoch 29/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6563 - val_loss: 0.0000e+00
# Epoch 30/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6445 - val_loss: 787.9008
# Epoch 31/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6508 - val_loss: 1.2261e-16
# Epoch 32/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6564 - val_loss: 0.0000e+00
# Epoch 33/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6512 - val_loss: 0.0000e+00
# Epoch 34/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6552 - val_loss: 7.4377
# Epoch 35/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6554 - val_loss: 5.3130e-18
# Epoch 36/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6518 - val_loss: 88.7406
# Epoch 37/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6446 - val_loss: 677.5766
# Epoch 38/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6519 - val_loss: 0.0000e+00
# Epoch 39/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6496 - val_loss: 0.0000e+00
# Epoch 40/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6485 - val_loss: 0.0000e+00
# Epoch 41/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6527 - val_loss: 0.0000e+00
# Epoch 42/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6491 - val_loss: 0.0000e+00
# Epoch 43/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6439 - val_loss: 0.0000e+00
# Epoch 44/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6488 - val_loss: 0.0000e+00
# Epoch 45/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6645 - val_loss: 593.1346
# Epoch 46/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6589 - val_loss: 4020.4097
# Epoch 47/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6497 - val_loss: 8286.8604
# Epoch 48/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6585 - val_loss: 127.4251
# Epoch 49/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6499 - val_loss: 444.6446
# Epoch 50/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6473 - val_loss: 61.8088
#
# Train/Test model HS_990 on Fold #8.
# Epoch 1/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.7052 - val_loss: 0.9444
# Epoch 2/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6682 - val_loss: 0.9674
# Epoch 3/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6639 - val_loss: 0.9265
# Epoch 4/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6639 - val_loss: 0.8114
# Epoch 5/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6614 - val_loss: 1.0816
# Epoch 6/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6653 - val_loss: 0.9715
# Epoch 7/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6680 - val_loss: 0.9435
# Epoch 8/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6662 - val_loss: 0.7819
# Epoch 9/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6665 - val_loss: 1.0645
# Epoch 10/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6648 - val_loss: 0.9048
# Epoch 11/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6630 - val_loss: 0.9225
# Epoch 12/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6624 - val_loss: 1.3962
# Epoch 13/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6622 - val_loss: 0.7081
# Epoch 14/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6620 - val_loss: 0.9623
# Epoch 15/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6626 - val_loss: 1.0377
# Epoch 16/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6622 - val_loss: 0.5520
# Epoch 17/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6653 - val_loss: 1.0166
# Epoch 18/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6625 - val_loss: 0.5787
# Epoch 19/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6614 - val_loss: 0.9511
# Epoch 20/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6616 - val_loss: 1.1254
# Epoch 21/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6613 - val_loss: 0.0262
# Epoch 22/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6618 - val_loss: 0.0866
# Epoch 23/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6646 - val_loss: 0.1377
# Epoch 24/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6630 - val_loss: 0.0043
# Epoch 25/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6679 - val_loss: 143.0668
# Epoch 26/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6654 - val_loss: 0.0000e+00
# Epoch 27/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6649 - val_loss: 1.7413e-21
# Epoch 28/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6675 - val_loss: 281.2740
# Epoch 29/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.7539 - val_loss: 2177.9329
# Epoch 30/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6823 - val_loss: 390.4789
# Epoch 31/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6608 - val_loss: 856.4519
# Epoch 32/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6532 - val_loss: 3196.8523
# Epoch 33/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6554 - val_loss: 404.5545
# Epoch 34/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6511 - val_loss: 0.0000e+00
# Epoch 35/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6520 - val_loss: 0.0000e+00
# Epoch 36/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6548 - val_loss: 0.0000e+00
# Epoch 37/50
# 45/45 [==============================] - 0s 3ms/step - loss: 0.6581 - val_loss: 0.0000e+00
# Epoch 38/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6551 - val_loss: 0.0000e+00
# Epoch 39/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6541 - val_loss: 0.0000e+00
# Epoch 40/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6555 - val_loss: 3164.7859
# Epoch 41/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6500 - val_loss: 2740.4500
# Epoch 42/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6554 - val_loss: 265.0624
# Epoch 43/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6564 - val_loss: 172.6864
# Epoch 44/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6550 - val_loss: 1682.0649
# Epoch 45/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6555 - val_loss: 0.0000e+00
# Epoch 46/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6481 - val_loss: 0.0000e+00
# Epoch 47/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6482 - val_loss: 0.0000e+00
# Epoch 48/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6492 - val_loss: 0.0000e+00
# Epoch 49/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6570 - val_loss: 0.0000e+00
# Epoch 50/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6503 - val_loss: 451.7211
#
# Train/Test model HS_990 on Fold #9.
# Epoch 1/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6808 - val_loss: 0.9134
# ...
# Epoch 49/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6632 - val_loss: 0.2584
# Epoch 50/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6595 - val_loss: 18.5128
#
# Train/Test model HS_990 on Fold #6.
# Epoch 1/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6715 - val_loss: 1.3118
# Epoch 2/50
# 45/45 [==============================] - 0s 7ms/step - loss: 0.6691 - val_loss: 1.6813
# Epoch 3/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6780 - val_loss: 0.2449
# Epoch 4/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6633 - val_loss: 1.3982
# Epoch 5/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6678 - val_loss: 5.1341
# Epoch 6/50
# 45/45 [==============================] - 0s 3ms/step - loss: 0.6674 - val_loss: 1.7468
# Epoch 7/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6617 - val_loss: 2.1609
# Epoch 8/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6600 - val_loss: 14.0808
# Epoch 9/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6599 - val_loss: 1.1583
# Epoch 10/50
# 45/45 [==============================] - 0s 7ms/step - loss: 0.6629 - val_loss: 0.6576
# Epoch 11/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6612 - val_loss: 0.0563
# Epoch 12/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6612 - val_loss: 0.0026
# Epoch 13/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6601 - val_loss: 3.6901
# Epoch 14/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6620 - val_loss: 0.7470
# Epoch 15/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6625 - val_loss: 0.0988
# Epoch 16/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6617 - val_loss: 0.0151
# Epoch 17/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6632 - val_loss: 13.5152
# Epoch 18/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6670 - val_loss: 4.1632
# Epoch 19/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6662 - val_loss: 7.7693e-05
# Epoch 20/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6625 - val_loss: 0.0012
# Epoch 21/50
# 45/45 [==============================] - 0s 9ms/step - loss: 0.6625 - val_loss: 0.0605
# Epoch 22/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6619 - val_loss: 0.8529
# Epoch 23/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6617 - val_loss: 1.0165
# Epoch 24/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6634 - val_loss: 4.4191e-04
# Epoch 25/50
# 45/45 [==============================] - 0s 7ms/step - loss: 0.6638 - val_loss: 1.5321
# Epoch 26/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6627 - val_loss: 7.1603
# Epoch 27/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6623 - val_loss: 0.8701
# Epoch 28/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6614 - val_loss: 7.1641e-05
# Epoch 29/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6652 - val_loss: 8.1270e-22
# Epoch 30/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6837 - val_loss: 1.9771e-24
# Epoch 31/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6825 - val_loss: 17.3341
# Epoch 32/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6682 - val_loss: 1.5532e-06
# Epoch 33/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6658 - val_loss: 25.1324
# Epoch 34/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6645 - val_loss: 23.1923
# Epoch 35/50
# 45/45 [==============================] - 0s 8ms/step - loss: 0.6611 - val_loss: 69.3661
# Epoch 36/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6744 - val_loss: 45.0607
# Epoch 37/50
# 45/45 [==============================] - 0s 7ms/step - loss: 0.6748 - val_loss: 6.6252
# Epoch 38/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6659 - val_loss: 0.2009
# Epoch 39/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6623 - val_loss: 0.4463
# Epoch 40/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6619 - val_loss: 1.7457
# Epoch 41/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6618 - val_loss: 0.7328
# Epoch 42/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6635 - val_loss: 12.3661
# Epoch 43/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6623 - val_loss: 2.3885
# Epoch 44/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6612 - val_loss: 12.7544
# Epoch 45/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6616 - val_loss: 0.7471
# Epoch 46/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6613 - val_loss: 9.0519
# Epoch 47/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6627 - val_loss: 9.4240
# Epoch 48/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6621 - val_loss: 18.6399
# Epoch 49/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6673 - val_loss: 0.0037
# Epoch 50/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6907 - val_loss: 1.7146e-30
#
# Train/Test model HS_990 on Fold #7.
# Epoch 1/50
# C:\Users\arya3\.conda\envs\base_tf_24\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\arya3\.conda\envs\base_tf_24\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 45/45 [==============================] - 0s 7ms/step - loss: 0.6933 - val_loss: 0.9113
# Epoch 2/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6683 - val_loss: 1.0723
# Epoch 3/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6627 - val_loss: 1.0150
# Epoch 4/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6629 - val_loss: 1.3021
# Epoch 5/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6656 - val_loss: 0.9903
# Epoch 6/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6624 - val_loss: 1.5027
# Epoch 7/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6632 - val_loss: 1.0257
# Epoch 8/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6642 - val_loss: 0.1597
# Epoch 9/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6628 - val_loss: 29.2711
# Epoch 10/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6619 - val_loss: 1.3660
# Epoch 11/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6643 - val_loss: 0.9423
# Epoch 12/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6588 - val_loss: 1.2378e-07
# Epoch 13/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6652 - val_loss: 9.3074e-05
# Epoch 14/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6637 - val_loss: 1.4686e-13
# Epoch 15/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6623 - val_loss: 4.2234e-30
# Epoch 16/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6594 - val_loss: 5.5729e-15
# Epoch 17/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6616 - val_loss: 4.1747
# Epoch 18/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6644 - val_loss: 0.0287
# Epoch 19/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6623 - val_loss: 0.5205
# Epoch 20/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6635 - val_loss: 24.0984
# Epoch 21/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6662 - val_loss: 1.0571
# Epoch 22/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6631 - val_loss: 0.0078
# Epoch 23/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6631 - val_loss: 0.2883
# Epoch 24/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6613 - val_loss: 0.0000e+00
# Epoch 25/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6635 - val_loss: 0.2431
# Epoch 26/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6599 - val_loss: 4.5736e-05
# Epoch 27/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6596 - val_loss: 1.0150
# Epoch 28/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6605 - val_loss: 6.5212
# Epoch 29/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6725 - val_loss: 1.2697e-11
# Epoch 30/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6672 - val_loss: 1.1648e-20
# Epoch 31/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6643 - val_loss: 31.7263
# Epoch 32/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6728 - val_loss: 2.0117e-18
# Epoch 33/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6789 - val_loss: 0.0000e+00
# Epoch 34/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6856 - val_loss: 0.0000e+00
# Epoch 35/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6729 - val_loss: 19.2016
# Epoch 36/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6624 - val_loss: 5.8668e-15
# Epoch 37/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6659 - val_loss: 10.8164
# Epoch 38/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6629 - val_loss: 59.6104
# Epoch 39/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6736 - val_loss: 1.1796e-14
# Epoch 40/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6634 - val_loss: 84.8623
# Epoch 41/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6675 - val_loss: 0.8009
# Epoch 42/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6680 - val_loss: 11.6410
# Epoch 43/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6743 - val_loss: 2.8502
# Epoch 44/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6655 - val_loss: 12.4948
# Epoch 45/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6627 - val_loss: 0.0258
# Epoch 46/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6611 - val_loss: 6.0497
# Epoch 47/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6613 - val_loss: 1.5516
# Epoch 48/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6606 - val_loss: 12.4718
# Epoch 49/50
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6626 - val_loss: 7.3155
# Epoch 50/50
# 36/45 [=======================>......] - ETA: 0s - loss: 0.6637
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ddec35ee5563> in <module>
#      81                           batch_size = batch_size, epochs = epochs,
#      82                           verbose = 1,
# ---> 83                           validation_split=0.2)
#      84
#      85                 ##################################################################################
#
# ~\.conda\envs\base_tf_24\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~\.conda\envs\base_tf_24\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     870               workers=workers,
#     871               use_multiprocessing=use_multiprocessing,
# --> 872               return_dict=True)
#     873           val_logs = {'val_' + name: val for name, val in val_logs.items()}
#     874           epoch_logs.update(val_logs)
#
# ~\.conda\envs\base_tf_24\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~\.conda\envs\base_tf_24\lib\site-packages\tensorflow\python\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1079                 step_num=step):
#    1080               callbacks.on_test_batch_begin(step)
# -> 1081               tmp_logs = test_function(iterator)
#    1082               # Catch OutOfRangeError for Datasets of unknown size.
#    1083               # This blocks until the batch has finished executing.
#
# ~\.conda\envs\base_tf_24\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~\.conda\envs\base_tf_24\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     616       # In this case we have not created variables on the first call. So we can
#     617       # run the first trace but we should fail if variables are created.
# --> 618       results = self._stateful_fn(*args, **kwds)
#     619       if self._created_variables:
#     620         raise ValueError("Creating variables on a non-first call to a function"
#
# ~\.conda\envs\base_tf_24\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~\.conda\envs\base_tf_24\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\.conda\envs\base_tf_24\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~\.conda\envs\base_tf_24\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~\.conda\envs\base_tf_24\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
# for root, dirs, files in os.walk(input_data_folder):
#     for file in files:
        
#         input_data_file = os.path.join(root, file)
        
#         current_dataset_variety = file.split("\\")[-1].split(".")[0]
        
#         ##################################################################################
#         ##### extract data from the related embedding file
#         ##################################################################################
        
#         embedding = pd.read_csv(input_data_file)
#         embedding = embedding.rename(columns={"Unnamed: 0" : "name"})
#         embedding["class"] = pd.Series([1 if "P" in val else 0 for val in list(embedding["name"])])
        
#         print("\n======================================================================")
#         print("\nFile:", input_data_file)
#         print("Positive:", embedding[embedding["class"] == 1].shape[0])
#         print("Negative:", embedding[embedding["class"] == 0].shape[0])
        
#         ##################################################################################
#         ##### Generate Folds from dataset, and store to file
#         ##################################################################################

#         ## create the features and labels datasets for the training
#         labels = np.array(embedding["class"])
#         features = np.array(embedding.drop("name", axis=1).drop("class", axis=1))
#         input_size = features[0].shape

#         ## Generate the k-fold dataset
#         folds = build_kfold(features, labels, k=n_fold, shuffle=shuffle, seed=seed)

#         ## Write the k-fold dataset to file
#         foldPath = os.path.join(outPath, expName, current_dataset_variety, "{}fold".format(n_fold))
#         if(not os.path.isdir(foldPath)):
#             os.makedirs(foldPath)
#         pickle.dump(folds, open(os.path.join(foldPath, foldName), "wb"))

#         ## Create and set directory to save model
#         modelPath = os.path.join(outPath, expName, current_dataset_variety, "{}fold".format(n_fold), "models")
#         if(not os.path.isdir(modelPath)):
#             os.makedirs(modelPath)
            
#         ##################################################################################
#         ##### TRAIN and PREDICT for every Fold, using models
#         ##################################################################################

#         # fold counter
#         i = 0

#         for fold in folds:

#             print("\nTrain/Test model "+current_dataset_variety+" on Fold #"+str(i)+".")

#             kernel_length = 3
#             ## Generate model using function
# #             model = Conv_LSTM_DLNN(input_shape = input_size, conv_filters_per_layer = 50, kernel_length = kernel_length, 
# #                                    lstm_decode_units = 50, max_pool_width = 2, max_pool_stride = 2, dense_decode_units = 50,
# #                                    learn_rate = 0.0001, prob = 0.5, loss='binary_crossentropy', metrics=None)

#             model = DLNN_custom_word2vec(input_shape = input_size)

# #             ## Define the model callbacks for early stopping and saving the model. Then train model
# #             modelCallbacks = [
# #                 tf.keras.callbacks.ModelCheckpoint(os.path.join(modelPath, "{}_bestModel-fold{}.hdf5".format(current_dataset_variety, i)),
# #                                                    monitor = 'val_loss', verbose = 0, save_best_only = True, 
# #                                                    save_weights_only = False, mode = 'auto', save_freq = 'epoch'),
# #                 tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', min_delta = 0, patience = 10, verbose = 0, 
# #                                                  mode = 'auto', baseline = None, restore_best_weights = False)
# #             ]
# #             model.fit(x = fold["X_train"], y = fold["y_train"], batch_size = batch_size, epochs = epochs, verbose = 0, 
# #                       callbacks = modelCallbacks, validation_split=0.2)

#             model.fit(x = fold["X_train"], y = fold["y_train"], 
#                       batch_size = batch_size, epochs = epochs, 
#                       verbose = 1, 
#                       validation_split=0.2)

#             ##################################################################################
#             ##### Prediction and metrics for TRAIN dataset
#             ##################################################################################

#             y_pred = model.predict(fold["X_train"])
#             label_pred = pred2label(y_pred)
#             # Compute precision, recall, sensitivity, specifity, mcc
#             acc = accuracy_score(fold["y_train"], label_pred)
#             prec = precision_score(fold["y_train"],label_pred)

#             conf = confusion_matrix(fold["y_train"], label_pred)
#             if(conf[0][0]+conf[1][0]):
#                 sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
#             else:
#                 sens = 0.0
#             if(conf[1][1]+conf[0][1]):
#                 spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
#             else:
#                 spec = 0.0
#             if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
#                 mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
#             else:
#                 mcc= 0.0
#             fpr, tpr, thresholds = roc_curve(fold["y_train"], y_pred)
#             auc = roc_auc_score(fold["y_train"], y_pred)

#             evaluations["Model"].append(current_dataset_variety)
#             evaluations["Kmer"].append(current_kmer)
#             evaluations["Dataset"].append(current_dataset_variety)
#             evaluations["Fold"].append(i)
#             evaluations["Train_Test"].append("Train")
#             evaluations["Accuracy"].append(acc)
#             evaluations["Precision"].append(prec)
#             evaluations["TPR"].append(tpr)
#             evaluations["FPR"].append(fpr)
#             evaluations["TPR_FPR_Thresholds"].append(thresholds)
#             evaluations["AUC"].append(auc)
#             evaluations["Sensitivity"].append(sens)
#             evaluations["Specificity"].append(spec)
#             evaluations["MCC"].append(mcc)

#             ##################################################################################
#             ##### Prediction and metrics for TEST dataset
#             ##################################################################################

#             y_pred = model.predict(fold["X_test"])
#             label_pred = pred2label(y_pred)
#             # Compute precision, recall, sensitivity, specifity, mcc
#             acc = accuracy_score(fold["y_test"], label_pred)
#             prec = precision_score(fold["y_test"],label_pred)

#             conf = confusion_matrix(fold["y_test"], label_pred)
#             if(conf[0][0]+conf[1][0]):
#                 sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
#             else:
#                 sens = 0.0
#             if(conf[1][1]+conf[0][1]):
#                 spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
#             else:
#                 spec = 0.0
#             if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
#                 mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
#             else:
#                 mcc= 0.0
#             fpr, tpr, thresholds = roc_curve(fold["y_test"], y_pred)
#             auc = roc_auc_score(fold["y_test"], y_pred)

#             evaluations["Model"].append(current_dataset_variety)
#             evaluations["Kmer"].append(current_kmer)
#             evaluations["Dataset"].append(current_dataset_variety)
#             evaluations["Fold"].append(i)
#             evaluations["Train_Test"].append("Test")
#             evaluations["Accuracy"].append(acc)
#             evaluations["Precision"].append(prec)
#             evaluations["TPR"].append(tpr)
#             evaluations["FPR"].append(fpr)
#             evaluations["TPR_FPR_Thresholds"].append(thresholds)
#             evaluations["AUC"].append(auc)
#             evaluations["Sensitivity"].append(sens)
#             evaluations["Specificity"].append(spec)
#             evaluations["MCC"].append(mcc)

#             i = i+1
#             del model
#             tf.keras.backend.clear_session()
            
#             raise ValueError("BLEH")

#         ##################################################################################
#         ##### Dump evaluations to a file
#         ##################################################################################

#         evalPath = os.path.join(outPath, expName, "_Evaluation_All_Datasets")
#         if(not os.path.isdir(evalPath)):
#             os.makedirs(evalPath)

#         pickle.dump(evaluations,
#                     open(os.path.join(evalPath, "{}fold_evaluations.pickle".format(n_fold)), "wb"))

# %% [markdown]
# ## Visualization of Evaluation

# %%
##################################################################################
##### Add import statement here, to make this next part of code standalone executable
##################################################################################

import os
import pickle
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter
import numpy as np
import pandas as pd

# %%
##################################################################################
##### Load file and convert to dataframe for easy manipulation
##################################################################################

evalPath = os.path.join(outPath, expName, "_Evaluation_All_Datasets")
if(not os.path.isdir(evalPath)):
    os.makedirs(evalPath)

evaluations = pickle.load(open(os.path.join(evalPath, "{}fold_evaluations.pickle".format(n_fold)), "rb"))

# %%
# evaluations["Model"] = evaluations["Model"][0:20]
# evaluations_df = pd.DataFrame.from_dict(evaluations)

# %%
evaluations_df = pd.DataFrame.from_dict(evaluations)

##################################################################################
##### Group dataset (mean of metrics) by [Dataset, Model, Train_Test] combinations
##################################################################################

evaluations_df_grouped = evaluations_df.groupby(["Dataset", 
                                                 "Model", 
                                                 "Kmer",
                                                 "Train_Test"]).mean().filter(['Accuracy', 
                                                                               'Precision', 
                                                                               'AUC', 
                                                                               'Sensitivity', 
                                                                               'Specificity', 
                                                                               'MCC'])

# DLNN_3 = evaluations_df_grouped[np.in1d(evaluations_df_grouped.index.get_level_values(1), ['DLNN_3'])]
# DLNN_5 = evaluations_df_grouped[np.in1d(evaluations_df_grouped.index.get_level_values(1), ['DLNN_5'])]

# DLNN_3_Train = DLNN_3[np.in1d(DLNN_3.index.get_level_values(2), ['Train'])]
# DLNN_3_Test = DLNN_3[np.in1d(DLNN_3.index.get_level_values(2), ['Test'])]

# DLNN_5_Train = DLNN_5[np.in1d(DLNN_5.index.get_level_values(2), ['Train'])]
# DLNN_5_Test = DLNN_5[np.in1d(DLNN_5.index.get_level_values(2), ['Test'])]

# %%
evaluations_df.columns

# %%
evaluations_df_grouped

# %%
# ##################################################################################
# ##### Decide on metric to visualize
# ##################################################################################

# print("Metrics Available : ")
# print(list(evaluations_df_grouped.columns))

# %% [markdown]
# #### Select a metric to plot below:

# %%
# metric_to_plot = "Accuracy"

# %%
# ##################################################################################
# ##### Visualize with a multiple Bar chart
# ##################################################################################

# x = np.arange(len(DLNN_3_Train[metric_to_plot]))
# width = 0.15

# fig, ax = plt.subplots(figsize=(17,6))
# rects1 = ax.bar(x - (4*(width/2)), round(DLNN_3_Train[metric_to_plot]*100, 3), width, label='DLNN_3, Train')
# rects2 = ax.bar(x - (1.5*(width/2)), round(DLNN_5_Train[metric_to_plot]*100, 3), width, label='DLNN_5, Train')
# rects3 = ax.bar(x + (1.5*(width/2)), round(DLNN_3_Test[metric_to_plot]*100, 3), width, label='DLNN_3, Test')
# rects4 = ax.bar(x + (4*(width/2)), round(DLNN_5_Test[metric_to_plot]*100, 3), width, label='DLNN_5, Test')

# ## Custom y-axis tick labels
# ax.set_ylabel(metric_to_plot)
# ax.set_ylim([(math.floor(min(evaluations_df_grouped[metric_to_plot])*10)-1)*10, 
#             (math.ceil(max(evaluations_df_grouped[metric_to_plot])*10)+1)*10])
# # ax.set_ylim([80, 105])

# ## Custom x-axis tick labels
# ax.set_xticks(x)
# # ax.set_xticklabels(DLNN_3_Train.index.get_level_values(0))
# # ax.set_xticklabels([m+" - "+str(n) for m,n in 
# #                         zip(DLNN_3_Train.index.get_level_values(0),DLNN_3_Train.index.get_level_values(1))],
# #                   rotation=30)
# ax.set_xticklabels(DLNN_3_Train.index.get_level_values(0))

# ax.set_title(metric_to_plot+' by Dataset, Model, Train/Test')
# ax.legend(loc='upper left')

# def autolabel(rects):
#     for rect in rects:
#         height = rect.get_height()
#         ax.annotate('{}'.format(height),
#                     xy=(rect.get_x() + rect.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points", 
#                     ha='center', va='bottom', rotation=90)

# autolabel(rects1)
# autolabel(rects2)
# autolabel(rects3)
# autolabel(rects4)

# plt.show()

# %% [markdown]
# ### Store all metrics' plots to file

# %%
# ##################################################################################
# ##### Iteratively generate comparison plot using every metric
# ##################################################################################

# for metric_to_plot in list(evaluations_df_grouped.columns):
    
#     x = np.arange(len(DLNN_3_Train[metric_to_plot]))
#     width = 0.15

#     fig, ax = plt.subplots(figsize=(17,6))
#     rects1 = ax.bar(x - (4*(width/2)), round(DLNN_3_Train[metric_to_plot]*100, 3), width, label='DLNN_3, Train')
#     rects2 = ax.bar(x - (1.5*(width/2)), round(DLNN_5_Train[metric_to_plot]*100, 3), width, label='DLNN_5, Train')
#     rects3 = ax.bar(x + (1.5*(width/2)), round(DLNN_3_Test[metric_to_plot]*100, 3), width, label='DLNN_3, Test')
#     rects4 = ax.bar(x + (4*(width/2)), round(DLNN_5_Test[metric_to_plot]*100, 3), width, label='DLNN_5, Test')

#     ## Custom y-axis tick labels
#     ax.set_ylabel(metric_to_plot)
#     ax.set_ylim([(math.floor(min(evaluations_df_grouped[metric_to_plot])*10)-1)*10, 
#                 (math.ceil(max(evaluations_df_grouped[metric_to_plot])*10)+1)*10])
#     # ax.set_ylim([80, 105])

#     ## Custom x-axis tick labels
#     ax.set_xticks(x)
#     # ax.set_xticklabels(DLNN_3_Train.index.get_level_values(0))
#     # ax.set_xticklabels([m+" - "+str(n) for m,n in 
#     #                         zip(DLNN_3_Train.index.get_level_values(0),DLNN_3_Train.index.get_level_values(1))],
#     #                   rotation=30)
#     ax.set_xticklabels(DLNN_3_Train.index.get_level_values(0))

#     ax.set_title(metric_to_plot+' by Dataset, Model, Train/Test')
#     ax.legend(loc='upper left')

#     def autolabel(rects):
#         for rect in rects:
#             height = rect.get_height()
#             ax.annotate('{}'.format(height),
#                         xy=(rect.get_x() + rect.get_width() / 2, height),
#                         xytext=(0, 3),  # 3 points vertical offset
#                         textcoords="offset points", 
#                         ha='center', va='bottom', rotation=90)

#     autolabel(rects1)
#     autolabel(rects2)
#     autolabel(rects3)
#     autolabel(rects4)
    
#     plt.savefig(os.path.join(evalPath, "{}_DLNN_Comparison".format(metric_to_plot)))
#     plt.close()

# %%
##################################################################################
##### Define all parameters for model tuning
##################################################################################

n_fold = 10
expName = "PSI_Site_DLNN_CORENup"
outPath = "Results"
foldName = "folds.pickle"

# modelNames = ["DLNN_3", "DLNN_5"]

epochs = 100
batch_size = 32
shuffle = True
seed = None

input_data_folder = "Data\\Psi_Site_Chen"

# %%
import os 
from Bio import SeqIO
import pickle
import numpy as np
import pandas as pd

import tensorflow as tf

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc, accuracy_score, precision_score, confusion_matrix
from sklearn.metrics import roc_auc_score

import math

# %%
# print(tf.test.is_gpu_available(cuda_only=True))
# physical_devices = tf.config.experimental.list_physical_devices('GPU')
physical_devices = tf.config.list_physical_devices('GPU')
print(physical_devices)
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
##################################################################################
##### define all CUSTOM functions
##################################################################################

def one_hot_encode_dna(sequence):
    
    seq_encoded = np.zeros((len(sequence),4))
    dict_nuc = {
        "A": 0,
        "C": 1,
        "G": 2,
        "T":3
    }
    i = 0
    
    for single_character in sequence:
        if(single_character.upper() in dict_nuc.keys()):
            seq_encoded[i][dict_nuc[single_character.upper()]] = 1
            i = i+1
        else:
            return []
    
    return seq_encoded

def one_hot_encode_rna(sequence):
    
    seq_encoded = np.zeros((len(sequence),4))
    dict_nuc = {
        "A": 0,
        "C": 1,
        "G": 2,
        "U":3
    }
    i = 0
    
    for single_character in sequence:
        if(single_character.upper() in dict_nuc.keys()):
            seq_encoded[i][dict_nuc[single_character.upper()]] = 1
            i = i+1
        else:
            return []
    
    return seq_encoded

# %%
##################################################################################
##### define evaluator functions
##################################################################################

## Build the K-fold from dataset
def build_kfold(features, labels, k=10, shuffle=False, seed=None):
    
    skf = StratifiedKFold(n_splits=k, shuffle=shuffle, random_state=seed)
    kfoldList = []
    for train_index, test_index in skf.split(features, labels):
        X_train, X_test = features[train_index], features[test_index]
        y_train, y_test = labels[train_index], labels[test_index]
        kfoldList.append({
            "X_train": X_train,
            "X_test": X_test,
            "y_train":y_train,
            "y_test":y_test
        })
    return kfoldList

def pred2label(y_pred):
    y_pred = np.round(y_pred).astype(int)
    return y_pred

# %%
##################################################################################
##### Function to customize the DLNN architecture with parameters
##################################################################################

def DLNN_CORENup(input_shape = (21,4),
                   conv_filters_per_layer_1 = 50, kernel_length_1 = 5, conv_strides_1 = 1, ## 1st Convolutional layer parameters
                   max_pool_width_1 = 2, max_pool_stride_1 = 2, ## 1st Maxpool layer parameters
                   lstm_decode_units = 50, ## LSTM layer parameters
                   conv_filters_per_layer_2 = 50,  kernel_length_2 = 10, conv_strides_2 = 1, ## 2nd Convolutional layer parameters
                   max_pool_width_2 = 2, max_pool_stride_2 = 2, ## 2nd Maxpool layer parameters
                   dense_decode_units = 370, ## Dense layer parameters
                   prob = 0.5, learn_rate = 0.0003, loss = 'binary_crossentropy', metrics = None):
    
    beta = 0.001
    
    input1 = tf.keras.layers.Input(shape=input_shape)

    x1 = tf.keras.layers.Conv1D(conv_filters_per_layer_1, kernel_length_1, input_shape = input_shape, 
                                strides = conv_strides_1, kernel_regularizer = tf.keras.regularizers.l2(beta), 
                                padding = "same"
                               )(input1)
    x1 = tf.keras.layers.Activation('relu')(x1)
    x1 = tf.keras.layers.MaxPool1D(pool_size = max_pool_width_1, strides = max_pool_stride_1)(x1)
    x1 = tf.keras.layers.Dropout(prob)(x1)

    ## LSTM Path

    x2 = tf.keras.layers.LSTM(lstm_decode_units, return_sequences = True, 
                              kernel_regularizer = tf.keras.regularizers.l2(beta))(x1)
    x2 = tf.keras.layers.Dropout(prob)(x2)
    
    x2 = tf.keras.layers.Flatten()(x2)

    ## Conv Path

    x3 = tf.keras.layers.Conv1D(conv_filters_per_layer_2, kernel_length_2, strides = conv_strides_2, 
                                kernel_regularizer = tf.keras.regularizers.l2(beta), 
                                padding = 'same'
                               )(x1)
    x3 = tf.keras.layers.Activation('relu')(x3)
    x3 = tf.keras.layers.MaxPooling1D(pool_size = max_pool_width_2, strides = max_pool_stride_2)(x3)
    x3 = tf.keras.layers.Dropout(prob)(x3)
    
    x3 = tf.keras.layers.Flatten()(x3)

    ## Fully connected Layers

    y = tf.keras.layers.Concatenate(1)([x2,x3])
    
    y = tf.keras.layers.Dense(dense_decode_units, kernel_regularizer = tf.keras.regularizers.l2(beta), activation = 'relu')(y)
    
    y = tf.keras.layers.Dropout(prob)(y)
    
    y = tf.keras.layers.Dense(1, kernel_regularizer = tf.keras.regularizers.l2(beta), activation = 'sigmoid')(y)

    ## Generate Model from input and output
    model = tf.keras.models.Model(inputs=[input1], outputs=y)
    
    ## Compile model
    if(metrics != None):
        model.compile(optimizer = tf.keras.optimizers.Adam(lr=learn_rate), loss = loss, metrics = metrics)
    else:
        model.compile(optimizer = tf.keras.optimizers.Adam(lr=learn_rate), loss = loss)

    return model

# %%
DLNN_CORENup().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 21, 4)]      0           []
#
#  conv1d (Conv1D)                (None, 21, 50)       1050        ['input_1[0][0]']
#
#  activation (Activation)        (None, 21, 50)       0           ['conv1d[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 50)       0           ['activation[0][0]']
#
#  dropout (Dropout)              (None, 10, 50)       0           ['max_pooling1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 10, 50)       25050       ['dropout[0][0]']
#
#  activation_1 (Activation)      (None, 10, 50)       0           ['conv1d_1[0][0]']
#
#  lstm (LSTM)                    (None, 10, 50)       20200       ['dropout[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 5, 50)       0           ['activation_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 10, 50)       0           ['lstm[0][0]']
#
#  dropout_2 (Dropout)            (None, 5, 50)        0           ['max_pooling1d_1[0][0]']
#
#  flatten (Flatten)              (None, 500)          0           ['dropout_1[0][0]']
#
#  flatten_1 (Flatten)            (None, 250)          0           ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 750)          0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  dense (Dense)                  (None, 370)          277870      ['concatenate[0][0]']
#
#  dropout_3 (Dropout)            (None, 370)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1)            371         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 324,541
# Trainable params: 324,541
# Non-trainable params: 0
# __________________________________________________________________________________________________
# C:\ProgramData\Anaconda3\envs\tf_2_8_py_3_10\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
##################################################################################
##### For each input file, train model and generate different outputs in a structured folder
##################################################################################

## create the evaluation data structure for all iterations
evaluations = {
    "Model" : [],
    "Dataset" : [],
    "Fold" : [],
    "Train_Test" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

# %%
for root, dirs, files in os.walk(input_data_folder):
    for file in files:
        
        input_data_file = os.path.join(root, file)
        
        current_dataset_variety = input_data_file.split("\\")[-1].split(".")[0]
        
        openFile = open(input_data_file)
        fastaSequences = SeqIO.parse(openFile, "fasta")
        
        ##################################################################################
        ##### extract data from the current fasta file
        ##################################################################################

        positive_List = []
        negative_List = []
        positive_onehotencoded_List = []
        negative_onehotencoded_List = []

        for fasta in fastaSequences: 
            name, sequence = fasta.id, str(fasta.seq)
            if "P" in name:
                positive_List.append(sequence)
                aus_seq = one_hot_encode_rna(sequence)
                if(len(aus_seq) != 0):
                    positive_onehotencoded_List.append(aus_seq)
            elif "N" in name:
                negative_List.append(sequence)
                aus_seq = one_hot_encode_rna(sequence)
                if(len(aus_seq) != 0):
                    negative_onehotencoded_List.append(aus_seq)

        openFile.close()

        print("\n======================================================================")
        print("\nFile: "+os.path.join(root, file))
        print("Positive: "+str(len(positive_onehotencoded_List)))
        print("Negative: "+str(len(negative_onehotencoded_List)))
        
        ##################################################################################
        ##### Generate Folds from dataset, and store to file
        ##################################################################################

        ## create the features and labels datasets for the training
        input_size = (len(positive_onehotencoded_List[1]), 4)
        labels = np.concatenate((np.ones((len(positive_onehotencoded_List), 1), dtype=np.float32), np.zeros((len(negative_onehotencoded_List), 1), dtype=np.float32)), axis=0)
        features = np.concatenate((positive_onehotencoded_List,negative_onehotencoded_List), 0)

        ## Generate the k-fold dataset
        folds = build_kfold(features, labels, k=n_fold, shuffle=shuffle, seed=seed)

        ## Write the k-fold dataset to file
        foldPath = os.path.join(outPath, expName, current_dataset_variety, "{}fold".format(n_fold))
        if(not os.path.isdir(foldPath)):
            os.makedirs(foldPath)
        pickle.dump(folds, open(os.path.join(foldPath, foldName), "wb"))

        ## Create and set directory to save model
        modelPath = os.path.join(outPath, expName, current_dataset_variety, "{}fold".format(n_fold), "models")
        if(not os.path.isdir(modelPath)):
            os.makedirs(modelPath)
            
        ##################################################################################
        ##### TRAIN and PREDICT for every Fold, using models
        ##################################################################################

        # fold counter
        i = 0

        for fold in folds:
            
            # adding random shuffling of the dataset for training purpose
            randomized_index_arr = np.arange(fold["X_train"].shape[0])
            randomized_index_arr = np.random.permutation(randomized_index_arr)

            print("\nTrain/Test model "+current_dataset_variety+" on Fold #"+str(i)+".")

            ## Generate model using function
            model = DLNN_CORENup(input_shape = input_size)
    
            model_file_path = os.path.join(modelPath, "{}_bestModel-fold{}.hdf5".format(current_dataset_variety, i))
            ## Define the model callbacks for early stopping and saving the model. Then train model
            modelCallbacks = [
                tf.keras.callbacks.ModelCheckpoint(model_file_path,
                                                   monitor = 'val_accuracy', verbose = 1, save_best_only = True, 
                                                   save_weights_only = False, mode = 'auto', save_freq = 'epoch'),
#                 tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', min_delta = 0, patience = 10, verbose = 0, 
#                                                  mode = 'auto', baseline = None, restore_best_weights = True)
            ]
            model.fit(x = fold["X_train"][randomized_index_arr], y = fold["y_train"][randomized_index_arr], batch_size = batch_size, epochs = epochs, verbose = 1, 
                      validation_data = (fold["X_test"], fold["y_test"]))
            
            model = tf.keras.models.load_model(model_file_path)
            
            ##################################################################################
            ##### Prediction and metrics for TRAIN dataset
            ##################################################################################

            y_pred = model.predict(fold["X_train"])
            label_pred = pred2label(y_pred)
            # Compute precision, recall, sensitivity, specifity, mcc
            acc = accuracy_score(fold["y_train"], label_pred)
            prec = precision_score(fold["y_train"],label_pred)

            conf = confusion_matrix(fold["y_train"], label_pred)
            if(conf[0][0]+conf[1][0]):
                sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
            else:
                sens = 0.0
            if(conf[1][1]+conf[0][1]):
                spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
            else:
                spec = 0.0
            if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
                mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
            else:
                mcc= 0.0
            fpr, tpr, thresholds = roc_curve(fold["y_train"], y_pred)
            auc = roc_auc_score(fold["y_train"], y_pred)

            evaluations["Model"].append(current_dataset_variety)
            evaluations["Dataset"].append(current_dataset_variety)
            evaluations["Fold"].append(i)
            evaluations["Train_Test"].append("Train")
            evaluations["Accuracy"].append(acc)
            evaluations["Precision"].append(prec)
            evaluations["TPR"].append(tpr)
            evaluations["FPR"].append(fpr)
            evaluations["TPR_FPR_Thresholds"].append(thresholds)
            evaluations["AUC"].append(auc)
            evaluations["Sensitivity"].append(sens)
            evaluations["Specificity"].append(spec)
            evaluations["MCC"].append(mcc)

            ##################################################################################
            ##### Prediction and metrics for TEST dataset
            ##################################################################################

            y_pred = model.predict(fold["X_test"])
            label_pred = pred2label(y_pred)
            # Compute precision, recall, sensitivity, specifity, mcc
            acc = accuracy_score(fold["y_test"], label_pred)
            prec = precision_score(fold["y_test"],label_pred)

            conf = confusion_matrix(fold["y_test"], label_pred)
            if(conf[0][0]+conf[1][0]):
                sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
            else:
                sens = 0.0
            if(conf[1][1]+conf[0][1]):
                spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
            else:
                spec = 0.0
            if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
                mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
            else:
                mcc= 0.0
            fpr, tpr, thresholds = roc_curve(fold["y_test"], y_pred)
            auc = roc_auc_score(fold["y_test"], y_pred)

            evaluations["Model"].append(current_dataset_variety)
            evaluations["Dataset"].append(current_dataset_variety)
            evaluations["Fold"].append(i)
            evaluations["Train_Test"].append("Test")
            evaluations["Accuracy"].append(acc)
            evaluations["Precision"].append(prec)
            evaluations["TPR"].append(tpr)
            evaluations["FPR"].append(fpr)
            evaluations["TPR_FPR_Thresholds"].append(thresholds)
            evaluations["AUC"].append(auc)
            evaluations["Sensitivity"].append(sens)
            evaluations["Specificity"].append(spec)
            evaluations["MCC"].append(mcc)

            i = i+1
            del model
            tf.keras.backend.clear_session()

        ##################################################################################
        ##### Dump evaluations to a file
        ##################################################################################

        evalPath = os.path.join(outPath, expName, "_Evaluation_All_Datasets")
        if(not os.path.isdir(evalPath)):
            os.makedirs(evalPath)

        pickle.dump(evaluations,
                    open(os.path.join(evalPath, "{}fold_evaluations.pickle".format(n_fold)), "wb"))
# Out:
# ======================================================================
#
# File: Data\Psi_Site_Chen\HS_990.txt
# Positive: 495
# Negative: 495
#
# Train/Test model HS_990 on Fold #0.
# Epoch 1/100
# C:\ProgramData\Anaconda3\envs\tf_2_8_py_3_10\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 28/28 [==============================] - ETA: 0s - loss: 1.3150WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 4s 25ms/step - loss: 1.3150 - val_loss: 1.2736
# Epoch 2/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.2607WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.2583 - val_loss: 1.2279
# Epoch 3/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.2174WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.2162 - val_loss: 1.1892
# Epoch 4/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.1808WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.1792 - val_loss: 1.1510
# Epoch 5/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.1396WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.1355 - val_loss: 1.1202
# Epoch 6/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.0983WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.0983 - val_loss: 1.0905
# Epoch 7/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.0809WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.0789 - val_loss: 1.0651
# Epoch 8/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.0423WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.0410 - val_loss: 1.0427
# Epoch 9/100
# 24/28 [========================>.....] - ETA: 0s - loss: 1.0309WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.0302 - val_loss: 1.0214
# Epoch 10/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.0092WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.0051 - val_loss: 1.0045
# Epoch 11/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.9816WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.9814 - val_loss: 0.9908
# Epoch 12/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.9724WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.9720 - val_loss: 0.9767
# Epoch 13/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.9543WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.9526 - val_loss: 0.9621
# Epoch 14/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.9336WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.9339 - val_loss: 0.9484
# Epoch 15/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.9279WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.9252 - val_loss: 0.9368
# Epoch 16/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.9154WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.9091 - val_loss: 0.9311
# Epoch 17/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.8892WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8891 - val_loss: 0.9222
# Epoch 18/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.8945WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8942 - val_loss: 0.9113
# Epoch 19/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.8833WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8837 - val_loss: 0.9021
# Epoch 20/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.8659WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8698 - val_loss: 0.8973
# Epoch 21/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.8522WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8532 - val_loss: 0.8975
# Epoch 22/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.8529WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8504 - val_loss: 0.8854
# Epoch 23/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.8280WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8330 - val_loss: 0.8865
# Epoch 24/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.8276WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8291 - val_loss: 0.8799
# Epoch 25/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.8196WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8217 - val_loss: 0.8739
# Epoch 26/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.8143WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8073 - val_loss: 0.8683
# Epoch 27/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.7974WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7975 - val_loss: 0.8641
# Epoch 28/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.8026WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8045 - val_loss: 0.8627
# Epoch 29/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.7810WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7878 - val_loss: 0.8547
# Epoch 30/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.7738WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7785 - val_loss: 0.8543
# Epoch 31/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.7714WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7670 - val_loss: 0.8564
# Epoch 32/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7616WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7620 - val_loss: 0.8509
# Epoch 33/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7741WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7705 - val_loss: 0.8474
# Epoch 34/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.7653WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7616 - val_loss: 0.8439
# Epoch 35/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.7667WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7596 - val_loss: 0.8491
# Epoch 36/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7447WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7482 - val_loss: 0.8449
# Epoch 37/100
# 28/28 [==============================] - ETA: 0s - loss: 0.7404WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7404 - val_loss: 0.8405
# Epoch 38/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.7314WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7300 - val_loss: 0.8362
# Epoch 39/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7210WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7196 - val_loss: 0.8320
# Epoch 40/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7364WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7308 - val_loss: 0.8357
# Epoch 41/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7321WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7262 - val_loss: 0.8359
# Epoch 42/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7100WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7115 - val_loss: 0.8386
# Epoch 43/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7007WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6986 - val_loss: 0.8445
# Epoch 44/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6997WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7035 - val_loss: 0.8388
# Epoch 45/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7038WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7027 - val_loss: 0.8349
# Epoch 46/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6906WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6952 - val_loss: 0.8372
# Epoch 47/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6935WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6870 - val_loss: 0.8327
# Epoch 48/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6942WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6901 - val_loss: 0.8334
# Epoch 49/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6743WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6724 - val_loss: 0.8275
# Epoch 50/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6721WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6724 - val_loss: 0.8403
# Epoch 51/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6787WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6743 - val_loss: 0.8310
# Epoch 52/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6613WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6627 - val_loss: 0.8323
# Epoch 53/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6797WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6715 - val_loss: 0.8319
# Epoch 54/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6403WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6434 - val_loss: 0.8479
# Epoch 55/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6480WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6461 - val_loss: 0.8407
# Epoch 56/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6414WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6444 - val_loss: 0.8475
# Epoch 57/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6304WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6438 - val_loss: 0.8474
# Epoch 58/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6517WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6465 - val_loss: 0.8325
# Epoch 59/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6586WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6501 - val_loss: 0.8338
# Epoch 60/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.6261WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6314 - val_loss: 0.8359
# Epoch 61/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6518WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6419 - val_loss: 0.8368
# Epoch 62/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6131WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6189 - val_loss: 0.8500
# Epoch 63/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6386WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6379 - val_loss: 0.8416
# Epoch 64/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6068WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6107 - val_loss: 0.8560
# Epoch 65/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6197WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6268 - val_loss: 0.8435
# Epoch 66/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6073WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6048 - val_loss: 0.8406
# Epoch 67/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6008WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6042 - val_loss: 0.8528
# Epoch 68/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6065WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6111 - val_loss: 0.8577
# Epoch 69/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6140WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6068 - val_loss: 0.8507
# Epoch 70/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6184WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6165 - val_loss: 0.8520
# Epoch 71/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.6006WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5976 - val_loss: 0.8488
# Epoch 72/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5992WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5937 - val_loss: 0.8625
# Epoch 73/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5955WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5893 - val_loss: 0.8705
# Epoch 74/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5934WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5935 - val_loss: 0.8665
# Epoch 75/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5977WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5956 - val_loss: 0.8600
# Epoch 76/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5624WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5645 - val_loss: 0.8746
# Epoch 77/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5702WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.5760 - val_loss: 0.8726
# Epoch 78/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.5888WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 10ms/step - loss: 0.5840 - val_loss: 0.8760
# Epoch 79/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5480WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.5621 - val_loss: 0.8847
# Epoch 80/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5791WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.5777 - val_loss: 0.8750
# Epoch 81/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5684WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5630 - val_loss: 0.8758
# Epoch 82/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.5783WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.5776 - val_loss: 0.8668
# Epoch 83/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5796WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5745 - val_loss: 0.8522
# Epoch 84/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5726WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.5695 - val_loss: 0.8533
# Epoch 85/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.5640WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5642 - val_loss: 0.8608
# Epoch 86/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5660WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5670 - val_loss: 0.8606
# Epoch 87/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5593WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5661 - val_loss: 0.8658
# Epoch 88/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5601WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5606 - val_loss: 0.8593
# Epoch 89/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5445WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.5470 - val_loss: 0.8543
# Epoch 90/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5346WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5378 - val_loss: 0.8586
# Epoch 91/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5583WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5566 - val_loss: 0.8645
# Epoch 92/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5624WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5578 - val_loss: 0.8482
# Epoch 93/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.5355WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5378 - val_loss: 0.8639
# Epoch 94/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5243WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5172 - val_loss: 0.8820
# Epoch 95/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5249WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5296 - val_loss: 0.8811
# Epoch 96/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5201WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5317 - val_loss: 0.8773
# Epoch 97/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5355WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.5387 - val_loss: 0.8740
# Epoch 98/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5444WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5470 - val_loss: 0.8725
# Epoch 99/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5335WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5254 - val_loss: 0.8784
# Epoch 100/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5540WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5477 - val_loss: 0.8754
#
# Train/Test model HS_990 on Fold #1.
# Epoch 1/100
# C:\ProgramData\Anaconda3\envs\tf_2_8_py_3_10\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 23/28 [=======================>......] - ETA: 0s - loss: 1.3215WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 2s 22ms/step - loss: 1.3155 - val_loss: 1.2750
# Epoch 2/100
# 28/28 [==============================] - ETA: 0s - loss: 1.2657WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 1.2657 - val_loss: 1.2288
# Epoch 3/100
# 22/28 [======================>.......] - ETA: 0s - loss: 1.2183WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 1.2136 - val_loss: 1.1894
# Epoch 4/100
# 24/28 [========================>.....] - ETA: 0s - loss: 1.1751WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.1751 - val_loss: 1.1541
# Epoch 5/100
# 23/28 [=======================>......] - ETA: 0s - loss: 1.1436WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.1438 - val_loss: 1.1245
# Epoch 6/100
# 23/28 [=======================>......] - ETA: 0s - loss: 1.1155WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.1132 - val_loss: 1.0956
# Epoch 7/100
# 22/28 [======================>.......] - ETA: 0s - loss: 1.0932WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 1.0918 - val_loss: 1.0720
# Epoch 8/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.0642WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.0652 - val_loss: 1.0494
# Epoch 9/100
# 22/28 [======================>.......] - ETA: 0s - loss: 1.0393WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 1.0378 - val_loss: 1.0290
# Epoch 10/100
# 25/28 [=========================>....] - ETA: 0s - loss: 1.0201WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.0196 - val_loss: 1.0112
# Epoch 11/100
# 23/28 [=======================>......] - ETA: 0s - loss: 1.0148WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 1.0114 - val_loss: 0.9965
# Epoch 12/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.9879WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.9859 - val_loss: 0.9836
# Epoch 13/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.9762WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.9784 - val_loss: 0.9679
# Epoch 14/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.9636WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.9612 - val_loss: 0.9525
# Epoch 15/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.9394WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.9376 - val_loss: 0.9419
# Epoch 16/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.9397WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.9337 - val_loss: 0.9294
# Epoch 17/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.9194WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.9213 - val_loss: 0.9178
# Epoch 18/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.9169WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.9144 - val_loss: 0.9077
# Epoch 19/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.8892WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8937 - val_loss: 0.8966
# Epoch 20/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.8844WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8887 - val_loss: 0.8891
# Epoch 21/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.8675WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8700 - val_loss: 0.8786
# Epoch 22/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.8726WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8701 - val_loss: 0.8706
# Epoch 23/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.8537WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8529 - val_loss: 0.8650
# Epoch 24/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.8363WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8425 - val_loss: 0.8579
# Epoch 25/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.8471WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8473 - val_loss: 0.8474
# Epoch 26/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.8262WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.8309 - val_loss: 0.8423
# Epoch 27/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.8246WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8173 - val_loss: 0.8347
# Epoch 28/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.8201WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.8173 - val_loss: 0.8308
# Epoch 29/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.8013WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7999 - val_loss: 0.8244
# Epoch 30/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.7981WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7984 - val_loss: 0.8198
# Epoch 31/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7882WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7916 - val_loss: 0.8134
# Epoch 32/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.7889WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7861 - val_loss: 0.8047
# Epoch 33/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.7744WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7787 - val_loss: 0.8087
# Epoch 34/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.7674WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7687 - val_loss: 0.7994
# Epoch 35/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7650WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7630 - val_loss: 0.8018
# Epoch 36/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.7520WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7523 - val_loss: 0.7895
# Epoch 37/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7641WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7649 - val_loss: 0.7856
# Epoch 38/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.7504WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7483 - val_loss: 0.7839
# Epoch 39/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.7424WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7444 - val_loss: 0.7811
# Epoch 40/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.7560WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7553 - val_loss: 0.7774
# Epoch 41/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.7307WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7328 - val_loss: 0.7867
# Epoch 42/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.7327WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7293 - val_loss: 0.7695
# Epoch 43/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7305WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7344 - val_loss: 0.7687
# Epoch 44/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.7062WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7070 - val_loss: 0.7741
# Epoch 45/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.7130WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7162 - val_loss: 0.7608
# Epoch 46/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.7035WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6981 - val_loss: 0.7592
# Epoch 47/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.6986WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.7067 - val_loss: 0.7581
# Epoch 48/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6856WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6903 - val_loss: 0.7529
# Epoch 49/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.7011WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.7015 - val_loss: 0.7525
# Epoch 50/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6976WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6987 - val_loss: 0.7568
# Epoch 51/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6983WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6924 - val_loss: 0.7542
# Epoch 52/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6868WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6784 - val_loss: 0.7477
# Epoch 53/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6750WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6753 - val_loss: 0.7560
# Epoch 54/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6860WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6883 - val_loss: 0.7488
# Epoch 55/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6651WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6696 - val_loss: 0.7540
# Epoch 56/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6649WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6685 - val_loss: 0.7449
# Epoch 57/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6567WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6575 - val_loss: 0.7460
# Epoch 58/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6314WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6445 - val_loss: 0.7477
# Epoch 59/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6569WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6519 - val_loss: 0.7534
# Epoch 60/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6399WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6359 - val_loss: 0.7471
# Epoch 61/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6511WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6536 - val_loss: 0.7486
# Epoch 62/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6305WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6299 - val_loss: 0.7461
# Epoch 63/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6350WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 7ms/step - loss: 0.6329 - val_loss: 0.7421
# Epoch 64/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6251WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6329 - val_loss: 0.7499
# Epoch 65/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.6338WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.6351 - val_loss: 0.7450
# Epoch 66/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.6265WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6341 - val_loss: 0.7454
# Epoch 67/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6253WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6284 - val_loss: 0.7423
# Epoch 68/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6097WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6119 - val_loss: 0.7386
# Epoch 69/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6185WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6254 - val_loss: 0.7453
# Epoch 70/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5996WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6016 - val_loss: 0.7425
# Epoch 71/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6265WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6285 - val_loss: 0.7396
# Epoch 72/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5992WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6060 - val_loss: 0.7397
# Epoch 73/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6012WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5885 - val_loss: 0.7414
# Epoch 74/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5992WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5953 - val_loss: 0.7425
# Epoch 75/100
# 28/28 [==============================] - ETA: 0s - loss: 0.5882WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.5882 - val_loss: 0.7511
# Epoch 76/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5799WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5928 - val_loss: 0.7486
# Epoch 77/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5875WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5929 - val_loss: 0.7471
# Epoch 78/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5945WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5867 - val_loss: 0.7475
# Epoch 79/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.6123WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.6082 - val_loss: 0.7457
# Epoch 80/100
# 22/28 [======================>.......] - ETA: 0s - loss: 0.5903WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 9ms/step - loss: 0.5909 - val_loss: 0.7453
# Epoch 81/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5799WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5825 - val_loss: 0.7528
# Epoch 82/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5910WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5848 - val_loss: 0.7512
# Epoch 83/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5571WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5670 - val_loss: 0.7567
# Epoch 84/100
# 23/28 [=======================>......] - ETA: 0s - loss: 0.5589WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5668 - val_loss: 0.7525
# Epoch 85/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5594WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5632 - val_loss: 0.7617
# Epoch 86/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.5953WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 7ms/step - loss: 0.5895 - val_loss: 0.7455
# Epoch 87/100
# 24/28 [========================>.....] - ETA: 0s - loss: 0.5716WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5684 - val_loss: 0.7571
# Epoch 88/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5500WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5522 - val_loss: 0.7598
# Epoch 89/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5583WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5599 - val_loss: 0.7665
# Epoch 90/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5505WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5530 - val_loss: 0.7601
# Epoch 91/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5268WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5361 - val_loss: 0.7565
# Epoch 92/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5361WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5395 - val_loss: 0.7524
# Epoch 93/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.5391WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5470 - val_loss: 0.7554
# Epoch 94/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5269WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5344 - val_loss: 0.7512
# Epoch 95/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5524WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5521 - val_loss: 0.7586
# Epoch 96/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5544WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5449 - val_loss: 0.7494
# Epoch 97/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.5471WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5434 - val_loss: 0.7519
# Epoch 98/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5256WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5218 - val_loss: 0.7597
# Epoch 99/100
# 26/28 [==========================>...] - ETA: 0s - loss: 0.5499WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5477 - val_loss: 0.7589
# Epoch 100/100
# 25/28 [=========================>....] - ETA: 0s - loss: 0.5238WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/28 [==============================] - 0s 8ms/step - loss: 0.5198 - val_loss: 0.7626
#
# Train/Test model HS_990 on Fold #2.
# Epoch 1/100
# C:\ProgramData\Anaconda3\envs\tf_2_8_py_3_10\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 23/28 [=======================>......] - ETA: 0s - loss: 1.3100
# KeyboardInterrupt

# %% [markdown]
# ## Visualization of Evaluation

# %%
##################################################################################
##### Add import statement here, to make this next part of code standalone executable
##################################################################################

import os
import pickle
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter
import numpy as np
import pandas as pd

# %%
##################################################################################
##### Load file and convert to dataframe for easy manipulation
##################################################################################

# evalPath = os.path.join(outPath, expName, "_Evaluation_All_Datasets")
# if(not os.path.isdir(evalPath)):
#     os.makedirs(evalPath)

# evaluations = pickle.load(open(os.path.join(evalPath, "{}fold_evaluations.pickle".format(n_fold)), "rb"))

evaluations_df = pd.DataFrame.from_dict(evaluations)

# %%
##################################################################################
##### Group dataset (mean of metrics) by [Dataset, Model, Train_Test] combinations
##################################################################################

evaluations_df_grouped = evaluations_df.groupby(["Dataset", 
                                                 "Model", 
                                                 "Train_Test"]).mean().filter(['Accuracy', 
                                                                               'Precision', 
                                                                               'AUC', 
                                                                               'Sensitivity', 
                                                                               'Specificity', 
                                                                               'MCC'])

# DLNN_3 = evaluations_df_grouped[np.in1d(evaluations_df_grouped.index.get_level_values(1), ['DLNN_3'])]
# DLNN_5 = evaluations_df_grouped[np.in1d(evaluations_df_grouped.index.get_level_values(1), ['DLNN_5'])]

# DLNN_3_Train = DLNN_3[np.in1d(DLNN_3.index.get_level_values(2), ['Train'])]
# DLNN_3_Test = DLNN_3[np.in1d(DLNN_3.index.get_level_values(2), ['Test'])]

# DLNN_5_Train = DLNN_5[np.in1d(DLNN_5.index.get_level_values(2), ['Train'])]
# DLNN_5_Test = DLNN_5[np.in1d(DLNN_5.index.get_level_values(2), ['Test'])]

# %%
evaluations_df

# %%
evaluations_df_grouped

# %% [markdown]
# # Max values in evaluation

# %%
evaluations_df_max = evaluations_df[["Dataset",
                                     "Model",
                                     "Train_Test",
                                     "Accuracy",
                                     "Precision",
                                     "Sensitivity",
                                     "Specificity",
                                     "AUC",
                                     "MCC"]].groupby(["Dataset", 
                                                      "Model", 
                                                      "Train_Test"]).max().filter(['Accuracy', 
                                                                               'Precision', 
                                                                               'AUC', 
                                                                               'Sensitivity', 
                                                                               'Specificity', 
                                                                               'MCC']).reset_index()

evaluations_df_test_max = evaluations_df_max[evaluations_df_max["Train_Test"] == 'Test']
evaluations_df_test_max

# %%
#     Dataset	Model	Train_Test	Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# 0	HS_990	HS_990	Test	0.676768	0.704545	0.704082	0.654545	0.704545	0.356886
# 2	MM_944	MM_944	Test	0.744681	0.744681	0.779538	0.769231	0.744681	0.489362
# 4	SS_628	SS_628	Test	0.730159	0.727273	0.776210	0.760000	0.727273	0.461469

# %%
# Dataset	Model	Train_Test	Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# 0	HS_990	HS_990	Test	0.707071	0.705882	0.722041	0.708333	0.705882	0.414047
# 2	MM_944	MM_944	Test	0.715789	0.678571	0.764599	0.769231	0.678571	0.440598
# 4	SS_628	SS_628	Test	0.777778	0.781250	0.826613	0.774194	0.781250	0.555444

# %% [markdown]
# ## Evaluate only top 5 model folds

# %%
evaluations_df5 = evaluations_df.sort_values(['Accuracy'], ascending=False).groupby(["Dataset", 
                                                                                    "Model", 
                                                                                    "Train_Test"]).head(5).reset_index()

evaluations_df5_grouped = evaluations_df5.groupby(["Dataset", 
                                                 "Model", 
                                                 "Train_Test"]).mean().filter(['Accuracy', 
                                                                               'Precision', 
                                                                               'AUC', 
                                                                               'Sensitivity', 
                                                                               'Specificity', 
                                                                               'MCC']).reset_index()

# %%
evaluations_df5_grouped[evaluations_df5_grouped["Train_Test"] == 'Test']

# %%
evaluations_df5_grouped

# %%
#     Dataset	Model	Train_Test	Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# 0	HS_990	HS_990	Test	0.636364	0.647777	0.663347	0.629172	0.647777	0.274748
# 2	MM_944	MM_944	Test	0.692788	0.673316	0.746133	0.722696	0.673316	0.390784
# 4	SS_628	SS_628	Test	0.680389	0.670531	0.770259	0.707128	0.670531	0.369560

# %%
# 	Dataset	Model	Train_Test	Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# 0	HS_990	HS_990	Test	0.624242	0.646211	0.671184	0.611681	0.646211	0.252720
# 2	MM_944	MM_944	Test	0.692744	0.661864	0.743313	0.739310	0.661864	0.393179
# 4	SS_628	SS_628	Test	0.720635	0.731435	0.776210	0.715402	0.731435	0.443644

# %% [markdown]
# # Independent Testing

# %%
independent_data_folder = "Data\\Psi_Site_Chen_Independent"

# %%
##################################################################################
##### For each input file, train model and generate different outputs in a structured folder
##################################################################################

## create the evaluation data structure for all iterations
evaluations = {
    "Model" : [],
    "Dataset" : [],
    "Fold" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

sum_evaluations = {
    "Model" : [],
    "Dataset" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

vote_evaluations = {
    "Model" : [],
    "Dataset" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

for root, dirs, files in os.walk(independent_data_folder):
    for file in files:
        
        input_data_file = os.path.join(root, file)
        
        if 'HS' in file:
            bench_data = 'HS_990'
        elif 'SS' in file:
            bench_data = 'SS_628'
            
        current_dataset_variety = input_data_file.split("\\")[-1].split(".")[0]
        
        openFile = open(input_data_file)
        fastaSequences = SeqIO.parse(openFile, "fasta")
        
        ##################################################################################
        ##### extract data from the current fasta file
        ##################################################################################

        positive_List = []
        negative_List = []
        positive_onehotencoded_List = []
        negative_onehotencoded_List = []

        for fasta in fastaSequences: 
            name, sequence = fasta.id, str(fasta.seq)
            if "P" in name:
                positive_List.append(sequence)
                aus_seq = one_hot_encode_rna(sequence)
                if(len(aus_seq) != 0):
                    positive_onehotencoded_List.append(aus_seq)
            elif "N" in name:
                negative_List.append(sequence)
                aus_seq = one_hot_encode_rna(sequence)
                if(len(aus_seq) != 0):
                    negative_onehotencoded_List.append(aus_seq)

        openFile.close()

        print("\n======================================================================")
        print("\nFile: "+os.path.join(root, file))
        print("Positive: "+str(len(positive_onehotencoded_List)))
        print("Negative: "+str(len(negative_onehotencoded_List)))
        
        ##################################################################################
        ##### Generate Folds from dataset, and store to file
        ##################################################################################

        ## create the features and labels datasets for the training
        labels = np.concatenate((np.ones((len(positive_onehotencoded_List), 1), dtype=np.float32), np.zeros((len(negative_onehotencoded_List), 1), dtype=np.float32)), axis=0)
        features = np.concatenate((positive_onehotencoded_List,negative_onehotencoded_List), 0)
        
        benchModelPath = os.path.join(outPath, expName, bench_data, "{}fold".format(n_fold), "models")
            
        ##################################################################################
        ##### TRAIN and PREDICT for every Fold, using models
        ##################################################################################
        
        y_pred_list = []

        for fold in range(n_fold):

            print("\nIndependent test on "+current_dataset_variety+" using Fold #"+str(fold)+" model from "+bench_data+".")
            
            current_model_path = os.path.join(
                benchModelPath, 
                "{}_bestModel-fold{}.hdf5".format(bench_data, fold)
            )
            
            model = tf.keras.models.load_model(current_model_path)

            ##################################################################################
            ##### Prediction and metrics for TEST dataset
            ##################################################################################
            
            y_pred = model.predict(features)
            y_pred_list.append(y_pred)
            label_pred = pred2label(y_pred)
            # Compute precision, recall, sensitivity, specifity, mcc
            acc = accuracy_score(labels, label_pred)
            prec = precision_score(labels,label_pred)

            conf = confusion_matrix(labels, label_pred)
            if(conf[0][0]+conf[1][0]):
                sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
            else:
                sens = 0.0
            if(conf[1][1]+conf[0][1]):
                spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
            else:
                spec = 0.0
            if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
                mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
            else:
                mcc= 0.0
            fpr, tpr, thresholds = roc_curve(labels, y_pred)
            auc = roc_auc_score(labels, y_pred)

            evaluations["Model"].append(current_dataset_variety)
            evaluations["Dataset"].append(current_dataset_variety)
            evaluations["Fold"].append(i)
            evaluations["Accuracy"].append(acc)
            evaluations["Precision"].append(prec)
            evaluations["TPR"].append(tpr)
            evaluations["FPR"].append(fpr)
            evaluations["TPR_FPR_Thresholds"].append(thresholds)
            evaluations["AUC"].append(auc)
            evaluations["Sensitivity"].append(sens)
            evaluations["Specificity"].append(spec)
            evaluations["MCC"].append(mcc)

            del model
            tf.keras.backend.clear_session()
            
        ##################################################################################
        ##### Prediction and metrics using sum of all folds
        ##################################################################################
        
        y_pred_list_arr = np.swapaxes(np.array(y_pred_list), 0,1)
        y_pred_vote = np.mean(y_pred_list_arr, axis = 1)
        label_vote = pred2label(y_pred_vote)
        
        # Compute precision, recall, sensitivity, specifity, mcc
        acc = accuracy_score(labels, label_vote)
        prec = precision_score(labels, label_vote)

        conf = confusion_matrix(labels, label_vote)
        if(conf[0][0]+conf[1][0]):
            sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
        else:
            sens = 0.0
        if(conf[1][1]+conf[0][1]):
            spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
        else:
            spec = 0.0
        if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
            mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
        else:
            mcc= 0.0
        fpr, tpr, thresholds = roc_curve(labels, y_pred_vote)
        auc = roc_auc_score(labels, y_pred_vote)
        
        sum_evaluations["Model"].append(current_dataset_variety)
        sum_evaluations["Dataset"].append(current_dataset_variety)
        sum_evaluations["Accuracy"].append(acc)
        sum_evaluations["Precision"].append(prec)
        sum_evaluations["TPR"].append(tpr)
        sum_evaluations["FPR"].append(fpr)
        sum_evaluations["TPR_FPR_Thresholds"].append(thresholds)
        sum_evaluations["AUC"].append(auc)
        sum_evaluations["Sensitivity"].append(sens)
        sum_evaluations["Specificity"].append(spec)
        sum_evaluations["MCC"].append(mcc)
        
        ##################################################################################
        ##### Prediction and metrics using vote of all folds
        ##################################################################################
        
        y_pred_list_arr = np.swapaxes(np.array(y_pred_list), 0,1)
        y_pred_vote = np.sum(np.round(y_pred_list_arr), axis = 1)
        label_vote = (y_pred_vote > 5).astype(int)
        
        # Compute precision, recall, sensitivity, specifity, mcc
        acc = accuracy_score(labels, label_vote)
        prec = precision_score(labels, label_vote)

        conf = confusion_matrix(labels, label_vote)
        if(conf[0][0]+conf[1][0]):
            sens = float(conf[0][0])/float(conf[0][0]+conf[1][0])
        else:
            sens = 0.0
        if(conf[1][1]+conf[0][1]):
            spec = float(conf[1][1])/float(conf[1][1]+conf[0][1])
        else:
            spec = 0.0
        if((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0])):
            mcc = (float(conf[0][0])*float(conf[1][1]) - float(conf[1][0])*float(conf[0][1]))/math.sqrt((conf[0][0]+conf[0][1])*(conf[0][0]+conf[1][0])*(conf[1][1]+conf[0][1])*(conf[1][1]+conf[1][0]))
        else:
            mcc= 0.0
        fpr, tpr, thresholds = roc_curve(labels, y_pred_vote)
        auc = roc_auc_score(labels, y_pred_vote)

        vote_evaluations["Model"].append(current_dataset_variety)
        vote_evaluations["Dataset"].append(current_dataset_variety)
        vote_evaluations["Accuracy"].append(acc)
        vote_evaluations["Precision"].append(prec)
        vote_evaluations["TPR"].append(tpr)
        vote_evaluations["FPR"].append(fpr)
        vote_evaluations["TPR_FPR_Thresholds"].append(thresholds)
        vote_evaluations["AUC"].append(auc)
        vote_evaluations["Sensitivity"].append(sens)
        vote_evaluations["Specificity"].append(spec)
        vote_evaluations["MCC"].append(mcc)
        
        ##################################################################################
        ##### Dump evaluations to a file
        ##################################################################################

        evalPath = os.path.join(outPath, expName, "_Evaluation_Independent_Datasets")
        if(not os.path.isdir(evalPath)):
            os.makedirs(evalPath)

        pickle.dump(evaluations,
                    open(os.path.join(evalPath, "{}fold_evaluations.pickle".format(n_fold)), "wb"))
        
        pickle.dump(sum_evaluations,
                    open(os.path.join(evalPath, "{}fold_sum_evaluations.pickle".format(n_fold)), "wb"))
        
        pickle.dump(vote_evaluations,
                    open(os.path.join(evalPath, "{}fold_vote_evaluations.pickle".format(n_fold)), "wb"))

# %% [markdown]
# ## Predict using each fold, average result of all 10 folds

# %%
evaluations_df = pd.DataFrame.from_dict(evaluations)

evaluations_df_grouped = evaluations_df.groupby(["Dataset", 
                                                 "Model"]).mean().filter(['Accuracy', 
                                                                           'Precision', 
                                                                           'AUC', 
                                                                           'Sensitivity', 
                                                                           'Specificity', 
                                                                           'MCC'])

# %%
evaluations_df_grouped

# %%
# Dataset	Model	Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# HS_200	HS_200	0.6780	0.676877	0.72104	0.684022	0.676877	0.358413
# SS_200	SS_200	0.6765	0.646861	0.75923	0.733891	0.646861	0.366287

# %%
#                 Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# Dataset	Model						
# HS_200	HS_200	0.6750	0.664200	0.72708	0.693586	0.664200	0.353822
# SS_200	SS_200	0.6975	0.674367	0.76201	0.731014	0.674367	0.400129

# %% [markdown]
# ## Predict using each fold, average result of top 5 folds

# %%
evaluations_df5 = evaluations_df.sort_values(['Accuracy'],ascending=False).groupby(["Dataset", 
                                                                                    "Model"]).head(5).reset_index()

evaluations_df5_grouped = evaluations_df5.groupby(["Dataset", 
                                                   "Model"]).mean().filter(['Accuracy', 
                                                                            'Precision', 
                                                                            'AUC', 
                                                                            'Sensitivity', 
                                                                            'Specificity', 
                                                                            'MCC']).reset_index()

# %%
evaluations_df5_grouped

# %%
# Dataset	Model	Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# 0	HS_200	HS_200	0.704	0.697657	0.73026	0.712350	0.697657	0.409001
# 1	SS_200	SS_200	0.701	0.679132	0.76770	0.731744	0.679132	0.406404

# %%
# 	Dataset	Model	Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# 0	HS_200	HS_200	0.690	0.690418	0.72364	0.690651	0.690418	0.380534
# 1	SS_200	SS_200	0.714	0.695143	0.76684	0.738915	0.695143	0.431015

# %% [markdown]
# ## Predict using all 10 folds, vote using sum of scores of all 10 folds

# %%
sum_evaluations_df = pd.DataFrame.from_dict(sum_evaluations)

sum_evaluations_df.filter(["Dataset", "Model", 'Accuracy', 'Precision', 'AUC', 'Sensitivity', 'Specificity', 'MCC'])

# %%
# 	Dataset	Model	Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# 0	HS_200	HS_200	0.705	0.702970	0.7352	0.707071	0.702970	0.410021
# 1	SS_200	SS_200	0.710	0.666667	0.7834	0.783784	0.666667	0.434959

# %%
# 	Dataset	Model	Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# 0	HS_200	HS_200	0.695	0.685714	0.7445	0.705263	0.685714	0.390488
# 1	SS_200	SS_200	0.705	0.672269	0.7873	0.753086	0.672269	0.417607

# %% [markdown]
# ## Predict using all 10 folds, vote using absolute vote of all 10 folds

# %%
vote_evaluations_df = pd.DataFrame.from_dict(vote_evaluations)

vote_evaluations_df.filter(["Dataset", "Model", 'Accuracy', 'Precision', 'AUC', 'Sensitivity', 'Specificity', 'MCC'])

# %%
#     Dataset	Model	Accuracy	Precision	AUC	Sensitivity	Specificity	MCC
# 0	HS_200	HS_200	0.715	0.712871	0.72785	0.717172	0.712871	0.430022
# 1	SS_200	SS_200	0.695	0.666667	0.76455	0.734940	0.666667	0.395761
